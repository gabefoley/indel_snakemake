# %%
import pickle
import pandas as pd
import matplotlib.pyplot as plt
import glob
import os
from collections import defaultdict
import csv
import ete3

# %%
taxa = sorted([x.split("/")[-1] for x in glob.glob("./output_dicts/*") if os.path.isdir(x)], key=float)

# %%
taxa
# Out:
# ['10', '20', '30', '40', '50']

# %%
methods = ['PSP', 'PSML', 'SICP', 'SICML', 'BEP', 'BEML', 'fastmlp', 'fastmlml']

output_file = "indel_output.csv"

methods_dict = defaultdict(dict)
for taxon in taxa:
    for method in methods:
        with open(f'./output_dicts/{taxon}/gaps_{method}_1.p', 'rb') as handle:
            methods_dict[method][taxon] = pickle.load(handle)
        
methods_dict
# Out:
# defaultdict(dict,
#             {'PSP': {'10': {'N0_N1': [],
#                'N0_sequence5': [<gap_checker.Indel at 0x1191997b8>,
#                 <gap_checker.Indel at 0x1191995c0>,
#                 <gap_checker.Indel at 0x1191994e0>,
#                 <gap_checker.Indel at 0x119199518>,
#                 <gap_checker.Indel at 0x119199320>],
#                'N1_sequence3': [<gap_checker.Indel at 0x119199390>,
#                 <gap_checker.Indel at 0x1191993c8>,
#                 <gap_checker.Indel at 0x119199400>],
#                'N1_N2': [],
#                'N2_N3': [],
#                'N2_N7': [],
#                'N3_N4': [<gap_checker.Indel at 0x119199208>],
#                'N3_N5': [],
#                'N7_sequence8': [<gap_checker.Indel at 0x1191991d0>,
#                 <gap_checker.Indel at 0x1191990b8>,
#                 <gap_checker.Indel at 0x1191990f0>],
#                'N7_N8': [<gap_checker.Indel at 0x119199160>],
#                'N4_sequence4': [],
#                'N4_sequence6': [<gap_checker.Indel at 0x118f6c278>],
#                'N5_sequence7': [],
#                'N5_N6': [],
#                'N8_sequence10': [],
#                'N8_sequence9': [],
#                'N6_sequence2': [],
#                'N6_sequence1': []},
#               '20': {'N0_N1': [],
#                'N0_N17': [<gap_checker.Indel at 0x11918e908>,
#                 <gap_checker.Indel at 0x119234358>,
#                 <gap_checker.Indel at 0x119234390>,
#                 <gap_checker.Indel at 0x119234400>,
#                 <gap_checker.Indel at 0x119234470>,
#                 <gap_checker.Indel at 0x1192344a8>],
#                'N1_N2': [<gap_checker.Indel at 0x119234550>,
#                 <gap_checker.Indel at 0x119234588>,
#                 <gap_checker.Indel at 0x1192345c0>,
#                 <gap_checker.Indel at 0x119234630>,
#                 <gap_checker.Indel at 0x119234668>],
#                'N1_N3': [],
#                'N17_N18': [],
#                'N17_sequence3': [<gap_checker.Indel at 0x119234710>,
#                 <gap_checker.Indel at 0x119234748>],
#                'N2_sequence12': [<gap_checker.Indel at 0x119234780>],
#                'N2_sequence8': [<gap_checker.Indel at 0x1192347f0>,
#                 <gap_checker.Indel at 0x119234828>,
#                 <gap_checker.Indel at 0x119234160>],
#                'N3_N4': [<gap_checker.Indel at 0x1192348d0>,
#                 <gap_checker.Indel at 0x119234908>],
#                'N3_N11': [<gap_checker.Indel at 0x1192349b0>],
#                'N18_sequence9': [],
#                'N18_sequence18': [],
#                'N4_N5': [<gap_checker.Indel at 0x119234a20>],
#                'N4_N8': [],
#                'N11_N12': [],
#                'N11_sequence5': [<gap_checker.Indel at 0x119234b00>,
#                 <gap_checker.Indel at 0x119234b38>,
#                 <gap_checker.Indel at 0x119234c18>],
#                'N5_sequence6': [<gap_checker.Indel at 0x119234dd8>,
#                 <gap_checker.Indel at 0x119234f60>,
#                 <gap_checker.Indel at 0x119189cf8>,
#                 <gap_checker.Indel at 0x119189588>],
#                'N5_N6': [],
#                'N8_sequence14': [],
#                'N8_N9': [<gap_checker.Indel at 0x119189e10>,
#                 <gap_checker.Indel at 0x119189dd8>,
#                 <gap_checker.Indel at 0x119189da0>],
#                'N12_sequence13': [<gap_checker.Indel at 0x119189eb8>,
#                 <gap_checker.Indel at 0x119189f28>,
#                 <gap_checker.Indel at 0x119189f60>,
#                 <gap_checker.Indel at 0x119189f98>],
#                'N12_N13': [<gap_checker.Indel at 0x11923c0b8>],
#                'N6_sequence15': [<gap_checker.Indel at 0x11923c0f0>,
#                 <gap_checker.Indel at 0x11923c160>],
#                'N6_N7': [],
#                'N9_sequence16': [<gap_checker.Indel at 0x11923c208>],
#                'N9_N10': [],
#                'N13_N14': [],
#                'N13_sequence10': [],
#                'N7_sequence1': [<gap_checker.Indel at 0x11923c2b0>],
#                'N7_sequence17': [<gap_checker.Indel at 0x11923c2e8>],
#                'N10_sequence4': [<gap_checker.Indel at 0x11923c320>],
#                'N10_sequence2': [],
#                'N14_sequence7': [<gap_checker.Indel at 0x11923c358>],
#                'N14_N15': [],
#                'N15_sequence11': [<gap_checker.Indel at 0x11923c3c8>,
#                 <gap_checker.Indel at 0x11923c400>],
#                'N15_N16': [],
#                'N16_sequence19': [],
#                'N16_sequence20': []},
#               '30': {'N0_N1': [],
#                'N0_N13': [],
#                'N1_N2': [<gap_checker.Indel at 0x119248c18>],
#                'N1_sequence23': [<gap_checker.Indel at 0x119679978>,
#                 <gap_checker.Indel at 0x119679a20>],
#                'N13_N14': [<gap_checker.Indel at 0x119679a90>,
#                 <gap_checker.Indel at 0x119679b00>],
#                'N13_N15': [],
#                'N2_N3': [<gap_checker.Indel at 0x119679ba8>],
#                'N2_N8': [],
#                'N14_sequence20': [<gap_checker.Indel at 0x119679c18>],
#                'N14_sequence17': [],
#                'N15_N16': [],
#                'N15_sequence11': [<gap_checker.Indel at 0x119679c88>,
#                 <gap_checker.Indel at 0x119679cc0>],
#                'N3_N4': [],
#                'N3_sequence16': [<gap_checker.Indel at 0x119679d68>,
#                 <gap_checker.Indel at 0x119679da0>],
#                'N8_N9': [],
#                'N8_N10': [],
#                'N16_N17': [],
#                'N16_N21': [<gap_checker.Indel at 0x119679ef0>,
#                 <gap_checker.Indel at 0x119679f60>],
#                'N4_N5': [],
#                'N4_sequence19': [<gap_checker.Indel at 0x11967d048>,
#                 <gap_checker.Indel at 0x11967d080>,
#                 <gap_checker.Indel at 0x11967d0f0>],
#                'N9_sequence28': [],
#                'N9_sequence30': [],
#                'N10_sequence22': [<gap_checker.Indel at 0x11967d160>],
#                'N10_N11': [],
#                'N17_N18': [<gap_checker.Indel at 0x11967d208>],
#                'N17_N19': [],
#                'N21_N22': [<gap_checker.Indel at 0x11967d2b0>,
#                 <gap_checker.Indel at 0x11967d320>,
#                 <gap_checker.Indel at 0x11967d390>],
#                'N21_N24': [],
#                'N5_sequence24': [<gap_checker.Indel at 0x11967d400>],
#                'N5_N6': [<gap_checker.Indel at 0x11967d4e0>],
#                'N11_sequence25': [],
#                'N11_N12': [],
#                'N18_sequence18': [<gap_checker.Indel at 0x11967d550>],
#                'N18_sequence29': [],
#                'N19_N20': [<gap_checker.Indel at 0x11967d5c0>],
#                'N19_sequence10': [],
#                'N22_sequence7': [<gap_checker.Indel at 0x11967d630>,
#                 <gap_checker.Indel at 0x11967d668>,
#                 <gap_checker.Indel at 0x11967d6a0>],
#                'N22_N23': [],
#                'N24_N25': [],
#                'N24_N27': [],
#                'N6_N7': [],
#                'N6_sequence5': [],
#                'N12_sequence6': [],
#                'N12_sequence3': [],
#                'N20_sequence21': [<gap_checker.Indel at 0x11967d7b8>],
#                'N20_sequence9': [<gap_checker.Indel at 0x11967d828>,
#                 <gap_checker.Indel at 0x11967d860>],
#                'N23_sequence13': [<gap_checker.Indel at 0x11967d898>],
#                'N23_sequence8': [<gap_checker.Indel at 0x11967d8d0>,
#                 <gap_checker.Indel at 0x11967d940>],
#                'N25_N26': [],
#                'N25_sequence12': [<gap_checker.Indel at 0x11967d9e8>,
#                 <gap_checker.Indel at 0x11967da20>,
#                 <gap_checker.Indel at 0x11967da58>],
#                'N27_N28': [<gap_checker.Indel at 0x11967db00>,
#                 <gap_checker.Indel at 0x11967db38>],
#                'N27_sequence27': [<gap_checker.Indel at 0x11967db70>,
#                 <gap_checker.Indel at 0x11967dc18>],
#                'N7_sequence14': [],
#                'N7_sequence26': [],
#                'N26_sequence2': [<gap_checker.Indel at 0x11967dc50>,
#                 <gap_checker.Indel at 0x11967dcc0>],
#                'N26_sequence15': [],
#                'N28_sequence1': [<gap_checker.Indel at 0x11967dcf8>,
#                 <gap_checker.Indel at 0x11967dd68>,
#                 <gap_checker.Indel at 0x11967dda0>],
#                'N28_sequence4': [<gap_checker.Indel at 0x11967ddd8>]},
#               '40': {'N0_N1': [],
#                'N0_N17': [],
#                'N1_N2': [],
#                'N1_N14': [<gap_checker.Indel at 0x1196c39b0>],
#                'N17_sequence17': [<gap_checker.Indel at 0x1196cbd68>,
#                 <gap_checker.Indel at 0x1196cbdd8>,
#                 <gap_checker.Indel at 0x1196cbe10>],
#                'N17_N18': [],
#                'N2_N3': [<gap_checker.Indel at 0x1196cbeb8>],
#                'N2_N5': [],
#                'N14_sequence27': [<gap_checker.Indel at 0x1196cbf60>,
#                 <gap_checker.Indel at 0x1196cbfd0>],
#                'N14_N15': [<gap_checker.Indel at 0x1196cf0b8>],
#                'N18_N19': [<gap_checker.Indel at 0x1196cf160>],
#                'N18_N27': [],
#                'N3_N4': [],
#                'N3_sequence32': [<gap_checker.Indel at 0x1196cf278>,
#                 <gap_checker.Indel at 0x1196cf2e8>,
#                 <gap_checker.Indel at 0x1196cf320>],
#                'N5_N6': [],
#                'N5_N10': [],
#                'N15_sequence34': [<gap_checker.Indel at 0x1196cf400>],
#                'N15_N16': [],
#                'N19_N20': [<gap_checker.Indel at 0x1196cf4e0>],
#                'N19_N21': [],
#                'N27_N28': [<gap_checker.Indel at 0x1196cf588>],
#                'N27_N38': [<gap_checker.Indel at 0x1196cf5f8>,
#                 <gap_checker.Indel at 0x1196cf630>,
#                 <gap_checker.Indel at 0x1196cf6a0>],
#                'N4_sequence5': [],
#                'N4_sequence13': [<gap_checker.Indel at 0x1196cf748>,
#                 <gap_checker.Indel at 0x1196cf780>,
#                 <gap_checker.Indel at 0x1196cf7b8>],
#                'N6_N7': [<gap_checker.Indel at 0x1196cf828>],
#                'N6_N9': [<gap_checker.Indel at 0x1196cf8d0>],
#                'N10_N11': [],
#                'N10_sequence23': [],
#                'N16_sequence25': [],
#                'N16_sequence7': [],
#                'N20_sequence29': [<gap_checker.Indel at 0x1196cf940>,
#                 <gap_checker.Indel at 0x1196cf9e8>],
#                'N20_sequence35': [],
#                'N21_N22': [],
#                'N21_N25': [],
#                'N28_N29': [],
#                'N28_N32': [],
#                'N38_sequence3': [<gap_checker.Indel at 0x1196cfb00>],
#                'N38_sequence22': [<gap_checker.Indel at 0x1196cfb38>],
#                'N7_N8': [],
#                'N7_sequence16': [],
#                'N9_sequence26': [<gap_checker.Indel at 0x1196cfbe0>,
#                 <gap_checker.Indel at 0x1196cfc18>,
#                 <gap_checker.Indel at 0x1196cfc50>],
#                'N9_sequence9': [<gap_checker.Indel at 0x1196cfc88>],
#                'N11_N12': [],
#                'N11_sequence30': [<gap_checker.Indel at 0x1196cfcf8>],
#                'N22_sequence21': [<gap_checker.Indel at 0x1196cfda0>],
#                'N22_N23': [<gap_checker.Indel at 0x1196cfe10>],
#                'N25_sequence15': [<gap_checker.Indel at 0x1196cfe48>,
#                 <gap_checker.Indel at 0x1196cfe80>],
#                'N25_N26': [<gap_checker.Indel at 0x1196cff28>],
#                'N29_N30': [],
#                'N29_N31': [<gap_checker.Indel at 0x1196d4048>],
#                'N32_N33': [],
#                'N32_sequence18': [<gap_checker.Indel at 0x1196d40f0>],
#                'N8_sequence31': [],
#                'N8_sequence14': [<gap_checker.Indel at 0x1196d4160>,
#                 <gap_checker.Indel at 0x1196d4198>,
#                 <gap_checker.Indel at 0x1196d4208>],
#                'N12_N13': [],
#                'N12_sequence2': [],
#                'N23_sequence33': [<gap_checker.Indel at 0x1196d4278>],
#                'N23_N24': [],
#                'N26_sequence1': [],
#                'N26_sequence6': [<gap_checker.Indel at 0x1196d4358>],
#                'N30_sequence37': [],
#                'N30_sequence38': [],
#                'N31_sequence10': [<gap_checker.Indel at 0x1196d4390>],
#                'N31_sequence12': [],
#                'N33_N34': [],
#                'N33_N35': [],
#                'N13_sequence24': [],
#                'N13_sequence39': [],
#                'N24_sequence8': [],
#                'N24_sequence4': [],
#                'N34_sequence40': [<gap_checker.Indel at 0x1196d4438>],
#                'N34_sequence11': [],
#                'N35_N36': [],
#                'N35_sequence20': [<gap_checker.Indel at 0x1196d44e0>],
#                'N36_sequence28': [],
#                'N36_N37': [],
#                'N37_sequence19': [],
#                'N37_sequence36': []},
#               '50': {'N0_N1': [<gap_checker.Indel at 0x119746048>],
#                'N0_N3': [],
#                'N1_N2': [],
#                'N1_sequence30': [],
#                'N3_N4': [],
#                'N3_N27': [<gap_checker.Indel at 0x119748b38>],
#                'N2_sequence13': [<gap_checker.Indel at 0x119748ba8>],
#                'N2_sequence16': [],
#                'N4_N5': [],
#                'N4_N21': [],
#                'N27_N28': [],
#                'N27_N37': [],
#                'N5_sequence2': [<gap_checker.Indel at 0x119748cc0>,
#                 <gap_checker.Indel at 0x119748d68>,
#                 <gap_checker.Indel at 0x119748dd8>,
#                 <gap_checker.Indel at 0x119748e48>,
#                 <gap_checker.Indel at 0x119748eb8>,
#                 <gap_checker.Indel at 0x119748f28>],
#                'N5_N6': [],
#                'N21_N22': [<gap_checker.Indel at 0x119748fd0>,
#                 <gap_checker.Indel at 0x11974b048>,
#                 <gap_checker.Indel at 0x11974b080>,
#                 <gap_checker.Indel at 0x11974b0b8>],
#                'N21_N26': [<gap_checker.Indel at 0x11974b160>,
#                 <gap_checker.Indel at 0x11974b1d0>,
#                 <gap_checker.Indel at 0x11974b208>],
#                'N28_N29': [<gap_checker.Indel at 0x11974b278>],
#                'N28_N35': [],
#                'N37_N38': [<gap_checker.Indel at 0x11974b320>],
#                'N37_N47': [<gap_checker.Indel at 0x11974b3c8>,
#                 <gap_checker.Indel at 0x119176198>],
#                'N6_N7': [<gap_checker.Indel at 0x119076f28>],
#                'N6_N15': [],
#                'N22_sequence26': [],
#                'N22_N23': [<gap_checker.Indel at 0x11974b470>],
#                'N26_sequence43': [<gap_checker.Indel at 0x11974b4a8>,
#                 <gap_checker.Indel at 0x11974b4e0>,
#                 <gap_checker.Indel at 0x11974b550>,
#                 <gap_checker.Indel at 0x11974b588>],
#                'N26_sequence48': [<gap_checker.Indel at 0x11974b5f8>,
#                 <gap_checker.Indel at 0x11974b668>,
#                 <gap_checker.Indel at 0x11974b6d8>],
#                'N29_N30': [],
#                'N29_N31': [],
#                'N35_N36': [],
#                'N35_sequence37': [<gap_checker.Indel at 0x11974b7b8>,
#                 <gap_checker.Indel at 0x11974b828>,
#                 <gap_checker.Indel at 0x11974b860>],
#                'N38_N39': [],
#                'N38_N40': [],
#                'N47_N48': [],
#                'N47_sequence34': [<gap_checker.Indel at 0x11974b978>],
#                'N7_N8': [],
#                'N7_sequence20': [<gap_checker.Indel at 0x11974b9e8>,
#                 <gap_checker.Indel at 0x11974ba20>],
#                'N15_N16': [],
#                'N15_N17': [<gap_checker.Indel at 0x11974bac8>],
#                'N23_N24': [],
#                'N23_N25': [<gap_checker.Indel at 0x11974bb70>],
#                'N30_sequence18': [<gap_checker.Indel at 0x11974bbe0>,
#                 <gap_checker.Indel at 0x11974bc18>,
#                 <gap_checker.Indel at 0x11974bc88>,
#                 <gap_checker.Indel at 0x11974bcf8>],
#                'N30_sequence40': [<gap_checker.Indel at 0x11974bda0>,
#                 <gap_checker.Indel at 0x11974bdd8>],
#                'N31_N32': [<gap_checker.Indel at 0x11974beb8>],
#                'N31_N34': [<gap_checker.Indel at 0x11974bf28>,
#                 <gap_checker.Indel at 0x11974bf60>,
#                 <gap_checker.Indel at 0x11974bfd0>,
#                 <gap_checker.Indel at 0x11974c048>,
#                 <gap_checker.Indel at 0x11974c0b8>],
#                'N36_sequence38': [<gap_checker.Indel at 0x11974c128>],
#                'N36_sequence17': [<gap_checker.Indel at 0x11974c1d0>,
#                 <gap_checker.Indel at 0x11974c208>],
#                'N39_sequence33': [],
#                'N39_sequence27': [<gap_checker.Indel at 0x11974c240>],
#                'N40_N41': [],
#                'N40_N43': [],
#                'N48_sequence10': [],
#                'N48_sequence5': [],
#                'N8_N9': [],
#                'N8_N14': [<gap_checker.Indel at 0x11974c3c8>,
#                 <gap_checker.Indel at 0x11974c438>,
#                 <gap_checker.Indel at 0x11974c470>],
#                'N16_sequence15': [<gap_checker.Indel at 0x11974c4e0>,
#                 <gap_checker.Indel at 0x11974c518>,
#                 <gap_checker.Indel at 0x11974c5c0>,
#                 <gap_checker.Indel at 0x11974c630>,
#                 <gap_checker.Indel at 0x11974c668>,
#                 <gap_checker.Indel at 0x11974c6d8>],
#                'N16_sequence45': [<gap_checker.Indel at 0x11974c748>],
#                'N17_N18': [<gap_checker.Indel at 0x11974c828>],
#                'N17_sequence21': [<gap_checker.Indel at 0x11974c898>],
#                'N24_sequence28': [<gap_checker.Indel at 0x11974c908>],
#                'N24_sequence6': [<gap_checker.Indel at 0x11974c978>,
#                 <gap_checker.Indel at 0x11974c9b0>,
#                 <gap_checker.Indel at 0x11974ca20>],
#                'N25_sequence32': [<gap_checker.Indel at 0x11974ca58>],
#                'N25_sequence9': [],
#                'N32_N33': [],
#                'N32_sequence49': [<gap_checker.Indel at 0x11974cb00>],
#                'N34_sequence3': [<gap_checker.Indel at 0x11974cb38>],
#                'N34_sequence29': [],
#                'N41_sequence23': [<gap_checker.Indel at 0x11974cba8>,
#                 <gap_checker.Indel at 0x11974cc18>,
#                 <gap_checker.Indel at 0x11974cc50>,
#                 <gap_checker.Indel at 0x11974ccc0>],
#                'N41_N42': [<gap_checker.Indel at 0x11974cda0>],
#                'N43_N44': [],
#                'N43_N46': [<gap_checker.Indel at 0x11974ce48>,
#                 <gap_checker.Indel at 0x11974ceb8>,
#                 <gap_checker.Indel at 0x11974cf28>],
#                'N9_N10': [<gap_checker.Indel at 0x11974cf98>],
#                'N9_N12': [<gap_checker.Indel at 0x11974e080>,
#                 <gap_checker.Indel at 0x11974e0b8>],
#                'N14_sequence46': [],
#                'N14_sequence47': [],
#                'N18_N19': [<gap_checker.Indel at 0x11974e160>,
#                 <gap_checker.Indel at 0x11974e198>],
#                'N18_sequence8': [],
#                'N33_sequence42': [],
#                'N33_sequence4': [],
#                'N42_sequence39': [],
#                'N42_sequence35': [<gap_checker.Indel at 0x11974e208>],
#                'N44_sequence12': [<gap_checker.Indel at 0x11974e240>],
#                'N44_N45': [<gap_checker.Indel at 0x11974e2e8>,
#                 <gap_checker.Indel at 0x11974e320>],
#                'N46_sequence1': [],
#                'N46_sequence7': [<gap_checker.Indel at 0x11974e358>,
#                 <gap_checker.Indel at 0x11974e390>,
#                 <gap_checker.Indel at 0x11974e400>],
#                'N10_N11': [<gap_checker.Indel at 0x11974e4a8>,
#                 <gap_checker.Indel at 0x11974e550>],
#                'N10_sequence44': [],
#                'N12_sequence36': [],
#                'N12_N13': [],
#                'N19_N20': [],
#                'N19_sequence22': [],
#                'N45_sequence25': [<gap_checker.Indel at 0x11974e630>],
#                'N45_sequence14': [],
#                'N11_sequence31': [],
#                'N11_sequence11': [],
#                'N13_sequence24': [],
#                'N13_sequence50': [],
#                'N20_sequence41': [],
#                'N20_sequence19': []}},
#              'PSML': {'10': {'N0_N1': [],
#                'N0_sequence5': [<gap_checker.Indel at 0x119199780>,
#                 <gap_checker.Indel at 0x119194ef0>,
#                 <gap_checker.Indel at 0x119194e10>,
#                 <gap_checker.Indel at 0x119194e48>,
#                 <gap_checker.Indel at 0x119194c50>],
#                'N1_sequence3': [<gap_checker.Indel at 0x119194cc0>,
#                 <gap_checker.Indel at 0x119194cf8>,
#                 <gap_checker.Indel at 0x119194d30>],
#                'N1_N2': [],
#                'N2_N3': [],
#                'N2_N7': [],
#                'N3_N4': [<gap_checker.Indel at 0x119194b38>],
#                'N3_N5': [],
#                'N7_sequence8': [<gap_checker.Indel at 0x119194a58>,
#                 <gap_checker.Indel at 0x119194b00>,
#                 <gap_checker.Indel at 0x119194908>],
#                'N7_N8': [<gap_checker.Indel at 0x119194978>],
#                'N4_sequence4': [],
#                'N4_sequence6': [<gap_checker.Indel at 0x1191949b0>],
#                'N5_sequence7': [],
#                'N5_N6': [],
#                'N8_sequence10': [],
#                'N8_sequence9': [],
#                'N6_sequence2': [],
#                'N6_sequence1': []},
#               '20': {'N0_N1': [],
#                'N0_N17': [<gap_checker.Indel at 0x1191998d0>,
#                 <gap_checker.Indel at 0x11923c550>,
#                 <gap_checker.Indel at 0x11923c588>,
#                 <gap_checker.Indel at 0x11923c5f8>,
#                 <gap_checker.Indel at 0x11923c668>,
#                 <gap_checker.Indel at 0x11923c6a0>],
#                'N1_N2': [],
#                'N1_N3': [],
#                'N17_N18': [],
#                'N17_sequence3': [<gap_checker.Indel at 0x11923c7b8>,
#                 <gap_checker.Indel at 0x11923c7f0>],
#                'N2_sequence12': [<gap_checker.Indel at 0x11923c828>,
#                 <gap_checker.Indel at 0x11923c898>,
#                 <gap_checker.Indel at 0x11923c8d0>,
#                 <gap_checker.Indel at 0x11923c908>,
#                 <gap_checker.Indel at 0x11923c978>],
#                'N2_sequence8': [<gap_checker.Indel at 0x11923c9b0>,
#                 <gap_checker.Indel at 0x11923c9e8>,
#                 <gap_checker.Indel at 0x11923ca20>,
#                 <gap_checker.Indel at 0x11923ca58>,
#                 <gap_checker.Indel at 0x11923cac8>,
#                 <gap_checker.Indel at 0x11923cb38>,
#                 <gap_checker.Indel at 0x11923cb70>],
#                'N3_N4': [],
#                'N3_N11': [<gap_checker.Indel at 0x11923cc18>,
#                 <gap_checker.Indel at 0x11923cc50>,
#                 <gap_checker.Indel at 0x11923cc88>],
#                'N18_sequence9': [],
#                'N18_sequence18': [],
#                'N4_N5': [<gap_checker.Indel at 0x11923ccf8>,
#                 <gap_checker.Indel at 0x11923cd68>],
#                'N4_N8': [<gap_checker.Indel at 0x11923ce10>],
#                'N11_N12': [],
#                'N11_sequence5': [<gap_checker.Indel at 0x11923ceb8>,
#                 <gap_checker.Indel at 0x11923cef0>,
#                 <gap_checker.Indel at 0x11923cf28>,
#                 <gap_checker.Indel at 0x11923cf98>],
#                'N5_sequence6': [<gap_checker.Indel at 0x119244048>,
#                 <gap_checker.Indel at 0x119244080>,
#                 <gap_checker.Indel at 0x1192440f0>,
#                 <gap_checker.Indel at 0x119244160>],
#                'N5_N6': [],
#                'N8_sequence14': [],
#                'N8_N9': [<gap_checker.Indel at 0x119244278>,
#                 <gap_checker.Indel at 0x1192442b0>,
#                 <gap_checker.Indel at 0x119244358>],
#                'N12_sequence13': [<gap_checker.Indel at 0x119244390>,
#                 <gap_checker.Indel at 0x119244400>,
#                 <gap_checker.Indel at 0x119244438>,
#                 <gap_checker.Indel at 0x119244470>,
#                 <gap_checker.Indel at 0x1192444a8>],
#                'N12_N13': [],
#                'N6_sequence15': [<gap_checker.Indel at 0x119244550>,
#                 <gap_checker.Indel at 0x1192445c0>],
#                'N6_N7': [],
#                'N9_sequence16': [<gap_checker.Indel at 0x119244668>],
#                'N9_N10': [],
#                'N13_N14': [],
#                'N13_sequence10': [],
#                'N7_sequence1': [<gap_checker.Indel at 0x119244710>],
#                'N7_sequence17': [<gap_checker.Indel at 0x119244748>],
#                'N10_sequence4': [<gap_checker.Indel at 0x119244780>],
#                'N10_sequence2': [],
#                'N14_sequence7': [<gap_checker.Indel at 0x1192447b8>],
#                'N14_N15': [],
#                'N15_sequence11': [<gap_checker.Indel at 0x119244828>,
#                 <gap_checker.Indel at 0x119244860>],
#                'N15_N16': [],
#                'N16_sequence19': [],
#                'N16_sequence20': []},
#               '30': {'N0_N1': [],
#                'N0_N13': [],
#                'N1_N2': [<gap_checker.Indel at 0x119672358>],
#                'N1_sequence23': [<gap_checker.Indel at 0x11967df28>,
#                 <gap_checker.Indel at 0x11967dfd0>],
#                'N13_N14': [<gap_checker.Indel at 0x119684080>,
#                 <gap_checker.Indel at 0x1196840f0>],
#                'N13_N15': [],
#                'N2_N3': [<gap_checker.Indel at 0x119684198>],
#                'N2_N8': [],
#                'N14_sequence20': [<gap_checker.Indel at 0x119684208>],
#                'N14_sequence17': [],
#                'N15_N16': [],
#                'N15_sequence11': [<gap_checker.Indel at 0x119684278>,
#                 <gap_checker.Indel at 0x1196842b0>],
#                'N3_N4': [],
#                'N3_sequence16': [<gap_checker.Indel at 0x119684358>,
#                 <gap_checker.Indel at 0x119684390>],
#                'N8_N9': [],
#                'N8_N10': [],
#                'N16_N17': [],
#                'N16_N21': [],
#                'N4_N5': [],
#                'N4_sequence19': [<gap_checker.Indel at 0x119684518>,
#                 <gap_checker.Indel at 0x119684550>,
#                 <gap_checker.Indel at 0x1196845c0>],
#                'N9_sequence28': [],
#                'N9_sequence30': [],
#                'N10_sequence22': [<gap_checker.Indel at 0x119684630>],
#                'N10_N11': [],
#                'N17_N18': [<gap_checker.Indel at 0x1196846d8>],
#                'N17_N19': [<gap_checker.Indel at 0x119684748>],
#                'N21_N22': [<gap_checker.Indel at 0x1196847f0>,
#                 <gap_checker.Indel at 0x119684860>,
#                 <gap_checker.Indel at 0x1196848d0>,
#                 <gap_checker.Indel at 0x119684908>,
#                 <gap_checker.Indel at 0x119684978>],
#                'N21_N24': [<gap_checker.Indel at 0x119684a20>,
#                 <gap_checker.Indel at 0x119684a90>],
#                'N5_sequence24': [<gap_checker.Indel at 0x119684b00>],
#                'N5_N6': [<gap_checker.Indel at 0x119684be0>],
#                'N11_sequence25': [],
#                'N11_N12': [],
#                'N18_sequence18': [<gap_checker.Indel at 0x119684c50>],
#                'N18_sequence29': [],
#                'N19_N20': [],
#                'N19_sequence10': [<gap_checker.Indel at 0x119684cc0>],
#                'N22_sequence7': [<gap_checker.Indel at 0x119684d30>,
#                 <gap_checker.Indel at 0x119684d68>,
#                 <gap_checker.Indel at 0x119684da0>],
#                'N22_N23': [],
#                'N24_N25': [<gap_checker.Indel at 0x119684e48>],
#                'N24_N27': [],
#                'N6_N7': [],
#                'N6_sequence5': [],
#                'N12_sequence6': [],
#                'N12_sequence3': [],
#                'N20_sequence21': [<gap_checker.Indel at 0x119684ef0>],
#                'N20_sequence9': [<gap_checker.Indel at 0x119684f60>,
#                 <gap_checker.Indel at 0x119684f98>],
#                'N23_sequence13': [<gap_checker.Indel at 0x119684fd0>],
#                'N23_sequence8': [<gap_checker.Indel at 0x119689048>,
#                 <gap_checker.Indel at 0x1196890b8>],
#                'N25_N26': [],
#                'N25_sequence12': [<gap_checker.Indel at 0x119689160>,
#                 <gap_checker.Indel at 0x119689198>,
#                 <gap_checker.Indel at 0x1196891d0>],
#                'N27_N28': [<gap_checker.Indel at 0x119689278>],
#                'N27_sequence27': [<gap_checker.Indel at 0x1196892b0>,
#                 <gap_checker.Indel at 0x119689358>,
#                 <gap_checker.Indel at 0x119689390>],
#                'N7_sequence14': [],
#                'N7_sequence26': [],
#                'N26_sequence2': [<gap_checker.Indel at 0x1196893c8>,
#                 <gap_checker.Indel at 0x119689438>],
#                'N26_sequence15': [],
#                'N28_sequence1': [<gap_checker.Indel at 0x119689470>,
#                 <gap_checker.Indel at 0x1196894e0>,
#                 <gap_checker.Indel at 0x119689518>],
#                'N28_sequence4': [<gap_checker.Indel at 0x119689550>]},
#               '40': {'N0_N1': [],
#                'N0_N17': [],
#                'N1_N2': [],
#                'N1_N14': [<gap_checker.Indel at 0x1196cbbe0>],
#                'N17_sequence17': [<gap_checker.Indel at 0x1196d46d8>,
#                 <gap_checker.Indel at 0x1196d4748>,
#                 <gap_checker.Indel at 0x1196d4780>],
#                'N17_N18': [],
#                'N2_N3': [],
#                'N2_N5': [],
#                'N14_sequence27': [<gap_checker.Indel at 0x1196d4860>,
#                 <gap_checker.Indel at 0x1196d48d0>],
#                'N14_N15': [<gap_checker.Indel at 0x1196d4978>],
#                'N18_N19': [<gap_checker.Indel at 0x1196d4a20>],
#                'N18_N27': [],
#                'N3_N4': [<gap_checker.Indel at 0x1196d4b38>],
#                'N3_sequence32': [<gap_checker.Indel at 0x1196d4ba8>,
#                 <gap_checker.Indel at 0x1196d4c18>,
#                 <gap_checker.Indel at 0x1196d4c88>,
#                 <gap_checker.Indel at 0x1196d4cc0>],
#                'N5_N6': [],
#                'N5_N10': [],
#                'N15_sequence34': [<gap_checker.Indel at 0x1196d4dd8>],
#                'N15_N16': [],
#                'N19_N20': [<gap_checker.Indel at 0x1196d4eb8>],
#                'N19_N21': [],
#                'N27_N28': [<gap_checker.Indel at 0x1196d4f60>],
#                'N27_N38': [<gap_checker.Indel at 0x1196d4fd0>,
#                 <gap_checker.Indel at 0x1196d7048>,
#                 <gap_checker.Indel at 0x1196d70b8>],
#                'N4_sequence5': [],
#                'N4_sequence13': [<gap_checker.Indel at 0x1196d7160>,
#                 <gap_checker.Indel at 0x1196d7198>,
#                 <gap_checker.Indel at 0x1196d71d0>],
#                'N6_N7': [<gap_checker.Indel at 0x1196d7240>],
#                'N6_N9': [<gap_checker.Indel at 0x1196d72e8>],
#                'N10_N11': [],
#                'N10_sequence23': [],
#                'N16_sequence25': [],
#                'N16_sequence7': [],
#                'N20_sequence29': [<gap_checker.Indel at 0x1196d7358>,
#                 <gap_checker.Indel at 0x1196d7400>],
#                'N20_sequence35': [],
#                'N21_N22': [],
#                'N21_N25': [],
#                'N28_N29': [],
#                'N28_N32': [],
#                'N38_sequence3': [<gap_checker.Indel at 0x1196d7518>],
#                'N38_sequence22': [<gap_checker.Indel at 0x1196d7550>],
#                'N7_N8': [],
#                'N7_sequence16': [],
#                'N9_sequence26': [<gap_checker.Indel at 0x1196d75f8>,
#                 <gap_checker.Indel at 0x1196d7630>,
#                 <gap_checker.Indel at 0x1196d7668>],
#                'N9_sequence9': [<gap_checker.Indel at 0x1196d76a0>],
#                'N11_N12': [],
#                'N11_sequence30': [<gap_checker.Indel at 0x1196d7710>],
#                'N22_sequence21': [<gap_checker.Indel at 0x1196d77b8>],
#                'N22_N23': [<gap_checker.Indel at 0x1196d7828>],
#                'N25_sequence15': [<gap_checker.Indel at 0x1196d7860>,
#                 <gap_checker.Indel at 0x1196d7898>],
#                'N25_N26': [<gap_checker.Indel at 0x1196d7940>],
#                'N29_N30': [],
#                'N29_N31': [<gap_checker.Indel at 0x1196d7a20>],
#                'N32_N33': [],
#                'N32_sequence18': [<gap_checker.Indel at 0x1196d7ac8>],
#                'N8_sequence31': [],
#                'N8_sequence14': [<gap_checker.Indel at 0x1196d7b38>,
#                 <gap_checker.Indel at 0x1196d7b70>,
#                 <gap_checker.Indel at 0x1196d7be0>],
#                'N12_N13': [],
#                'N12_sequence2': [],
#                'N23_sequence33': [<gap_checker.Indel at 0x1196d7c50>],
#                'N23_N24': [],
#                'N26_sequence1': [],
#                'N26_sequence6': [<gap_checker.Indel at 0x1196d7d30>],
#                'N30_sequence37': [],
#                'N30_sequence38': [],
#                'N31_sequence10': [<gap_checker.Indel at 0x1196d7d68>],
#                'N31_sequence12': [],
#                'N33_N34': [],
#                'N33_N35': [],
#                'N13_sequence24': [],
#                'N13_sequence39': [],
#                'N24_sequence8': [],
#                'N24_sequence4': [],
#                'N34_sequence40': [<gap_checker.Indel at 0x1196d7e10>],
#                'N34_sequence11': [],
#                'N35_N36': [],
#                'N35_sequence20': [<gap_checker.Indel at 0x1196d7eb8>],
#                'N36_sequence28': [],
#                'N36_N37': [],
#                'N37_sequence19': [],
#                'N37_sequence36': []},
#               '50': {'N0_N1': [<gap_checker.Indel at 0x1197460b8>],
#                'N0_N3': [],
#                'N1_N2': [],
#                'N1_sequence30': [],
#                'N3_N4': [],
#                'N3_N27': [<gap_checker.Indel at 0x11974e860>],
#                'N2_sequence13': [<gap_checker.Indel at 0x11974e8d0>],
#                'N2_sequence16': [],
#                'N4_N5': [],
#                'N4_N21': [],
#                'N27_N28': [],
#                'N27_N37': [],
#                'N5_sequence2': [<gap_checker.Indel at 0x11974e9e8>,
#                 <gap_checker.Indel at 0x11974ea90>,
#                 <gap_checker.Indel at 0x11974eb00>,
#                 <gap_checker.Indel at 0x11974eb70>,
#                 <gap_checker.Indel at 0x11974ebe0>,
#                 <gap_checker.Indel at 0x11974ec50>],
#                'N5_N6': [],
#                'N21_N22': [<gap_checker.Indel at 0x11974ecf8>,
#                 <gap_checker.Indel at 0x11974ed30>,
#                 <gap_checker.Indel at 0x11974ed68>,
#                 <gap_checker.Indel at 0x11974eda0>,
#                 <gap_checker.Indel at 0x11974edd8>],
#                'N21_N26': [<gap_checker.Indel at 0x11974ee48>,
#                 <gap_checker.Indel at 0x11974eeb8>,
#                 <gap_checker.Indel at 0x11974eef0>],
#                'N28_N29': [<gap_checker.Indel at 0x11974ef60>],
#                'N28_N35': [],
#                'N37_N38': [<gap_checker.Indel at 0x119750048>],
#                'N37_N47': [<gap_checker.Indel at 0x1197500f0>,
#                 <gap_checker.Indel at 0x119750128>],
#                'N6_N7': [<gap_checker.Indel at 0x1197501d0>],
#                'N6_N15': [],
#                'N22_sequence26': [<gap_checker.Indel at 0x119750240>],
#                'N22_N23': [],
#                'N26_sequence43': [<gap_checker.Indel at 0x1197502b0>,
#                 <gap_checker.Indel at 0x1197502e8>,
#                 <gap_checker.Indel at 0x119750358>,
#                 <gap_checker.Indel at 0x119750390>],
#                'N26_sequence48': [<gap_checker.Indel at 0x119750400>,
#                 <gap_checker.Indel at 0x119750470>,
#                 <gap_checker.Indel at 0x1197504e0>],
#                'N29_N30': [],
#                'N29_N31': [],
#                'N35_N36': [],
#                'N35_sequence37': [<gap_checker.Indel at 0x1197505c0>,
#                 <gap_checker.Indel at 0x119750630>,
#                 <gap_checker.Indel at 0x119750668>],
#                'N38_N39': [],
#                'N38_N40': [],
#                'N47_N48': [],
#                'N47_sequence34': [<gap_checker.Indel at 0x119750780>],
#                'N7_N8': [],
#                'N7_sequence20': [<gap_checker.Indel at 0x1197507f0>,
#                 <gap_checker.Indel at 0x119750828>],
#                'N15_N16': [],
#                'N15_N17': [<gap_checker.Indel at 0x1197508d0>,
#                 <gap_checker.Indel at 0x119750908>],
#                'N23_N24': [],
#                'N23_N25': [<gap_checker.Indel at 0x1197509e8>],
#                'N30_sequence18': [<gap_checker.Indel at 0x119750a58>,
#                 <gap_checker.Indel at 0x119750a90>,
#                 <gap_checker.Indel at 0x119750b00>,
#                 <gap_checker.Indel at 0x119750b70>],
#                'N30_sequence40': [<gap_checker.Indel at 0x119750c18>,
#                 <gap_checker.Indel at 0x119750c50>],
#                'N31_N32': [<gap_checker.Indel at 0x119750d30>],
#                'N31_N34': [<gap_checker.Indel at 0x119750da0>,
#                 <gap_checker.Indel at 0x119750dd8>,
#                 <gap_checker.Indel at 0x119750e48>,
#                 <gap_checker.Indel at 0x119750e80>,
#                 <gap_checker.Indel at 0x119750ef0>],
#                'N36_sequence38': [<gap_checker.Indel at 0x119750f60>],
#                'N36_sequence17': [<gap_checker.Indel at 0x119753048>,
#                 <gap_checker.Indel at 0x119753080>],
#                'N39_sequence33': [],
#                'N39_sequence27': [<gap_checker.Indel at 0x1197530b8>],
#                'N40_N41': [],
#                'N40_N43': [],
#                'N48_sequence10': [],
#                'N48_sequence5': [],
#                'N8_N9': [],
#                'N8_N14': [<gap_checker.Indel at 0x119753240>,
#                 <gap_checker.Indel at 0x1197532b0>,
#                 <gap_checker.Indel at 0x1197532e8>],
#                'N16_sequence15': [<gap_checker.Indel at 0x119753358>,
#                 <gap_checker.Indel at 0x119753390>,
#                 <gap_checker.Indel at 0x119753438>,
#                 <gap_checker.Indel at 0x1197534a8>,
#                 <gap_checker.Indel at 0x1197534e0>,
#                 <gap_checker.Indel at 0x119753550>],
#                'N16_sequence45': [<gap_checker.Indel at 0x1197535c0>],
#                'N17_N18': [],
#                'N17_sequence21': [<gap_checker.Indel at 0x1197536a0>,
#                 <gap_checker.Indel at 0x119753710>],
#                'N24_sequence28': [<gap_checker.Indel at 0x119753780>],
#                'N24_sequence6': [<gap_checker.Indel at 0x1197537f0>,
#                 <gap_checker.Indel at 0x119753828>,
#                 <gap_checker.Indel at 0x119753898>],
#                'N25_sequence32': [<gap_checker.Indel at 0x1197538d0>],
#                'N25_sequence9': [],
#                'N32_N33': [],
#                'N32_sequence49': [<gap_checker.Indel at 0x119753978>],
#                'N34_sequence3': [<gap_checker.Indel at 0x1197539b0>],
#                'N34_sequence29': [],
#                'N41_sequence23': [<gap_checker.Indel at 0x119753a20>,
#                 <gap_checker.Indel at 0x119753a90>,
#                 <gap_checker.Indel at 0x119753ac8>,
#                 <gap_checker.Indel at 0x119753b38>],
#                'N41_N42': [<gap_checker.Indel at 0x119753c18>],
#                'N43_N44': [],
#                'N43_N46': [<gap_checker.Indel at 0x119753cc0>,
#                 <gap_checker.Indel at 0x119753d30>,
#                 <gap_checker.Indel at 0x119753da0>],
#                'N9_N10': [<gap_checker.Indel at 0x119753e10>],
#                'N9_N12': [<gap_checker.Indel at 0x119753eb8>,
#                 <gap_checker.Indel at 0x119753ef0>],
#                'N14_sequence46': [],
#                'N14_sequence47': [],
#                'N18_N19': [<gap_checker.Indel at 0x119753f98>,
#                 <gap_checker.Indel at 0x119753fd0>],
#                'N18_sequence8': [],
#                'N33_sequence42': [],
#                'N33_sequence4': [],
#                'N42_sequence39': [],
#                'N42_sequence35': [<gap_checker.Indel at 0x11975c080>],
#                'N44_sequence12': [<gap_checker.Indel at 0x11975c0b8>],
#                'N44_N45': [<gap_checker.Indel at 0x11975c160>,
#                 <gap_checker.Indel at 0x11975c198>],
#                'N46_sequence1': [],
#                'N46_sequence7': [<gap_checker.Indel at 0x11975c1d0>,
#                 <gap_checker.Indel at 0x11975c208>,
#                 <gap_checker.Indel at 0x11975c278>],
#                'N10_N11': [<gap_checker.Indel at 0x11975c320>,
#                 <gap_checker.Indel at 0x11975c3c8>],
#                'N10_sequence44': [],
#                'N12_sequence36': [],
#                'N12_N13': [],
#                'N19_N20': [],
#                'N19_sequence22': [],
#                'N45_sequence25': [<gap_checker.Indel at 0x11975c4a8>],
#                'N45_sequence14': [],
#                'N11_sequence31': [],
#                'N11_sequence11': [],
#                'N13_sequence24': [],
#                'N13_sequence50': [],
#                'N20_sequence41': [],
#                'N20_sequence19': []}},
#              'SICP': {'10': {'N0_N1': [],
#                'N0_sequence5': [<gap_checker.Indel at 0x1191996a0>,
#                 <gap_checker.Indel at 0x119194898>,
#                 <gap_checker.Indel at 0x1191947b8>,
#                 <gap_checker.Indel at 0x1191946d8>,
#                 <gap_checker.Indel at 0x119194710>],
#                'N1_sequence3': [<gap_checker.Indel at 0x1191946a0>,
#                 <gap_checker.Indel at 0x119194668>,
#                 <gap_checker.Indel at 0x119194630>],
#                'N1_N2': [],
#                'N2_N3': [],
#                'N2_N7': [],
#                'N3_N4': [<gap_checker.Indel at 0x119194470>],
#                'N3_N5': [],
#                'N7_sequence8': [<gap_checker.Indel at 0x1191944a8>,
#                 <gap_checker.Indel at 0x119194550>,
#                 <gap_checker.Indel at 0x119194240>],
#                'N7_N8': [<gap_checker.Indel at 0x1191942b0>],
#                'N4_sequence4': [],
#                'N4_sequence6': [<gap_checker.Indel at 0x1191942e8>],
#                'N5_sequence7': [],
#                'N5_N6': [],
#                'N8_sequence10': [],
#                'N8_sequence9': [],
#                'N6_sequence2': [],
#                'N6_sequence1': []},
#               '20': {'N0_N1': [],
#                'N0_N17': [<gap_checker.Indel at 0x119199630>,
#                 <gap_checker.Indel at 0x1192449b0>,
#                 <gap_checker.Indel at 0x1192449e8>,
#                 <gap_checker.Indel at 0x119244a58>,
#                 <gap_checker.Indel at 0x119244ac8>,
#                 <gap_checker.Indel at 0x119244b00>],
#                'N1_N2': [<gap_checker.Indel at 0x119244ba8>,
#                 <gap_checker.Indel at 0x119244be0>,
#                 <gap_checker.Indel at 0x119244c18>,
#                 <gap_checker.Indel at 0x119244c88>],
#                'N1_N3': [],
#                'N17_N18': [],
#                'N17_sequence3': [<gap_checker.Indel at 0x119244d68>,
#                 <gap_checker.Indel at 0x119244da0>],
#                'N2_sequence12': [<gap_checker.Indel at 0x119244dd8>],
#                'N2_sequence8': [<gap_checker.Indel at 0x119244e48>,
#                 <gap_checker.Indel at 0x119244e80>,
#                 <gap_checker.Indel at 0x119244ef0>],
#                'N3_N4': [<gap_checker.Indel at 0x119244f60>],
#                'N3_N11': [<gap_checker.Indel at 0x119248048>,
#                 <gap_checker.Indel at 0x119248080>],
#                'N18_sequence9': [],
#                'N18_sequence18': [],
#                'N4_N5': [<gap_checker.Indel at 0x1192480f0>],
#                'N4_N8': [],
#                'N11_N12': [],
#                'N11_sequence5': [<gap_checker.Indel at 0x1192481d0>,
#                 <gap_checker.Indel at 0x119248208>,
#                 <gap_checker.Indel at 0x119248240>],
#                'N5_sequence6': [<gap_checker.Indel at 0x1192482b0>,
#                 <gap_checker.Indel at 0x1192482e8>,
#                 <gap_checker.Indel at 0x119248358>,
#                 <gap_checker.Indel at 0x1192483c8>],
#                'N5_N6': [],
#                'N8_sequence14': [],
#                'N8_N9': [<gap_checker.Indel at 0x1192484e0>,
#                 <gap_checker.Indel at 0x119248518>,
#                 <gap_checker.Indel at 0x1192485c0>],
#                'N12_sequence13': [<gap_checker.Indel at 0x1192485f8>,
#                 <gap_checker.Indel at 0x119248668>,
#                 <gap_checker.Indel at 0x1192486a0>,
#                 <gap_checker.Indel at 0x1192486d8>],
#                'N12_N13': [<gap_checker.Indel at 0x1192487b8>],
#                'N6_sequence15': [<gap_checker.Indel at 0x1192487f0>,
#                 <gap_checker.Indel at 0x119248860>],
#                'N6_N7': [],
#                'N9_sequence16': [<gap_checker.Indel at 0x119248908>],
#                'N9_N10': [],
#                'N13_N14': [],
#                'N13_sequence10': [],
#                'N7_sequence1': [<gap_checker.Indel at 0x1192489b0>],
#                'N7_sequence17': [<gap_checker.Indel at 0x1192489e8>],
#                'N10_sequence4': [<gap_checker.Indel at 0x119248a20>],
#                'N10_sequence2': [],
#                'N14_sequence7': [<gap_checker.Indel at 0x119248a58>],
#                'N14_N15': [],
#                'N15_sequence11': [<gap_checker.Indel at 0x119248ac8>,
#                 <gap_checker.Indel at 0x119248b00>],
#                'N15_N16': [],
#                'N16_sequence19': [],
#                'N16_sequence20': []},
#               '30': {'N0_N1': [],
#                'N0_N13': [],
#                'N1_N2': [<gap_checker.Indel at 0x119675668>],
#                'N1_sequence23': [<gap_checker.Indel at 0x1196896a0>,
#                 <gap_checker.Indel at 0x119689748>],
#                'N13_N14': [<gap_checker.Indel at 0x1196897b8>,
#                 <gap_checker.Indel at 0x119689828>],
#                'N13_N15': [],
#                'N2_N3': [<gap_checker.Indel at 0x1196898d0>],
#                'N2_N8': [],
#                'N14_sequence20': [<gap_checker.Indel at 0x119689940>],
#                'N14_sequence17': [],
#                'N15_N16': [],
#                'N15_sequence11': [<gap_checker.Indel at 0x1196899b0>,
#                 <gap_checker.Indel at 0x1196899e8>],
#                'N3_N4': [],
#                'N3_sequence16': [<gap_checker.Indel at 0x119689a90>,
#                 <gap_checker.Indel at 0x119689ac8>],
#                'N8_N9': [],
#                'N8_N10': [],
#                'N16_N17': [],
#                'N16_N21': [<gap_checker.Indel at 0x119689c18>,
#                 <gap_checker.Indel at 0x119689c88>],
#                'N4_N5': [],
#                'N4_sequence19': [<gap_checker.Indel at 0x119689d30>,
#                 <gap_checker.Indel at 0x119689d68>,
#                 <gap_checker.Indel at 0x119689dd8>],
#                'N9_sequence28': [],
#                'N9_sequence30': [],
#                'N10_sequence22': [<gap_checker.Indel at 0x119689e48>],
#                'N10_N11': [],
#                'N17_N18': [<gap_checker.Indel at 0x119689ef0>],
#                'N17_N19': [],
#                'N21_N22': [<gap_checker.Indel at 0x119689f98>,
#                 <gap_checker.Indel at 0x11968f048>,
#                 <gap_checker.Indel at 0x11968f0b8>],
#                'N21_N24': [],
#                'N5_sequence24': [<gap_checker.Indel at 0x11968f128>],
#                'N5_N6': [<gap_checker.Indel at 0x11968f208>],
#                'N11_sequence25': [],
#                'N11_N12': [],
#                'N18_sequence18': [<gap_checker.Indel at 0x11968f278>],
#                'N18_sequence29': [],
#                'N19_N20': [<gap_checker.Indel at 0x11968f2e8>],
#                'N19_sequence10': [],
#                'N22_sequence7': [<gap_checker.Indel at 0x11968f358>,
#                 <gap_checker.Indel at 0x11968f390>,
#                 <gap_checker.Indel at 0x11968f3c8>],
#                'N22_N23': [],
#                'N24_N25': [],
#                'N24_N27': [],
#                'N6_N7': [],
#                'N6_sequence5': [],
#                'N12_sequence6': [],
#                'N12_sequence3': [],
#                'N20_sequence21': [<gap_checker.Indel at 0x11968f4e0>],
# ...
#                'N14_N15': [],
#                'N15_sequence11': [<gap_checker.Indel at 0x1196797b8>,
#                 <gap_checker.Indel at 0x1196797f0>],
#                'N15_N16': [],
#                'N16_sequence19': [],
#                'N16_sequence20': []},
#               '30': {'N0_N1': [],
#                'N0_N13': [],
#                'N1_N2': [<gap_checker.Indel at 0x1196bf400>],
#                'N1_sequence23': [<gap_checker.Indel at 0x1196c96d8>,
#                 <gap_checker.Indel at 0x1196c9780>],
#                'N13_N14': [<gap_checker.Indel at 0x1196c97f0>,
#                 <gap_checker.Indel at 0x1196c9860>],
#                'N13_N15': [],
#                'N2_N3': [<gap_checker.Indel at 0x1196c9908>],
#                'N2_N8': [],
#                'N14_sequence20': [<gap_checker.Indel at 0x1196c9978>],
#                'N14_sequence17': [],
#                'N15_N16': [],
#                'N15_sequence11': [<gap_checker.Indel at 0x1196c99e8>,
#                 <gap_checker.Indel at 0x1196c9a20>],
#                'N3_N4': [],
#                'N3_sequence16': [<gap_checker.Indel at 0x1196c9ac8>,
#                 <gap_checker.Indel at 0x1196c9b00>],
#                'N8_N9': [],
#                'N8_N10': [],
#                'N16_N17': [],
#                'N16_N21': [<gap_checker.Indel at 0x1196c9c50>,
#                 <gap_checker.Indel at 0x1196c9cc0>],
#                'N4_N5': [],
#                'N4_sequence19': [<gap_checker.Indel at 0x1196c9d68>,
#                 <gap_checker.Indel at 0x1196c9da0>,
#                 <gap_checker.Indel at 0x1196c9e10>],
#                'N9_sequence28': [],
#                'N9_sequence30': [],
#                'N10_sequence22': [<gap_checker.Indel at 0x1196c9e80>],
#                'N10_N11': [],
#                'N17_N18': [<gap_checker.Indel at 0x1196c9f28>],
#                'N17_N19': [],
#                'N21_N22': [<gap_checker.Indel at 0x1196c9fd0>,
#                 <gap_checker.Indel at 0x1196cb080>,
#                 <gap_checker.Indel at 0x1196cb0f0>],
#                'N21_N24': [],
#                'N5_sequence24': [<gap_checker.Indel at 0x1196cb160>],
#                'N5_N6': [<gap_checker.Indel at 0x1196cb240>],
#                'N11_sequence25': [],
#                'N11_N12': [],
#                'N18_sequence18': [<gap_checker.Indel at 0x1196cb2b0>],
#                'N18_sequence29': [],
#                'N19_N20': [],
#                'N19_sequence10': [],
#                'N22_sequence7': [<gap_checker.Indel at 0x1196cb320>,
#                 <gap_checker.Indel at 0x1196cb358>,
#                 <gap_checker.Indel at 0x1196cb390>],
#                'N22_N23': [],
#                'N24_N25': [],
#                'N24_N27': [],
#                'N6_N7': [],
#                'N6_sequence5': [],
#                'N12_sequence6': [],
#                'N12_sequence3': [],
#                'N20_sequence21': [<gap_checker.Indel at 0x1196cb4a8>],
#                'N20_sequence9': [<gap_checker.Indel at 0x1196cb550>,
#                 <gap_checker.Indel at 0x1196cb588>,
#                 <gap_checker.Indel at 0x1196cb5c0>],
#                'N23_sequence13': [<gap_checker.Indel at 0x1196cb630>],
#                'N23_sequence8': [<gap_checker.Indel at 0x1196cb668>,
#                 <gap_checker.Indel at 0x1196cb6d8>],
#                'N25_N26': [],
#                'N25_sequence12': [<gap_checker.Indel at 0x1196cb780>,
#                 <gap_checker.Indel at 0x1196cb7b8>,
#                 <gap_checker.Indel at 0x1196cb7f0>],
#                'N27_N28': [<gap_checker.Indel at 0x1196cb898>,
#                 <gap_checker.Indel at 0x1196cb8d0>],
#                'N27_sequence27': [<gap_checker.Indel at 0x1196cb908>,
#                 <gap_checker.Indel at 0x1196cb9b0>],
#                'N7_sequence14': [],
#                'N7_sequence26': [],
#                'N26_sequence2': [<gap_checker.Indel at 0x1196cb9e8>,
#                 <gap_checker.Indel at 0x1196cba58>],
#                'N26_sequence15': [],
#                'N28_sequence1': [<gap_checker.Indel at 0x1196cba90>,
#                 <gap_checker.Indel at 0x1196cbb00>,
#                 <gap_checker.Indel at 0x1196cbb38>],
#                'N28_sequence4': [<gap_checker.Indel at 0x1196cbb70>]},
#               '40': {'N0_N1': [],
#                'N0_N17': [],
#                'N1_N2': [],
#                'N1_N14': [<gap_checker.Indel at 0x1197416d8>],
#                'N17_sequence17': [<gap_checker.Indel at 0x1197461d0>,
#                 <gap_checker.Indel at 0x119746240>,
#                 <gap_checker.Indel at 0x119746278>],
#                'N17_N18': [],
#                'N2_N3': [<gap_checker.Indel at 0x119746320>],
#                'N2_N5': [],
#                'N14_sequence27': [<gap_checker.Indel at 0x1197463c8>,
#                 <gap_checker.Indel at 0x119746438>],
#                'N14_N15': [<gap_checker.Indel at 0x1197464e0>],
#                'N18_N19': [<gap_checker.Indel at 0x119746588>],
#                'N18_N27': [],
#                'N3_N4': [],
#                'N3_sequence32': [<gap_checker.Indel at 0x1197466a0>,
#                 <gap_checker.Indel at 0x119746710>,
#                 <gap_checker.Indel at 0x119746748>],
#                'N5_N6': [],
#                'N5_N10': [],
#                'N15_sequence34': [<gap_checker.Indel at 0x119746828>],
#                'N15_N16': [],
#                'N19_N20': [<gap_checker.Indel at 0x119746908>],
#                'N19_N21': [],
#                'N27_N28': [<gap_checker.Indel at 0x1197469b0>],
#                'N27_N38': [<gap_checker.Indel at 0x119746a20>,
#                 <gap_checker.Indel at 0x119746a58>,
#                 <gap_checker.Indel at 0x119746ac8>],
#                'N4_sequence5': [],
#                'N4_sequence13': [<gap_checker.Indel at 0x119746b70>,
#                 <gap_checker.Indel at 0x119746ba8>,
#                 <gap_checker.Indel at 0x119746be0>],
#                'N6_N7': [<gap_checker.Indel at 0x119746c50>],
#                'N6_N9': [<gap_checker.Indel at 0x119746cf8>],
#                'N10_N11': [],
#                'N10_sequence23': [],
#                'N16_sequence25': [],
#                'N16_sequence7': [],
#                'N20_sequence29': [<gap_checker.Indel at 0x119746d68>,
#                 <gap_checker.Indel at 0x119746e10>],
#                'N20_sequence35': [],
#                'N21_N22': [],
#                'N21_N25': [],
#                'N28_N29': [],
#                'N28_N32': [],
#                'N38_sequence3': [<gap_checker.Indel at 0x119746f28>],
#                'N38_sequence22': [<gap_checker.Indel at 0x119746f60>],
#                'N7_N8': [],
#                'N7_sequence16': [],
#                'N9_sequence26': [<gap_checker.Indel at 0x119748048>,
#                 <gap_checker.Indel at 0x119748080>,
#                 <gap_checker.Indel at 0x1197480b8>],
#                'N9_sequence9': [<gap_checker.Indel at 0x1197480f0>],
#                'N11_N12': [],
#                'N11_sequence30': [<gap_checker.Indel at 0x119748160>],
#                'N22_sequence21': [<gap_checker.Indel at 0x119748208>],
#                'N22_N23': [<gap_checker.Indel at 0x119748278>],
#                'N25_sequence15': [<gap_checker.Indel at 0x1197482b0>,
#                 <gap_checker.Indel at 0x1197482e8>],
#                'N25_N26': [<gap_checker.Indel at 0x119748390>],
#                'N29_N30': [],
#                'N29_N31': [<gap_checker.Indel at 0x119748470>],
#                'N32_N33': [],
#                'N32_sequence18': [<gap_checker.Indel at 0x119748518>],
#                'N8_sequence31': [],
#                'N8_sequence14': [<gap_checker.Indel at 0x119748588>,
#                 <gap_checker.Indel at 0x1197485c0>,
#                 <gap_checker.Indel at 0x119748630>],
#                'N12_N13': [],
#                'N12_sequence2': [],
#                'N23_sequence33': [<gap_checker.Indel at 0x1197486a0>],
#                'N23_N24': [],
#                'N26_sequence1': [],
#                'N26_sequence6': [<gap_checker.Indel at 0x119748780>],
#                'N30_sequence37': [],
#                'N30_sequence38': [],
#                'N31_sequence10': [<gap_checker.Indel at 0x1197487b8>],
#                'N31_sequence12': [],
#                'N33_N34': [],
#                'N33_N35': [],
#                'N13_sequence24': [],
#                'N13_sequence39': [],
#                'N24_sequence8': [],
#                'N24_sequence4': [],
#                'N34_sequence40': [<gap_checker.Indel at 0x119748860>],
#                'N34_sequence11': [],
#                'N35_N36': [],
#                'N35_sequence20': [<gap_checker.Indel at 0x119748908>],
#                'N36_sequence28': [],
#                'N36_N37': [],
#                'N37_sequence19': [],
#                'N37_sequence36': []},
#               '50': {'N0_N1': [<gap_checker.Indel at 0x1191ed710>],
#                'N0_N3': [],
#                'N1_N2': [],
#                'N1_sequence30': [],
#                'N3_N4': [],
#                'N3_N27': [<gap_checker.Indel at 0x1197fc048>],
#                'N2_sequence13': [<gap_checker.Indel at 0x1197fc0b8>],
#                'N2_sequence16': [],
#                'N4_N5': [],
#                'N4_N21': [],
#                'N27_N28': [],
#                'N27_N37': [],
#                'N5_sequence2': [<gap_checker.Indel at 0x1197fc1d0>,
#                 <gap_checker.Indel at 0x1197fc278>,
#                 <gap_checker.Indel at 0x1197fc2e8>,
#                 <gap_checker.Indel at 0x1197fc358>,
#                 <gap_checker.Indel at 0x1197fc3c8>,
#                 <gap_checker.Indel at 0x1197fc438>],
#                'N5_N6': [],
#                'N21_N22': [<gap_checker.Indel at 0x1197fc4e0>,
#                 <gap_checker.Indel at 0x1197fc518>,
#                 <gap_checker.Indel at 0x1197fc550>,
#                 <gap_checker.Indel at 0x1197fc588>],
#                'N21_N26': [<gap_checker.Indel at 0x1197fc630>,
#                 <gap_checker.Indel at 0x1197fc6a0>,
#                 <gap_checker.Indel at 0x1197fc6d8>],
#                'N28_N29': [<gap_checker.Indel at 0x1197fc748>],
#                'N28_N35': [],
#                'N37_N38': [<gap_checker.Indel at 0x1197fc7f0>],
#                'N37_N47': [<gap_checker.Indel at 0x1197fc898>,
#                 <gap_checker.Indel at 0x1197fc8d0>],
#                'N6_N7': [<gap_checker.Indel at 0x1197fc978>],
#                'N6_N15': [],
#                'N22_sequence26': [],
#                'N22_N23': [<gap_checker.Indel at 0x1197fca20>],
#                'N26_sequence43': [<gap_checker.Indel at 0x1197fca58>,
#                 <gap_checker.Indel at 0x1197fca90>,
#                 <gap_checker.Indel at 0x1197fcb00>,
#                 <gap_checker.Indel at 0x1197fcb38>],
#                'N26_sequence48': [<gap_checker.Indel at 0x1197fcba8>,
#                 <gap_checker.Indel at 0x1197fcc18>,
#                 <gap_checker.Indel at 0x1197fcc88>],
#                'N29_N30': [],
#                'N29_N31': [],
#                'N35_N36': [],
#                'N35_sequence37': [<gap_checker.Indel at 0x1197fcd68>,
#                 <gap_checker.Indel at 0x1197fcdd8>,
#                 <gap_checker.Indel at 0x1197fce10>],
#                'N38_N39': [],
#                'N38_N40': [],
#                'N47_N48': [],
#                'N47_sequence34': [<gap_checker.Indel at 0x1197fcf28>],
#                'N7_N8': [],
#                'N7_sequence20': [<gap_checker.Indel at 0x1197fcf98>,
#                 <gap_checker.Indel at 0x1197fcfd0>],
#                'N15_N16': [],
#                'N15_N17': [<gap_checker.Indel at 0x1197ff0b8>],
#                'N23_N24': [],
#                'N23_N25': [<gap_checker.Indel at 0x1197ff160>],
#                'N30_sequence18': [<gap_checker.Indel at 0x1197ff1d0>,
#                 <gap_checker.Indel at 0x1197ff208>,
#                 <gap_checker.Indel at 0x1197ff278>,
#                 <gap_checker.Indel at 0x1197ff2e8>],
#                'N30_sequence40': [<gap_checker.Indel at 0x1197ff390>,
#                 <gap_checker.Indel at 0x1197ff3c8>],
#                'N31_N32': [<gap_checker.Indel at 0x1197ff4a8>],
#                'N31_N34': [<gap_checker.Indel at 0x1197ff518>,
#                 <gap_checker.Indel at 0x1197ff550>,
#                 <gap_checker.Indel at 0x1197ff5c0>,
#                 <gap_checker.Indel at 0x1197ff5f8>,
#                 <gap_checker.Indel at 0x1197ff668>],
#                'N36_sequence38': [<gap_checker.Indel at 0x1197ff6d8>],
#                'N36_sequence17': [<gap_checker.Indel at 0x1197ff780>,
#                 <gap_checker.Indel at 0x1197ff7b8>],
#                'N39_sequence33': [],
#                'N39_sequence27': [<gap_checker.Indel at 0x1197ff7f0>],
#                'N40_N41': [],
#                'N40_N43': [],
#                'N48_sequence10': [],
#                'N48_sequence5': [],
#                'N8_N9': [],
#                'N8_N14': [<gap_checker.Indel at 0x1197ff978>,
#                 <gap_checker.Indel at 0x1197ff9e8>,
#                 <gap_checker.Indel at 0x1197ffa20>],
#                'N16_sequence15': [<gap_checker.Indel at 0x1197ffa90>,
#                 <gap_checker.Indel at 0x1197ffac8>,
#                 <gap_checker.Indel at 0x1197ffb70>,
#                 <gap_checker.Indel at 0x1197ffbe0>,
#                 <gap_checker.Indel at 0x1197ffc18>,
#                 <gap_checker.Indel at 0x1197ffc88>],
#                'N16_sequence45': [<gap_checker.Indel at 0x1197ffcf8>],
#                'N17_N18': [<gap_checker.Indel at 0x1197ffdd8>],
#                'N17_sequence21': [<gap_checker.Indel at 0x1197ffe48>],
#                'N24_sequence28': [<gap_checker.Indel at 0x1197ffeb8>],
#                'N24_sequence6': [<gap_checker.Indel at 0x1197fff28>,
#                 <gap_checker.Indel at 0x1197fff60>,
#                 <gap_checker.Indel at 0x1197fffd0>],
#                'N25_sequence32': [<gap_checker.Indel at 0x119800048>],
#                'N25_sequence9': [],
#                'N32_N33': [],
#                'N32_sequence49': [<gap_checker.Indel at 0x1198000f0>],
#                'N34_sequence3': [<gap_checker.Indel at 0x119800128>],
#                'N34_sequence29': [],
#                'N41_sequence23': [<gap_checker.Indel at 0x119800198>,
#                 <gap_checker.Indel at 0x119800208>,
#                 <gap_checker.Indel at 0x119800240>,
#                 <gap_checker.Indel at 0x1198002b0>],
#                'N41_N42': [],
#                'N43_N44': [],
#                'N43_N46': [<gap_checker.Indel at 0x119800400>,
#                 <gap_checker.Indel at 0x119800470>,
#                 <gap_checker.Indel at 0x1198004e0>],
#                'N9_N10': [<gap_checker.Indel at 0x119800550>],
#                'N9_N12': [<gap_checker.Indel at 0x1198005f8>,
#                 <gap_checker.Indel at 0x119800630>],
#                'N14_sequence46': [],
#                'N14_sequence47': [],
#                'N18_N19': [<gap_checker.Indel at 0x1198006d8>,
#                 <gap_checker.Indel at 0x119800710>],
#                'N18_sequence8': [],
#                'N33_sequence42': [],
#                'N33_sequence4': [],
#                'N42_sequence39': [<gap_checker.Indel at 0x119800780>],
#                'N42_sequence35': [<gap_checker.Indel at 0x1198007b8>],
#                'N44_sequence12': [<gap_checker.Indel at 0x119800828>],
#                'N44_N45': [<gap_checker.Indel at 0x1198008d0>,
#                 <gap_checker.Indel at 0x119800908>],
#                'N46_sequence1': [],
#                'N46_sequence7': [<gap_checker.Indel at 0x119800940>,
#                 <gap_checker.Indel at 0x119800978>,
#                 <gap_checker.Indel at 0x1198009e8>],
#                'N10_N11': [<gap_checker.Indel at 0x119800a90>,
#                 <gap_checker.Indel at 0x119800b38>],
#                'N10_sequence44': [],
#                'N12_sequence36': [],
#                'N12_N13': [],
#                'N19_N20': [],
#                'N19_sequence22': [],
#                'N45_sequence25': [<gap_checker.Indel at 0x119800c18>],
#                'N45_sequence14': [],
#                'N11_sequence31': [],
#                'N11_sequence11': [],
#                'N13_sequence24': [],
#                'N13_sequence50': [],
#                'N20_sequence41': [],
#                'N20_sequence19': []}}})

# %%
def indel_present(indelible_branch, indelible_indel, method_gap_dict):
    for method_indel in method_gap_dict[branch]:
        if method_indel.category == indelible_indel.category and method_indel.start == indelible_indel.start and method_indel.end == indelible_indel.end:
            return True
        else:
            return False
    else:
        return False

with open (output_file, 'w+') as output:
    writer = csv.writer(output, delimiter=',', quotechar='\"', quoting=csv.QUOTE_MINIMAL)
    writer.writerow(['Taxa', 'Name', 'Category', 'Start', 'End', 'Terminal', 'Content', 'Gapped_Content', 'Width', 'Descendants', 'Root_Dist', 'Child_Extant'] + methods)

    for taxon in taxa:
        
        indelible_tree = ete3.Tree(f"./indelible_output/{taxon}/cleaned_N0_trees/1.nwk", format=1)
        with open(f'./output_dicts/{taxon}/gaps_indelible_1.p', 'rb') as handle:
            indelible_gap_dict = pickle.load(handle)


        for branch, indel_list in indelible_gap_dict.items():
            child_node = branch.split("_")[1]
            tree_node = indelible_tree&child_node
            descendants = len([x for x in tree_node.iter_descendants()])
            root_dist = tree_node.get_distance(indelible_tree.get_tree_root())
            child_extant = False
            for child in tree_node.children:
                if child.is_leaf():
                    child_extant = True

            for indel in indel_list:
                print (indel)
                method_presence = [indel_present(branch, indel, methods_dict[method][taxon]) for method in methods]
                print (method_presence)
                print (branch)
                print (branch.split("_")[1])
                
            
                
                writer.writerow([taxon, f'{branch}_{indel.start}_{indel.end}', indel.category, indel.start, indel.end, indel.terminal, indel.content, indel.gapped_content, indel.width, descendants, root_dist, child_extant] + method_presence)


                    
    "with open (output_file, 'w+') as output:\n",
    "    \n",
    "    writer = csv.writer(output, delimiter=',', quotechar='\"', quoting=csv.QUOTE_MINIMAL)\n",
    "    writer.writerow(['Name', 'Root', 'Type', 'Kingdom', 'Phylum', 'Class', 'Order', 'Family', 'Genus', 'Species', 'Extra'])\n",
# Out:
# <gap_checker.Indel object at 0x11982f9e8>
# [False, False, False, False, False, False, False, False]
# N0_N1
# N1
# <gap_checker.Indel object at 0x11982fc50>
# [True, True, True, False, True, True, True, True]
# N0_sequence5
# sequence5
# <gap_checker.Indel object at 0x11982fcc0>
# [False, False, False, False, False, False, False, False]
# N0_sequence5
# sequence5
# <gap_checker.Indel object at 0x11982fd30>
# [False, False, False, False, False, False, False, False]
# N0_sequence5
# sequence5
# <gap_checker.Indel object at 0x11982fd68>
# [False, False, False, False, False, False, False, False]
# N0_sequence5
# sequence5
# <gap_checker.Indel object at 0x11982fe10>
# [True, True, True, False, True, True, True, True]
# N1_sequence3
# sequence3
# <gap_checker.Indel object at 0x11982fe48>
# [False, False, False, False, False, False, False, False]
# N1_sequence3
# sequence3
# <gap_checker.Indel object at 0x11982fe80>
# [False, False, False, False, False, False, False, False]
# N1_sequence3
# sequence3
# <gap_checker.Indel object at 0x11982ff98>
# [True, True, True, False, True, True, True, True]
# N3_N4
# N4
# <gap_checker.Indel object at 0x119816048>
# [True, True, True, False, True, True, True, True]
# N7_sequence8
# sequence8
# <gap_checker.Indel object at 0x1198160f0>
# [False, False, False, True, False, False, False, False]
# N7_sequence8
# sequence8
# <gap_checker.Indel object at 0x119816160>
# [False, False, False, False, False, False, False, False]
# N7_sequence8
# sequence8
# <gap_checker.Indel object at 0x1198161d0>
# [True, True, True, False, True, True, True, True]
# N7_N8
# N8
# <gap_checker.Indel object at 0x119816208>
# [True, True, True, False, True, True, True, True]
# N4_sequence6
# sequence6
# <gap_checker.Indel object at 0x119234ba8>
# [True, True, True, False, True, True, True, True]
# N0_N17
# N17
# <gap_checker.Indel object at 0x1198169b0>
# [False, False, False, False, False, False, False, False]
# N0_N17
# N17
# <gap_checker.Indel object at 0x1198169e8>
# [False, False, False, False, False, False, False, False]
# N0_N17
# N17
# <gap_checker.Indel object at 0x119816a58>
# [False, False, False, False, False, False, False, False]
# N0_N17
# N17
# <gap_checker.Indel object at 0x119816ac8>
# [False, False, False, False, False, False, False, False]
# N0_N17
# N17
# <gap_checker.Indel object at 0x119816b00>
# [False, False, False, False, False, False, False, False]
# N0_N17
# N17
# <gap_checker.Indel object at 0x119816ba8>
# [True, False, True, False, True, True, True, True]
# N1_N2
# N2
# <gap_checker.Indel object at 0x119816be0>
# [False, False, False, False, False, False, False, False]
# N1_N2
# N2
# <gap_checker.Indel object at 0x119816c18>
# [False, False, False, False, False, False, False, False]
# N1_N2
# N2
# <gap_checker.Indel object at 0x119816c88>
# [False, False, False, False, False, False, False, False]
# N1_N2
# N2
# <gap_checker.Indel object at 0x119816d68>
# [True, True, True, True, True, True, True, True]
# N17_sequence3
# sequence3
# <gap_checker.Indel object at 0x119816da0>
# [False, False, False, False, False, False, False, False]
# N17_sequence3
# sequence3
# <gap_checker.Indel object at 0x119816dd8>
# [True, True, True, False, True, True, True, True]
# N2_sequence12
# sequence12
# <gap_checker.Indel object at 0x119816e48>
# [True, False, True, False, True, True, True, True]
# N2_sequence8
# sequence8
# <gap_checker.Indel object at 0x119816e80>
# [False, False, False, False, False, False, False, False]
# N2_sequence8
# sequence8
# <gap_checker.Indel object at 0x119816ef0>
# [False, False, False, False, False, False, False, False]
# N2_sequence8
# sequence8
# <gap_checker.Indel object at 0x119816f60>
# [False, False, True, False, True, False, True, True]
# N3_N4
# N4
# <gap_checker.Indel object at 0x119822048>
# [True, True, True, False, True, True, True, True]
# N3_N11
# N11
# <gap_checker.Indel object at 0x119822080>
# [False, False, False, False, False, False, False, False]
# N3_N11
# N11
# <gap_checker.Indel object at 0x1198220f0>
# [True, True, True, False, True, True, True, True]
# N4_N5
# N5
# <gap_checker.Indel object at 0x1198221d0>
# [True, True, True, False, True, True, True, True]
# N11_sequence5
# sequence5
# <gap_checker.Indel object at 0x119822208>
# [False, False, False, False, False, False, False, False]
# N11_sequence5
# sequence5
# <gap_checker.Indel object at 0x119822240>
# [False, False, False, False, False, False, False, False]
# N11_sequence5
# sequence5
# <gap_checker.Indel object at 0x1198222b0>
# [True, True, True, False, True, True, True, True]
# N5_sequence6
# sequence6
# <gap_checker.Indel object at 0x1198222e8>
# [False, False, False, False, False, False, False, False]
# N5_sequence6
# sequence6
# <gap_checker.Indel object at 0x119822358>
# [False, False, False, False, False, False, False, False]
# N5_sequence6
# sequence6
# <gap_checker.Indel object at 0x1198223c8>
# [False, False, False, False, False, False, False, False]
# N5_sequence6
# sequence6
# <gap_checker.Indel object at 0x1198224e0>
# [True, True, True, True, True, True, True, True]
# N8_N9
# N9
# <gap_checker.Indel object at 0x119822518>
# [False, False, False, False, False, False, False, False]
# N8_N9
# N9
# <gap_checker.Indel object at 0x1198225c0>
# [False, False, False, False, False, False, False, False]
# N8_N9
# N9
# <gap_checker.Indel object at 0x1198225f8>
# [True, True, True, False, True, True, True, True]
# N12_sequence13
# sequence13
# <gap_checker.Indel object at 0x119822668>
# [False, False, False, False, False, False, False, False]
# N12_sequence13
# sequence13
# <gap_checker.Indel object at 0x1198226a0>
# [False, False, False, False, False, False, False, False]
# N12_sequence13
# sequence13
# <gap_checker.Indel object at 0x1198226d8>
# [False, False, False, False, False, False, False, False]
# N12_sequence13
# sequence13
# <gap_checker.Indel object at 0x1198227b8>
# [True, False, True, False, True, False, True, True]
# N12_N13
# N13
# <gap_checker.Indel object at 0x1198227f0>
# [True, True, True, False, True, True, True, True]
# N6_sequence15
# sequence15
# <gap_checker.Indel object at 0x119822860>
# [False, False, False, False, False, False, False, False]
# N6_sequence15
# sequence15
# <gap_checker.Indel object at 0x119822908>
# [True, True, True, True, True, True, True, True]
# N9_sequence16
# sequence16
# <gap_checker.Indel object at 0x1198229b0>
# [True, True, True, False, True, True, True, True]
# N7_sequence1
# sequence1
# <gap_checker.Indel object at 0x1198229e8>
# [True, True, True, False, True, True, True, True]
# N7_sequence17
# sequence17
# <gap_checker.Indel object at 0x119822a20>
# [True, True, True, True, True, True, True, True]
# N10_sequence4
# sequence4
# <gap_checker.Indel object at 0x119822a58>
# [True, True, True, False, True, True, True, True]
# N14_sequence7
# sequence7
# <gap_checker.Indel object at 0x119822ac8>
# [True, True, True, True, True, True, True, True]
# N15_sequence11
# sequence11
# <gap_checker.Indel object at 0x119822b00>
# [False, False, False, False, False, False, False, False]
# N15_sequence11
# sequence11
# <gap_checker.Indel object at 0x119816828>
# [True, True, True, False, True, True, True, True]
# N1_N2
# N2
# <gap_checker.Indel object at 0x11982cdd8>
# [True, True, True, False, True, True, True, True]
# N1_sequence23
# sequence23
# <gap_checker.Indel object at 0x11982ce80>
# [False, False, False, False, False, False, False, False]
# N1_sequence23
# sequence23
# <gap_checker.Indel object at 0x11982cef0>
# [True, True, True, False, True, True, True, True]
# N13_N14
# N14
# <gap_checker.Indel object at 0x11982cf60>
# [False, False, False, False, False, False, False, False]
# N13_N14
# N14
# <gap_checker.Indel object at 0x119834048>
# [True, True, True, False, True, True, True, True]
# N2_N3
# N3
# <gap_checker.Indel object at 0x1198340b8>
# [True, True, True, False, True, True, True, True]
# N14_sequence20
# sequence20
# <gap_checker.Indel object at 0x119834128>
# [True, True, True, False, True, True, True, True]
# N15_sequence11
# sequence11
# <gap_checker.Indel object at 0x119834160>
# [False, False, False, False, False, False, False, False]
# N15_sequence11
# sequence11
# <gap_checker.Indel object at 0x119834208>
# [True, True, True, False, True, True, True, True]
# N3_sequence16
# sequence16
# <gap_checker.Indel object at 0x119834240>
# [False, False, False, False, False, False, False, False]
# N3_sequence16
# sequence16
# <gap_checker.Indel object at 0x119834390>
# [True, False, True, False, True, False, True, True]
# N16_N21
# N21
# <gap_checker.Indel object at 0x119834400>
# [False, False, False, False, False, False, False, False]
# N16_N21
# N21
# <gap_checker.Indel object at 0x1198344a8>
# [True, True, True, False, True, True, True, True]
# N4_sequence19
# sequence19
# <gap_checker.Indel object at 0x1198344e0>
# [False, False, False, False, False, False, False, False]
# N4_sequence19
# sequence19
# <gap_checker.Indel object at 0x119834550>
# [False, False, False, False, False, False, False, False]
# N4_sequence19
# sequence19
# <gap_checker.Indel object at 0x1198345c0>
# [True, True, True, True, True, True, True, True]
# N10_sequence22
# sequence22
# <gap_checker.Indel object at 0x119834668>
# [True, True, True, False, True, True, True, True]
# N17_N18
# N18
# <gap_checker.Indel object at 0x119834710>
# [True, True, True, False, True, True, True, True]
# N21_N22
# N22
# <gap_checker.Indel object at 0x119834780>
# [False, False, False, False, False, False, False, False]
# N21_N22
# N22
# <gap_checker.Indel object at 0x1198347f0>
# [False, False, False, False, False, False, False, False]
# N21_N22
# N22
# <gap_checker.Indel object at 0x119834860>
# [True, True, True, False, True, True, True, True]
# N5_sequence24
# sequence24
# <gap_checker.Indel object at 0x119834940>
# [True, True, True, False, True, True, True, True]
# N5_N6
# N6
# <gap_checker.Indel object at 0x1198349b0>
# [True, True, True, True, True, True, True, True]
# N18_sequence18
# sequence18
# <gap_checker.Indel object at 0x119834a20>
# [True, True, True, True, True, True, True, True]
# N22_sequence7
# sequence7
# <gap_checker.Indel object at 0x119834a58>
# [False, False, False, False, False, False, False, False]
# N22_sequence7
# sequence7
# <gap_checker.Indel object at 0x119834a90>
# [False, False, False, False, False, False, False, False]
# N22_sequence7
# sequence7
# <gap_checker.Indel object at 0x119834ba8>
# [False, False, False, False, False, True, True, True]
# N20_sequence21
# sequence21
# <gap_checker.Indel object at 0x119834c50>
# [True, True, True, False, True, True, True, True]
# N20_sequence9
# sequence9
# <gap_checker.Indel object at 0x119834c88>
# [False, False, False, False, False, False, False, False]
# N20_sequence9
# sequence9
# <gap_checker.Indel object at 0x119834cc0>
# [False, False, False, False, False, False, False, False]
# N20_sequence9
# sequence9
# <gap_checker.Indel object at 0x119834d30>
# [True, True, True, False, True, True, True, True]
# N23_sequence13
# sequence13
# <gap_checker.Indel object at 0x119834d68>
# [True, True, True, True, True, True, True, True]
# N23_sequence8
# sequence8
# <gap_checker.Indel object at 0x119834dd8>
# [False, False, False, False, False, False, False, False]
# N23_sequence8
# sequence8
# <gap_checker.Indel object at 0x119834e80>
# [True, True, True, True, True, True, True, True]
# N25_sequence12
# sequence12
# <gap_checker.Indel object at 0x119834eb8>
# [False, False, False, False, False, False, False, False]
# N25_sequence12
# sequence12
# <gap_checker.Indel object at 0x119834ef0>
# [False, False, False, False, False, False, False, False]
# N25_sequence12
# sequence12
# <gap_checker.Indel object at 0x119834f98>
# [True, False, True, False, True, True, True, True]
# N27_N28
# N28
# <gap_checker.Indel object at 0x119834fd0>
# [False, True, False, False, False, False, False, False]
# N27_N28
# N28
# <gap_checker.Indel object at 0x119837048>
# [True, True, True, False, True, True, True, True]
# N27_sequence27
# sequence27
# <gap_checker.Indel object at 0x1198370f0>
# [False, False, False, False, False, False, False, False]
# N27_sequence27
# sequence27
# <gap_checker.Indel object at 0x119837128>
# [True, True, True, True, True, True, True, True]
# N26_sequence2
# sequence2
# <gap_checker.Indel object at 0x119837198>
# [False, False, False, False, False, False, False, False]
# N26_sequence2
# sequence2
# <gap_checker.Indel object at 0x1198371d0>
# [True, True, True, False, True, True, True, True]
# N28_sequence1
# sequence1
# <gap_checker.Indel object at 0x119837240>
# [False, False, False, True, False, False, False, False]
# N28_sequence1
# sequence1
# <gap_checker.Indel object at 0x119837278>
# [False, False, False, False, False, False, False, False]
# N28_sequence1
# sequence1
# <gap_checker.Indel object at 0x1198372b0>
# [True, True, True, False, True, True, True, True]
# N28_sequence4
# sequence4
# <gap_checker.Indel object at 0x11982ccc0>
# [True, True, True, False, True, True, True, True]
# N1_N14
# N14
# <gap_checker.Indel object at 0x1198373c8>
# [True, True, True, False, True, True, True, True]
# N17_sequence17
# sequence17
# <gap_checker.Indel object at 0x119837438>
# [False, False, False, False, False, False, False, False]
# N17_sequence17
# sequence17
# <gap_checker.Indel object at 0x119837470>
# [False, False, False, False, False, False, False, False]
# N17_sequence17
# sequence17
# <gap_checker.Indel object at 0x119837518>
# [True, False, True, False, True, False, True, True]
# N2_N3
# N3
# <gap_checker.Indel object at 0x1198375c0>
# [True, True, True, False, True, True, True, True]
# N14_sequence27
# sequence27
# <gap_checker.Indel object at 0x119837630>
# [False, False, False, False, False, False, False, False]
# N14_sequence27
# sequence27
# <gap_checker.Indel object at 0x1198376d8>
# [True, True, True, False, True, True, True, True]
# N14_N15
# N15
# <gap_checker.Indel object at 0x119837780>
# [True, True, True, False, True, True, True, True]
# N18_N19
# N19
# <gap_checker.Indel object at 0x119837898>
# [True, True, True, False, True, True, True, True]
# N3_sequence32
# sequence32
# <gap_checker.Indel object at 0x119837908>
# [False, False, False, False, False, False, False, False]
# N3_sequence32
# sequence32
# <gap_checker.Indel object at 0x119837940>
# [False, False, False, False, False, False, False, False]
# N3_sequence32
# sequence32
# <gap_checker.Indel object at 0x119837a20>
# [True, True, True, False, True, True, True, True]
# N15_sequence34
# sequence34
# <gap_checker.Indel object at 0x119837b00>
# [True, True, True, False, True, True, True, True]
# N19_N20
# N20
# <gap_checker.Indel object at 0x119837ba8>
# [True, True, True, False, True, True, True, True]
# N27_N28
# N28
# <gap_checker.Indel object at 0x119837c18>
# [True, True, True, False, True, True, True, True]
# N27_N38
# N38
# <gap_checker.Indel object at 0x119837c50>
# [False, False, False, False, False, False, False, False]
# N27_N38
# N38
# <gap_checker.Indel object at 0x119837cc0>
# [False, False, False, False, False, False, False, False]
# N27_N38
# N38
# <gap_checker.Indel object at 0x119837d68>
# [True, True, True, False, True, True, True, True]
# N4_sequence13
# sequence13
# <gap_checker.Indel object at 0x119837da0>
# [False, False, False, False, False, False, False, False]
# N4_sequence13
# sequence13
# <gap_checker.Indel object at 0x119837dd8>
# [False, False, False, False, False, False, False, False]
# N4_sequence13
# sequence13
# <gap_checker.Indel object at 0x119837e48>
# [True, True, True, False, True, True, True, True]
# N6_N7
# N7
# <gap_checker.Indel object at 0x119837ef0>
# [True, True, True, False, True, True, True, True]
# N6_N9
# N9
# <gap_checker.Indel object at 0x119837f60>
# [True, True, True, False, True, True, True, True]
# N20_sequence29
# sequence29
# <gap_checker.Indel object at 0x11983d048>
# [False, False, False, False, False, False, False, False]
# N20_sequence29
# sequence29
# <gap_checker.Indel object at 0x11983d160>
# [True, True, True, False, True, True, True, True]
# N38_sequence3
# sequence3
# <gap_checker.Indel object at 0x11983d198>
# [True, True, True, True, True, True, True, True]
# N38_sequence22
# sequence22
# <gap_checker.Indel object at 0x11983d240>
# [True, True, True, False, True, True, True, True]
# N9_sequence26
# sequence26
# <gap_checker.Indel object at 0x11983d278>
# [False, False, False, False, False, False, False, False]
# N9_sequence26
# sequence26
# <gap_checker.Indel object at 0x11983d2b0>
# [False, False, False, False, False, False, False, False]
# N9_sequence26
# sequence26
# <gap_checker.Indel object at 0x11983d2e8>
# [True, True, True, False, True, True, True, True]
# N9_sequence9
# sequence9
# <gap_checker.Indel object at 0x11983d358>
# [True, True, True, False, True, True, True, True]
# N11_sequence30
# sequence30
# <gap_checker.Indel object at 0x11983d400>
# [True, True, True, True, True, True, True, True]
# N22_sequence21
# sequence21
# <gap_checker.Indel object at 0x11983d470>
# [True, True, True, False, True, True, True, True]
# N22_N23
# N23
# <gap_checker.Indel object at 0x11983d4a8>
# [True, True, True, True, True, True, True, True]
# N25_sequence15
# sequence15
# <gap_checker.Indel object at 0x11983d4e0>
# [False, False, False, False, False, False, False, False]
# N25_sequence15
# sequence15
# <gap_checker.Indel object at 0x11983d588>
# [True, True, True, False, True, True, True, True]
# N25_N26
# N26
# <gap_checker.Indel object at 0x11983d668>
# [True, True, True, False, True, True, True, True]
# N29_N31
# N31
# <gap_checker.Indel object at 0x11983d710>
# [True, True, True, False, True, True, True, True]
# N32_sequence18
# sequence18
# <gap_checker.Indel object at 0x11983d780>
# [True, True, True, True, True, True, True, True]
# N8_sequence14
# sequence14
# <gap_checker.Indel object at 0x11983d7b8>
# [False, False, False, False, False, False, False, False]
# N8_sequence14
# sequence14
# <gap_checker.Indel object at 0x11983d828>
# [False, False, False, False, False, False, False, False]
# N8_sequence14
# sequence14
# <gap_checker.Indel object at 0x11983d898>
# [True, True, True, False, True, True, True, True]
# N23_sequence33
# sequence33
# <gap_checker.Indel object at 0x11983d978>
# [True, True, True, True, True, True, True, True]
# N26_sequence6
# sequence6
# <gap_checker.Indel object at 0x11983d9b0>
# [True, True, True, True, True, True, True, True]
# N31_sequence10
# sequence10
# <gap_checker.Indel object at 0x11983da58>
# [True, True, True, True, True, True, True, True]
# N34_sequence40
# sequence40
# <gap_checker.Indel object at 0x11983db00>
# [True, True, True, True, True, True, True, True]
# N35_sequence20
# sequence20
# <gap_checker.Indel object at 0x11982fbe0>
# [True, True, True, False, True, True, False, True]
# N0_N1
# N1
# <gap_checker.Indel object at 0x119840cf8>
# [True, True, True, False, True, True, True, True]
# N3_N27
# N27
# <gap_checker.Indel object at 0x119840d68>
# [True, True, True, False, True, True, True, True]
# N2_sequence13
# sequence13
# <gap_checker.Indel object at 0x119840e80>
# [True, True, True, False, True, True, True, True]
# N5_sequence2
# sequence2
# <gap_checker.Indel object at 0x119840f28>
# [False, False, False, False, False, False, False, False]
# N5_sequence2
# sequence2
# <gap_checker.Indel object at 0x119840f98>
# [False, False, False, False, False, False, False, False]
# N5_sequence2
# sequence2
# <gap_checker.Indel object at 0x119844048>
# [False, False, False, False, False, False, False, False]
# N5_sequence2
# sequence2
# <gap_checker.Indel object at 0x1198440b8>
# [False, False, False, False, False, False, False, False]
# N5_sequence2
# sequence2
# <gap_checker.Indel object at 0x119844128>
# [False, False, False, False, False, False, False, False]
# N5_sequence2
# sequence2
# <gap_checker.Indel object at 0x1198441d0>
# [True, True, True, False, True, True, True, True]
# N21_N22
# N22
# <gap_checker.Indel object at 0x119844208>
# [False, False, False, False, False, False, False, False]
# N21_N22
# N22
# <gap_checker.Indel object at 0x119844240>
# [False, False, False, False, False, False, False, False]
# N21_N22
# N22
# <gap_checker.Indel object at 0x119844278>
# [False, False, False, False, False, False, False, False]
# N21_N22
# N22
# <gap_checker.Indel object at 0x119844320>
# [True, True, True, False, True, True, True, True]
# N21_N26
# N26
# <gap_checker.Indel object at 0x119844390>
# [False, False, False, False, False, False, False, False]
# N21_N26
# N26
# <gap_checker.Indel object at 0x1198443c8>
# [False, False, False, False, False, False, False, False]
# N21_N26
# N26
# <gap_checker.Indel object at 0x119844438>
# [True, True, True, False, True, True, True, True]
# N28_N29
# N29
# <gap_checker.Indel object at 0x1198444e0>
# [True, True, True, False, True, True, True, True]
# N37_N38
# N38
# <gap_checker.Indel object at 0x119844588>
# [True, True, True, False, True, True, True, True]
# N37_N47
# N47
# <gap_checker.Indel object at 0x1198445c0>
# [False, False, False, False, False, False, False, False]
# N37_N47
# N47
# <gap_checker.Indel object at 0x119844668>
# [True, True, True, False, True, True, True, True]
# N6_N7
# N7
# <gap_checker.Indel object at 0x119844710>
# [True, False, True, True, True, False, True, True]
# N22_N23
# N23
# <gap_checker.Indel object at 0x119844748>
# [True, True, True, False, True, True, True, True]
# N26_sequence43
# sequence43
# <gap_checker.Indel object at 0x119844780>
# [False, False, False, False, False, False, False, False]
# N26_sequence43
# sequence43
# <gap_checker.Indel object at 0x1198447f0>
# [False, False, False, False, False, False, False, False]
# N26_sequence43
# sequence43
# <gap_checker.Indel object at 0x119844828>
# [False, False, False, False, False, False, False, False]
# N26_sequence43
# sequence43
# <gap_checker.Indel object at 0x119844898>
# [True, True, True, False, True, True, True, True]
# N26_sequence48
# sequence48
# <gap_checker.Indel object at 0x119844908>
# [False, False, False, False, False, False, False, False]
# N26_sequence48
# sequence48
# <gap_checker.Indel object at 0x119844978>
# [False, False, False, False, False, False, False, False]
# N26_sequence48
# sequence48
# <gap_checker.Indel object at 0x119844a58>
# [True, True, True, False, True, True, True, True]
# N35_sequence37
# sequence37
# <gap_checker.Indel object at 0x119844ac8>
# [False, False, False, False, False, False, False, False]
# N35_sequence37
# sequence37
# <gap_checker.Indel object at 0x119844b00>
# [False, False, False, False, False, False, False, False]
# N35_sequence37
# sequence37
# <gap_checker.Indel object at 0x119844c18>
# [True, True, True, False, True, True, True, True]
# N47_sequence34
# sequence34
# <gap_checker.Indel object at 0x119844c88>
# [True, True, True, False, True, True, True, True]
# N7_sequence20
# sequence20
# <gap_checker.Indel object at 0x119844cc0>
# [False, False, False, False, False, False, False, False]
# N7_sequence20
# sequence20
# <gap_checker.Indel object at 0x119844d68>
# [True, True, True, False, True, True, True, True]
# N15_N17
# N17
# <gap_checker.Indel object at 0x119844e10>
# [True, True, True, False, True, True, True, True]
# N23_N25
# N25
# <gap_checker.Indel object at 0x119844e80>
# [True, True, True, False, True, True, True, True]
# N30_sequence18
# sequence18
# <gap_checker.Indel object at 0x119844eb8>
# [False, False, False, False, False, False, False, False]
# N30_sequence18
# sequence18
# <gap_checker.Indel object at 0x119844f28>
# [False, False, False, False, False, False, False, False]
# N30_sequence18
# sequence18
# <gap_checker.Indel object at 0x119844f98>
# [False, False, False, False, False, False, False, False]
# N30_sequence18
# sequence18
# <gap_checker.Indel object at 0x119852080>
# [True, True, True, False, True, True, True, True]
# N30_sequence40
# sequence40
# <gap_checker.Indel object at 0x1198520b8>
# [False, False, False, False, False, False, False, False]
# N30_sequence40
# sequence40
# <gap_checker.Indel object at 0x119852198>
# [True, True, True, False, True, True, True, True]
# N31_N32
# N32
# <gap_checker.Indel object at 0x119852208>
# [True, True, True, False, True, True, True, True]
# N31_N34
# N34
# <gap_checker.Indel object at 0x119852240>
# [False, False, False, False, False, False, False, False]
# N31_N34
# N34
# <gap_checker.Indel object at 0x1198522b0>
# [False, False, False, False, False, False, False, False]
# N31_N34
# N34
# <gap_checker.Indel object at 0x1198522e8>
# [False, False, False, False, False, False, False, False]
# N31_N34
# N34
# <gap_checker.Indel object at 0x119852358>
# [False, False, False, False, False, False, False, False]
# N31_N34
# N34
# <gap_checker.Indel object at 0x1198523c8>
# [True, True, True, False, True, True, True, True]
# N36_sequence38
# sequence38
# <gap_checker.Indel object at 0x119852470>
# [True, True, True, False, True, True, True, True]
# N36_sequence17
# sequence17
# <gap_checker.Indel object at 0x1198524a8>
# [False, False, False, False, False, False, False, False]
# N36_sequence17
# sequence17
# <gap_checker.Indel object at 0x1198524e0>
# [True, True, True, False, True, True, True, True]
# N39_sequence27
# sequence27
# <gap_checker.Indel object at 0x119852668>
# [True, True, True, False, True, True, True, True]
# N8_N14
# N14
# <gap_checker.Indel object at 0x1198526d8>
# [False, False, False, False, False, False, False, False]
# N8_N14
# N14
# <gap_checker.Indel object at 0x119852710>
# [False, False, False, False, False, False, False, False]
# N8_N14
# N14
# <gap_checker.Indel object at 0x119852780>
# [True, True, True, False, True, True, True, True]
# N16_sequence15
# sequence15
# <gap_checker.Indel object at 0x1198527b8>
# [False, False, False, False, False, False, False, False]
# N16_sequence15
# sequence15
# <gap_checker.Indel object at 0x119852860>
# [False, False, False, False, False, False, False, False]
# N16_sequence15
# sequence15
# <gap_checker.Indel object at 0x1198528d0>
# [False, False, False, False, False, False, False, False]
# N16_sequence15
# sequence15
# <gap_checker.Indel object at 0x119852908>
# [False, False, False, False, False, False, False, False]
# N16_sequence15
# sequence15
# <gap_checker.Indel object at 0x119852978>
# [False, False, False, False, False, False, False, False]
# N16_sequence15
# sequence15
# <gap_checker.Indel object at 0x1198529e8>
# [True, True, False, False, False, True, False, True]
# N16_sequence45
# sequence45
# <gap_checker.Indel object at 0x119852ac8>
# [True, False, True, True, True, False, True, True]
# N17_N18
# N18
# <gap_checker.Indel object at 0x119852b38>
# [True, False, True, False, True, False, True, True]
# N17_sequence21
# sequence21
# <gap_checker.Indel object at 0x119852ba8>
# [True, True, True, False, True, True, True, True]
# N24_sequence28
# sequence28
# <gap_checker.Indel object at 0x119852c18>
# [True, True, True, False, True, True, True, True]
# N24_sequence6
# sequence6
# <gap_checker.Indel object at 0x119852c50>
# [False, False, False, False, False, False, False, False]
# N24_sequence6
# sequence6
# <gap_checker.Indel object at 0x119852cc0>
# [False, False, False, False, False, False, False, False]
# N24_sequence6
# sequence6
# <gap_checker.Indel object at 0x119852cf8>
# [True, True, True, False, True, True, True, True]
# N25_sequence32
# sequence32
# <gap_checker.Indel object at 0x119852da0>
# [True, True, True, False, True, True, True, True]
# N32_sequence49
# sequence49
# <gap_checker.Indel object at 0x119852dd8>
# [True, True, True, False, True, True, True, True]
# N34_sequence3
# sequence3
# <gap_checker.Indel object at 0x119852e48>
# [True, True, True, True, True, True, True, True]
# N41_sequence23
# sequence23
# <gap_checker.Indel object at 0x119852eb8>
# [False, False, False, False, False, False, False, False]
# N41_sequence23
# sequence23
# <gap_checker.Indel object at 0x119852ef0>
# [False, False, False, False, False, False, False, False]
# N41_sequence23
# sequence23
# <gap_checker.Indel object at 0x119852f60>
# [False, False, False, False, False, False, False, False]
# N41_sequence23
# sequence23
# <gap_checker.Indel object at 0x1198560f0>
# [True, True, True, False, True, True, True, True]
# N43_N46
# N46
# <gap_checker.Indel object at 0x119856160>
# [False, False, False, False, False, False, False, False]
# N43_N46
# N46
# <gap_checker.Indel object at 0x1198561d0>
# [False, False, False, False, False, False, False, False]
# N43_N46
# N46
# <gap_checker.Indel object at 0x119856240>
# [True, True, True, False, True, True, True, True]
# N9_N10
# N10
# <gap_checker.Indel object at 0x1198562e8>
# [True, True, True, False, True, True, True, True]
# N9_N12
# N12
# <gap_checker.Indel object at 0x119856320>
# [False, False, False, False, False, False, False, False]
# N9_N12
# N12
# <gap_checker.Indel object at 0x1198563c8>
# [True, True, True, False, True, True, True, True]
# N18_N19
# N19
# <gap_checker.Indel object at 0x119856400>
# [False, False, False, True, False, False, False, False]
# N18_N19
# N19
# <gap_checker.Indel object at 0x119856470>
# [False, False, False, False, False, True, True, True]
# N42_sequence39
# sequence39
# <gap_checker.Indel object at 0x1198564a8>
# [False, False, False, False, False, True, True, True]
# N42_sequence35
# sequence35
# <gap_checker.Indel object at 0x119856518>
# [True, True, True, False, True, True, True, True]
# N44_sequence12
# sequence12
# <gap_checker.Indel object at 0x1198565c0>
# [True, True, True, False, True, True, True, True]
# N44_N45
# N45
# <gap_checker.Indel object at 0x1198565f8>
# [False, False, False, False, False, False, False, False]
# N44_N45
# N45
# <gap_checker.Indel object at 0x119856630>
# [True, True, True, True, True, True, True, True]
# N46_sequence7
# sequence7
# <gap_checker.Indel object at 0x119856668>
# [False, False, False, False, False, False, False, False]
# N46_sequence7
# sequence7
# <gap_checker.Indel object at 0x1198566d8>
# [False, False, False, False, False, False, False, False]
# N46_sequence7
# sequence7
# <gap_checker.Indel object at 0x119856780>
# [True, True, True, False, True, True, True, True]
# N10_N11
# N11
# <gap_checker.Indel object at 0x119856828>
# [False, False, False, False, False, False, False, False]
# N10_N11
# N11
# <gap_checker.Indel object at 0x119856908>
# [True, True, True, True, True, True, True, True]
# N45_sequence25
# sequence25
