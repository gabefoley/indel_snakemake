# %%
import pickle
import pandas as pd
import matplotlib.pyplot as plt
import glob
import os
from collections import defaultdict
import csv
import ete3

# %%
taxa = sorted([x.split("/")[-1] for x in glob.glob("./output_dicts/*") if os.path.isdir(x)], key=float)

# %%
taxa
# Out:
# ['10', '20', '30', '40', '50']

# %%
methods = ['PSP', 'PSML', 'SICP', 'SICML', 'BEP', 'BEML']

output_file = "indel_output.csv"

methods_dict = defaultdict(dict)
for taxon in taxa:
    for method in methods:
        with open(f'./output_dicts/{taxon}/gaps_{method}_1.p', 'rb') as handle:
            methods_dict[method][taxon] = pickle.load(handle)
        
methods_dict
# Out:
# defaultdict(dict,
#             {'PSP': {'10': {'N0_N1': [<gap_checker.Indel at 0x11e02c320>,
#                 <gap_checker.Indel at 0x11dff3828>,
#                 <gap_checker.Indel at 0x11dff3278>,
#                 <gap_checker.Indel at 0x11dff3a20>],
#                'N0_sequence5': [<gap_checker.Indel at 0x11dff37f0>,
#                 <gap_checker.Indel at 0x11dff3ac8>,
#                 <gap_checker.Indel at 0x11dff3400>,
#                 <gap_checker.Indel at 0x11e321128>,
#                 <gap_checker.Indel at 0x11e321588>,
#                 <gap_checker.Indel at 0x11e321b38>,
#                 <gap_checker.Indel at 0x11e3216d8>,
#                 <gap_checker.Indel at 0x11e321550>,
#                 <gap_checker.Indel at 0x11e02f668>,
#                 <gap_checker.Indel at 0x11e02fef0>,
#                 <gap_checker.Indel at 0x11e02f828>],
#                'N1_sequence3': [<gap_checker.Indel at 0x11e02f630>,
#                 <gap_checker.Indel at 0x11e02ff98>,
#                 <gap_checker.Indel at 0x11e02fc18>,
#                 <gap_checker.Indel at 0x11e08cef0>,
#                 <gap_checker.Indel at 0x11e08cb70>,
#                 <gap_checker.Indel at 0x11e08ce48>],
#                'N1_N2': [<gap_checker.Indel at 0x11e08ca58>,
#                 <gap_checker.Indel at 0x11e08c160>,
#                 <gap_checker.Indel at 0x11e08c2e8>,
#                 <gap_checker.Indel at 0x11e08cc18>,
#                 <gap_checker.Indel at 0x11e08ceb8>,
#                 <gap_checker.Indel at 0x11e08cda0>,
#                 <gap_checker.Indel at 0x11e08cf60>,
#                 <gap_checker.Indel at 0x11e0319e8>],
#                'N2_N3': [<gap_checker.Indel at 0x11e031278>,
#                 <gap_checker.Indel at 0x11e031b70>],
#                'N2_N7': [<gap_checker.Indel at 0x11e0317b8>,
#                 <gap_checker.Indel at 0x11e487828>],
#                'N3_N4': [<gap_checker.Indel at 0x11e487438>,
#                 <gap_checker.Indel at 0x11e487d68>,
#                 <gap_checker.Indel at 0x11e487940>,
#                 <gap_checker.Indel at 0x11e487160>,
#                 <gap_checker.Indel at 0x11e487550>],
#                'N3_N5': [<gap_checker.Indel at 0x11e487470>,
#                 <gap_checker.Indel at 0x11e487fd0>,
#                 <gap_checker.Indel at 0x11e487f98>,
#                 <gap_checker.Indel at 0x11e487e48>],
#                'N7_sequence8': [<gap_checker.Indel at 0x11e4879e8>,
#                 <gap_checker.Indel at 0x11e487080>,
#                 <gap_checker.Indel at 0x11e487240>,
#                 <gap_checker.Indel at 0x11e4870b8>,
#                 <gap_checker.Indel at 0x11e4871d0>,
#                 <gap_checker.Indel at 0x11e487ba8>,
#                 <gap_checker.Indel at 0x11e4876a0>,
#                 <gap_checker.Indel at 0x11e487860>,
#                 <gap_checker.Indel at 0x11e487cc0>,
#                 <gap_checker.Indel at 0x11e0ccf28>,
#                 <gap_checker.Indel at 0x11e0ccfd0>],
#                'N7_N8': [<gap_checker.Indel at 0x11e459ac8>,
#                 <gap_checker.Indel at 0x11e459080>,
#                 <gap_checker.Indel at 0x11e459ef0>,
#                 <gap_checker.Indel at 0x11e459e48>,
#                 <gap_checker.Indel at 0x11e459f28>],
#                'N4_sequence4': [<gap_checker.Indel at 0x11e4595c0>,
#                 <gap_checker.Indel at 0x11e459b00>,
#                 <gap_checker.Indel at 0x11e4593c8>,
#                 <gap_checker.Indel at 0x11e459a90>,
#                 <gap_checker.Indel at 0x11e459b70>,
#                 <gap_checker.Indel at 0x11e459518>,
#                 <gap_checker.Indel at 0x11e4592b0>,
#                 <gap_checker.Indel at 0x11e4591d0>,
#                 <gap_checker.Indel at 0x11e459828>],
#                'N4_sequence6': [<gap_checker.Indel at 0x11e459358>,
#                 <gap_checker.Indel at 0x11e459198>,
#                 <gap_checker.Indel at 0x11e459048>,
#                 <gap_checker.Indel at 0x11e459fd0>,
#                 <gap_checker.Indel at 0x11e459208>,
#                 <gap_checker.Indel at 0x11e459390>],
#                'N5_sequence7': [<gap_checker.Indel at 0x11e4596d8>,
#                 <gap_checker.Indel at 0x11e048c18>],
#                'N5_N6': [<gap_checker.Indel at 0x11e0487f0>,
#                 <gap_checker.Indel at 0x11e048588>,
#                 <gap_checker.Indel at 0x11e0485f8>,
#                 <gap_checker.Indel at 0x11e0484e0>],
#                'N8_sequence10': [<gap_checker.Indel at 0x11e483128>],
#                'N8_sequence9': [],
#                'N6_sequence2': [<gap_checker.Indel at 0x11e4830b8>],
#                'N6_sequence1': []},
#               '20': {'N0_N1': [<gap_checker.Indel at 0x11e0e2cc0>,
#                 <gap_checker.Indel at 0x11e39cdd8>,
#                 <gap_checker.Indel at 0x11e39ce80>],
#                'N0_N17': [<gap_checker.Indel at 0x11e39cf28>,
#                 <gap_checker.Indel at 0x11e39cf60>,
#                 <gap_checker.Indel at 0x11e39cf98>,
#                 <gap_checker.Indel at 0x11e39cfd0>,
#                 <gap_checker.Indel at 0x11e3ae048>,
#                 <gap_checker.Indel at 0x11e3ae080>,
#                 <gap_checker.Indel at 0x11e3ae0b8>],
#                'N1_N2': [<gap_checker.Indel at 0x11e3ae160>,
#                 <gap_checker.Indel at 0x11e3ae1d0>],
#                'N1_N3': [<gap_checker.Indel at 0x11e3ae278>,
#                 <gap_checker.Indel at 0x11e3ae2e8>,
#                 <gap_checker.Indel at 0x11e3ae390>,
#                 <gap_checker.Indel at 0x11e3ae400>],
#                'N17_N18': [<gap_checker.Indel at 0x11e3ae4e0>],
#                'N17_sequence3': [],
#                'N2_sequence12': [<gap_checker.Indel at 0x11e3ae550>,
#                 <gap_checker.Indel at 0x11e3ae5c0>,
#                 <gap_checker.Indel at 0x11e3ae5f8>,
#                 <gap_checker.Indel at 0x11e3ae6a0>,
#                 <gap_checker.Indel at 0x11e3ae6d8>,
#                 <gap_checker.Indel at 0x11e3ae748>,
#                 <gap_checker.Indel at 0x11e3ae7b8>,
#                 <gap_checker.Indel at 0x11e3ae860>,
#                 <gap_checker.Indel at 0x11e3ae8d0>,
#                 <gap_checker.Indel at 0x11e3ae940>,
#                 <gap_checker.Indel at 0x11e3ae9b0>],
#                'N2_sequence8': [<gap_checker.Indel at 0x11e3aea20>,
#                 <gap_checker.Indel at 0x11e3aeac8>,
#                 <gap_checker.Indel at 0x11e3aeb70>,
#                 <gap_checker.Indel at 0x11e3aebe0>,
#                 <gap_checker.Indel at 0x11e3aec50>,
#                 <gap_checker.Indel at 0x11e3aec88>,
#                 <gap_checker.Indel at 0x11e3aecf8>,
#                 <gap_checker.Indel at 0x11e3aeda0>,
#                 <gap_checker.Indel at 0x11e3aee10>,
#                 <gap_checker.Indel at 0x11e3aee48>],
#                'N3_N4': [<gap_checker.Indel at 0x11e3aef28>,
#                 <gap_checker.Indel at 0x11e3aef98>,
#                 <gap_checker.Indel at 0x11e3b1048>,
#                 <gap_checker.Indel at 0x11e3b1080>],
#                'N3_N11': [<gap_checker.Indel at 0x11e3b1128>,
#                 <gap_checker.Indel at 0x11e3b1198>,
#                 <gap_checker.Indel at 0x11e3b11d0>,
#                 <gap_checker.Indel at 0x11e3b1208>,
#                 <gap_checker.Indel at 0x11e3b1278>],
#                'N18_sequence9': [<gap_checker.Indel at 0x11e3b12b0>,
#                 <gap_checker.Indel at 0x11e3b1320>],
#                'N18_sequence18': [<gap_checker.Indel at 0x11e3b1358>,
#                 <gap_checker.Indel at 0x11e3b1390>],
#                'N4_N5': [<gap_checker.Indel at 0x11e3b1400>,
#                 <gap_checker.Indel at 0x11e3b1470>,
#                 <gap_checker.Indel at 0x11e3b1518>,
#                 <gap_checker.Indel at 0x11e3b1588>],
#                'N4_N8': [<gap_checker.Indel at 0x11e3b1630>,
#                 <gap_checker.Indel at 0x11e3b1668>,
#                 <gap_checker.Indel at 0x11e3b16a0>,
#                 <gap_checker.Indel at 0x11e3b1710>,
#                 <gap_checker.Indel at 0x11e3b1780>,
#                 <gap_checker.Indel at 0x11e3b17f0>,
#                 <gap_checker.Indel at 0x11e3b1860>,
#                 <gap_checker.Indel at 0x11e3b1898>,
#                 <gap_checker.Indel at 0x11e3b1908>,
#                 <gap_checker.Indel at 0x11e3b1978>,
#                 <gap_checker.Indel at 0x11e3b19e8>],
#                'N11_N12': [<gap_checker.Indel at 0x11e3b1ac8>,
#                 <gap_checker.Indel at 0x11e3b1b38>,
#                 <gap_checker.Indel at 0x11e3b1be0>],
#                'N11_sequence5': [<gap_checker.Indel at 0x11e3b1c50>,
#                 <gap_checker.Indel at 0x11e3b1cc0>,
#                 <gap_checker.Indel at 0x11e3b1d30>,
#                 <gap_checker.Indel at 0x11e3b1da0>,
#                 <gap_checker.Indel at 0x11e3b1e10>,
#                 <gap_checker.Indel at 0x11e3b1e80>],
#                'N5_sequence6': [<gap_checker.Indel at 0x11e3b1ef0>,
#                 <gap_checker.Indel at 0x11e3b1f60>,
#                 <gap_checker.Indel at 0x11e3b1fd0>,
#                 <gap_checker.Indel at 0x11e3cd080>,
#                 <gap_checker.Indel at 0x11e3cd0b8>,
#                 <gap_checker.Indel at 0x11e3cd160>,
#                 <gap_checker.Indel at 0x11e3cd1d0>,
#                 <gap_checker.Indel at 0x11e3cd240>,
#                 <gap_checker.Indel at 0x11e3cd278>,
#                 <gap_checker.Indel at 0x11e3cd2e8>,
#                 <gap_checker.Indel at 0x11e3cd358>,
#                 <gap_checker.Indel at 0x11e3cd390>,
#                 <gap_checker.Indel at 0x11e3cd3c8>],
#                'N5_N6': [<gap_checker.Indel at 0x11e3cd438>,
#                 <gap_checker.Indel at 0x11e3cd4a8>],
#                'N8_sequence14': [<gap_checker.Indel at 0x11e3cd518>,
#                 <gap_checker.Indel at 0x11e3cd550>],
#                'N8_N9': [<gap_checker.Indel at 0x11e3cd5f8>,
#                 <gap_checker.Indel at 0x11e3cd630>,
#                 <gap_checker.Indel at 0x11e3cd6a0>,
#                 <gap_checker.Indel at 0x11e3cd710>],
#                'N12_sequence13': [<gap_checker.Indel at 0x11e3cd7b8>,
#                 <gap_checker.Indel at 0x11e3cd828>,
#                 <gap_checker.Indel at 0x11e3cd898>,
#                 <gap_checker.Indel at 0x11e3cd908>,
#                 <gap_checker.Indel at 0x11e3cd978>],
#                'N12_N13': [<gap_checker.Indel at 0x11e3cda20>,
#                 <gap_checker.Indel at 0x11e3cda58>,
#                 <gap_checker.Indel at 0x11e3cdac8>],
#                'N6_sequence15': [<gap_checker.Indel at 0x11e3cdb38>,
#                 <gap_checker.Indel at 0x11e3cdba8>,
#                 <gap_checker.Indel at 0x11e3cdbe0>,
#                 <gap_checker.Indel at 0x11e3cdc50>,
#                 <gap_checker.Indel at 0x11e3cdcc0>],
#                'N6_N7': [<gap_checker.Indel at 0x11e3cdd68>,
#                 <gap_checker.Indel at 0x11e3cddd8>],
#                'N9_sequence16': [],
#                'N9_N10': [],
#                'N13_N14': [],
#                'N13_sequence10': [<gap_checker.Indel at 0x11e3cdef0>,
#                 <gap_checker.Indel at 0x11e3cdf60>,
#                 <gap_checker.Indel at 0x11e3cdfd0>,
#                 <gap_checker.Indel at 0x11e169048>,
#                 <gap_checker.Indel at 0x11e1690b8>,
#                 <gap_checker.Indel at 0x11e169160>],
#                'N7_sequence1': [<gap_checker.Indel at 0x11e1691d0>,
#                 <gap_checker.Indel at 0x11e169240>,
#                 <gap_checker.Indel at 0x11e1692e8>],
#                'N7_sequence17': [<gap_checker.Indel at 0x11e169358>,
#                 <gap_checker.Indel at 0x11e169400>,
#                 <gap_checker.Indel at 0x11e169470>,
#                 <gap_checker.Indel at 0x11e1694a8>],
#                'N10_sequence4': [<gap_checker.Indel at 0x11e169588>],
#                'N10_sequence2': [],
#                'N14_sequence7': [<gap_checker.Indel at 0x11e169630>,
#                 <gap_checker.Indel at 0x11e169668>,
#                 <gap_checker.Indel at 0x11e1696d8>,
#                 <gap_checker.Indel at 0x11e169748>,
#                 <gap_checker.Indel at 0x11e1697b8>,
#                 <gap_checker.Indel at 0x11e169828>,
#                 <gap_checker.Indel at 0x11e1698d0>],
#                'N14_N15': [<gap_checker.Indel at 0x11e1699b0>,
#                 <gap_checker.Indel at 0x11e169a20>,
#                 <gap_checker.Indel at 0x11e169a58>,
#                 <gap_checker.Indel at 0x11e169ac8>],
#                'N15_sequence11': [<gap_checker.Indel at 0x11e169b70>],
#                'N15_N16': [<gap_checker.Indel at 0x11e169c18>,
#                 <gap_checker.Indel at 0x11e169c50>,
#                 <gap_checker.Indel at 0x11e169cf8>,
#                 <gap_checker.Indel at 0x11e169d68>,
#                 <gap_checker.Indel at 0x11e169da0>],
#                'N16_sequence19': [<gap_checker.Indel at 0x11e169dd8>],
#                'N16_sequence20': []},
#               '30': {'N0_N1': [<gap_checker.Indel at 0x11e169ef0>],
#                'N0_N13': [<gap_checker.Indel at 0x11eddce10>],
#                'N1_N2': [<gap_checker.Indel at 0x11eddceb8>],
#                'N1_sequence23': [<gap_checker.Indel at 0x11eddcf28>,
#                 <gap_checker.Indel at 0x11eddcf98>,
#                 <gap_checker.Indel at 0x11ede9080>,
#                 <gap_checker.Indel at 0x11ede90b8>,
#                 <gap_checker.Indel at 0x11ede9128>,
#                 <gap_checker.Indel at 0x11ede9160>],
#                'N13_N14': [<gap_checker.Indel at 0x11ede9208>,
#                 <gap_checker.Indel at 0x11ede9278>,
#                 <gap_checker.Indel at 0x11ede92e8>,
#                 <gap_checker.Indel at 0x11ede9320>,
#                 <gap_checker.Indel at 0x11ede9390>,
#                 <gap_checker.Indel at 0x11ede9400>,
#                 <gap_checker.Indel at 0x11ede9470>,
#                 <gap_checker.Indel at 0x11ede9518>,
#                 <gap_checker.Indel at 0x11ede9588>],
#                'N13_N15': [<gap_checker.Indel at 0x11ede9630>,
#                 <gap_checker.Indel at 0x11ede96a0>,
#                 <gap_checker.Indel at 0x11ede9710>],
#                'N2_N3': [<gap_checker.Indel at 0x11ede97f0>,
#                 <gap_checker.Indel at 0x11ede9828>],
#                'N2_N8': [<gap_checker.Indel at 0x11ede98d0>,
#                 <gap_checker.Indel at 0x11ede9978>,
#                 <gap_checker.Indel at 0x11ede9a20>,
#                 <gap_checker.Indel at 0x11ede9a90>],
#                'N14_sequence20': [<gap_checker.Indel at 0x11ede9b38>,
#                 <gap_checker.Indel at 0x11ede9ba8>],
#                'N14_sequence17': [<gap_checker.Indel at 0x11ede9c18>],
#                'N15_N16': [<gap_checker.Indel at 0x11ede9cc0>,
#                 <gap_checker.Indel at 0x11ede9d30>,
#                 <gap_checker.Indel at 0x11ede9da0>],
#                'N15_sequence11': [<gap_checker.Indel at 0x11ede9e10>,
#                 <gap_checker.Indel at 0x11ede9e80>,
#                 <gap_checker.Indel at 0x11ede9eb8>,
#                 <gap_checker.Indel at 0x11ede9ef0>,
#                 <gap_checker.Indel at 0x11ede9f60>,
#                 <gap_checker.Indel at 0x11ede9fd0>,
#                 <gap_checker.Indel at 0x11edee080>,
#                 <gap_checker.Indel at 0x11edee0f0>],
#                'N3_N4': [<gap_checker.Indel at 0x11edee198>,
#                 <gap_checker.Indel at 0x11edee240>],
#                'N3_sequence16': [<gap_checker.Indel at 0x11edee2b0>,
#                 <gap_checker.Indel at 0x11edee320>],
#                'N8_N9': [<gap_checker.Indel at 0x11edee3c8>,
#                 <gap_checker.Indel at 0x11edee400>,
#                 <gap_checker.Indel at 0x11edee470>],
#                'N8_N10': [<gap_checker.Indel at 0x11edee518>,
#                 <gap_checker.Indel at 0x11edee550>],
#                'N16_N17': [<gap_checker.Indel at 0x11edee5c0>,
#                 <gap_checker.Indel at 0x11edee630>,
#                 <gap_checker.Indel at 0x11edee6a0>],
#                'N16_N21': [<gap_checker.Indel at 0x11edee748>],
#                'N4_N5': [<gap_checker.Indel at 0x11edee7b8>,
#                 <gap_checker.Indel at 0x11edee828>],
#                'N4_sequence19': [<gap_checker.Indel at 0x11edee898>,
#                 <gap_checker.Indel at 0x11edee8d0>,
#                 <gap_checker.Indel at 0x11edee940>,
#                 <gap_checker.Indel at 0x11edee9b0>,
#                 <gap_checker.Indel at 0x11edeea20>,
#                 <gap_checker.Indel at 0x11edeea58>],
#                'N9_sequence28': [],
#                'N9_sequence30': [],
#                'N10_sequence22': [<gap_checker.Indel at 0x11edeeac8>,
#                 <gap_checker.Indel at 0x11edeeb38>,
#                 <gap_checker.Indel at 0x11edeebe0>],
#                'N10_N11': [<gap_checker.Indel at 0x11edeec88>],
#                'N17_N18': [<gap_checker.Indel at 0x11edeed30>,
#                 <gap_checker.Indel at 0x11edeed68>,
#                 <gap_checker.Indel at 0x11edeeda0>],
#                'N17_N19': [<gap_checker.Indel at 0x11edeee48>],
#                'N21_N22': [<gap_checker.Indel at 0x11edeeef0>,
#                 <gap_checker.Indel at 0x11edeef60>,
#                 <gap_checker.Indel at 0x11edeef98>,
#                 <gap_checker.Indel at 0x11edf0048>,
#                 <gap_checker.Indel at 0x11edf0080>],
#                'N21_N24': [<gap_checker.Indel at 0x11edf00f0>,
#                 <gap_checker.Indel at 0x11edf0198>],
#                'N5_sequence24': [<gap_checker.Indel at 0x11edf0208>,
#                 <gap_checker.Indel at 0x11edf0240>,
#                 <gap_checker.Indel at 0x11edf02e8>],
#                'N5_N6': [<gap_checker.Indel at 0x11edf0390>,
#                 <gap_checker.Indel at 0x11edf0400>,
#                 <gap_checker.Indel at 0x11edf0438>,
#                 <gap_checker.Indel at 0x11edf04a8>,
#                 <gap_checker.Indel at 0x11edf0518>,
#                 <gap_checker.Indel at 0x11edf05c0>,
#                 <gap_checker.Indel at 0x11edf05f8>,
#                 <gap_checker.Indel at 0x11edf06a0>,
#                 <gap_checker.Indel at 0x11edf0710>],
#                'N11_sequence25': [],
#                'N11_N12': [],
#                'N18_sequence18': [<gap_checker.Indel at 0x11edf07b8>],
#                'N18_sequence29': [<gap_checker.Indel at 0x11edf07f0>,
#                 <gap_checker.Indel at 0x11edf0898>,
#                 <gap_checker.Indel at 0x11edf0908>,
#                 <gap_checker.Indel at 0x11edf0978>],
#                'N19_N20': [],
#                'N19_sequence10': [<gap_checker.Indel at 0x11edf0a20>,
#                 <gap_checker.Indel at 0x11edf0a90>,
#                 <gap_checker.Indel at 0x11edf0ac8>,
#                 <gap_checker.Indel at 0x11edf0b38>],
#                'N22_sequence7': [<gap_checker.Indel at 0x11edf0be0>,
#                 <gap_checker.Indel at 0x11edf0c50>,
#                 <gap_checker.Indel at 0x11edf0c88>],
#                'N22_N23': [],
#                'N24_N25': [<gap_checker.Indel at 0x11edf0d68>,
#                 <gap_checker.Indel at 0x11edf0dd8>,
#                 <gap_checker.Indel at 0x11edf0e48>,
#                 <gap_checker.Indel at 0x11edf0e80>],
#                'N24_N27': [],
#                'N6_N7': [<gap_checker.Indel at 0x11edf0f98>],
#                'N6_sequence5': [<gap_checker.Indel at 0x11edfe048>],
#                'N12_sequence6': [],
#                'N12_sequence3': [],
#                'N20_sequence21': [<gap_checker.Indel at 0x11edfe0b8>],
#                'N20_sequence9': [<gap_checker.Indel at 0x11edfe0f0>,
#                 <gap_checker.Indel at 0x11edfe160>],
#                'N23_sequence13': [<gap_checker.Indel at 0x11edfe198>,
#                 <gap_checker.Indel at 0x11edfe208>,
#                 <gap_checker.Indel at 0x11edfe240>],
#                'N23_sequence8': [<gap_checker.Indel at 0x11edfe2e8>],
#                'N25_N26': [<gap_checker.Indel at 0x11edfe358>,
#                 <gap_checker.Indel at 0x11edfe3c8>],
#                'N25_sequence12': [<gap_checker.Indel at 0x11edfe438>,
#                 <gap_checker.Indel at 0x11edfe4a8>,
#                 <gap_checker.Indel at 0x11edfe518>],
#                'N27_N28': [<gap_checker.Indel at 0x11edfe5c0>],
#                'N27_sequence27': [<gap_checker.Indel at 0x11edfe5f8>,
#                 <gap_checker.Indel at 0x11edfe630>,
#                 <gap_checker.Indel at 0x11edfe6a0>,
#                 <gap_checker.Indel at 0x11edfe748>,
#                 <gap_checker.Indel at 0x11edfe780>,
#                 <gap_checker.Indel at 0x11edfe7f0>],
#                'N7_sequence14': [<gap_checker.Indel at 0x11edfe860>],
#                'N7_sequence26': [<gap_checker.Indel at 0x11edfe8d0>],
#                'N26_sequence2': [<gap_checker.Indel at 0x11edfe978>,
#                 <gap_checker.Indel at 0x11edfe9e8>,
#                 <gap_checker.Indel at 0x11edfea58>],
#                'N26_sequence15': [],
#                'N28_sequence1': [],
#                'N28_sequence4': [<gap_checker.Indel at 0x11edfeb00>,
#                 <gap_checker.Indel at 0x11edfeb70>]},
#               '40': {'N0_N1': [<gap_checker.Indel at 0x11eb34160>,
#                 <gap_checker.Indel at 0x11ed7b860>],
#                'N0_N17': [<gap_checker.Indel at 0x11ed7b908>,
#                 <gap_checker.Indel at 0x11ed7b978>],
#                'N1_N2': [<gap_checker.Indel at 0x11ed7ba20>,
#                 <gap_checker.Indel at 0x11ed7ba58>],
#                'N1_N14': [],
#                'N17_sequence17': [<gap_checker.Indel at 0x11ed7bac8>,
#                 <gap_checker.Indel at 0x11ed7bb00>,
#                 <gap_checker.Indel at 0x11ed7bba8>,
#                 <gap_checker.Indel at 0x11ed7bbe0>,
#                 <gap_checker.Indel at 0x11ed7bc88>,
#                 <gap_checker.Indel at 0x11ed7bcf8>,
#                 <gap_checker.Indel at 0x11ed7bd68>],
#                'N17_N18': [<gap_checker.Indel at 0x11ed7be10>],
#                'N2_N3': [<gap_checker.Indel at 0x11ed7beb8>,
#                 <gap_checker.Indel at 0x11ed7bf60>,
#                 <gap_checker.Indel at 0x11ed7bfd0>],
#                'N2_N5': [],
#                'N14_sequence27': [<gap_checker.Indel at 0x11ed850b8>,
#                 <gap_checker.Indel at 0x11ed850f0>,
#                 <gap_checker.Indel at 0x11ed85160>],
#                'N14_N15': [<gap_checker.Indel at 0x11ed851d0>,
#                 <gap_checker.Indel at 0x11ed85240>,
#                 <gap_checker.Indel at 0x11ed852b0>],
#                'N18_N19': [<gap_checker.Indel at 0x11ed85358>,
#                 <gap_checker.Indel at 0x11ed853c8>,
#                 <gap_checker.Indel at 0x11ed85400>,
#                 <gap_checker.Indel at 0x11ed85470>],
#                'N18_N27': [],
#                'N3_N4': [<gap_checker.Indel at 0x11ed855c0>,
#                 <gap_checker.Indel at 0x11ed85630>],
#                'N3_sequence32': [<gap_checker.Indel at 0x11ed856a0>,
#                 <gap_checker.Indel at 0x11ed85710>,
#                 <gap_checker.Indel at 0x11ed857b8>,
#                 <gap_checker.Indel at 0x11ed857f0>,
#                 <gap_checker.Indel at 0x11ed85860>],
#                'N5_N6': [<gap_checker.Indel at 0x11ed858d0>],
#                'N5_N10': [<gap_checker.Indel at 0x11ed85978>,
#                 <gap_checker.Indel at 0x11ed859e8>,
#                 <gap_checker.Indel at 0x11ed85a20>,
#                 <gap_checker.Indel at 0x11ed85a90>],
#                'N15_sequence34': [<gap_checker.Indel at 0x11ed85b38>,
#                 <gap_checker.Indel at 0x11ed85ba8>],
#                'N15_N16': [<gap_checker.Indel at 0x11ed85c50>],
#                'N19_N20': [<gap_checker.Indel at 0x11ed85d30>,
#                 <gap_checker.Indel at 0x11ed85da0>,
#                 <gap_checker.Indel at 0x11ed85e10>],
#                'N19_N21': [],
#                'N27_N28': [<gap_checker.Indel at 0x11ed85ef0>,
#                 <gap_checker.Indel at 0x11ed85f28>],
#                'N27_N38': [<gap_checker.Indel at 0x11ed85fd0>,
#                 <gap_checker.Indel at 0x11ed860b8>,
#                 <gap_checker.Indel at 0x11ed86128>,
#                 <gap_checker.Indel at 0x11ed86160>,
#                 <gap_checker.Indel at 0x11ed861d0>,
#                 <gap_checker.Indel at 0x11ed86208>],
#                'N4_sequence5': [<gap_checker.Indel at 0x11ed86240>,
#                 <gap_checker.Indel at 0x11ed862b0>,
#                 <gap_checker.Indel at 0x11ed862e8>],
#                'N4_sequence13': [<gap_checker.Indel at 0x11ed86358>,
#                 <gap_checker.Indel at 0x11ed86390>,
#                 <gap_checker.Indel at 0x11ed86400>,
#                 <gap_checker.Indel at 0x11ed86470>,
#                 <gap_checker.Indel at 0x11ed86518>],
#                'N6_N7': [<gap_checker.Indel at 0x11ed865c0>,
#                 <gap_checker.Indel at 0x11ed86630>,
#                 <gap_checker.Indel at 0x11ed86668>,
#                 <gap_checker.Indel at 0x11ed866d8>,
#                 <gap_checker.Indel at 0x11ed86748>,
#                 <gap_checker.Indel at 0x11ed867b8>,
#                 <gap_checker.Indel at 0x11ed867f0>,
#                 <gap_checker.Indel at 0x11ed86898>],
#                'N6_N9': [<gap_checker.Indel at 0x11ed86940>,
#                 <gap_checker.Indel at 0x11ed86978>,
#                 <gap_checker.Indel at 0x11ed86a20>],
#                'N10_N11': [<gap_checker.Indel at 0x11ed86b00>],
#                'N10_sequence23': [<gap_checker.Indel at 0x11ed86b38>,
#                 <gap_checker.Indel at 0x11ed86ba8>,
#                 <gap_checker.Indel at 0x11ed86c50>,
#                 <gap_checker.Indel at 0x11ed86cc0>,
#                 <gap_checker.Indel at 0x11ed86d30>],
#                'N16_sequence25': [],
#                'N16_sequence7': [],
#                'N20_sequence29': [<gap_checker.Indel at 0x11ed86da0>,
#                 <gap_checker.Indel at 0x11ed86dd8>,
#                 <gap_checker.Indel at 0x11ed86e10>,
#                 <gap_checker.Indel at 0x11ed86e80>,
#                 <gap_checker.Indel at 0x11ed86ef0>],
#                'N20_sequence35': [<gap_checker.Indel at 0x11ed86f60>,
#                 <gap_checker.Indel at 0x11ed86f98>],
#                'N21_N22': [<gap_checker.Indel at 0x11ed92080>,
#                 <gap_checker.Indel at 0x11ed920f0>],
#                'N21_N25': [<gap_checker.Indel at 0x11ed92160>],
#                'N28_N29': [],
#                'N28_N32': [],
#                'N38_sequence3': [],
#                'N38_sequence22': [],
#                'N7_N8': [],
#                'N7_sequence16': [<gap_checker.Indel at 0x11ed92278>,
#                 <gap_checker.Indel at 0x11ed922b0>],
#                'N9_sequence26': [<gap_checker.Indel at 0x11ed92320>,
#                 <gap_checker.Indel at 0x11ed92358>],
#                'N9_sequence9': [<gap_checker.Indel at 0x11ed923c8>,
#                 <gap_checker.Indel at 0x11ed92438>,
#                 <gap_checker.Indel at 0x11ed924e0>],
#                'N11_N12': [],
#                'N11_sequence30': [<gap_checker.Indel at 0x11ed92588>,
#                 <gap_checker.Indel at 0x11ed92630>],
#                'N22_sequence21': [<gap_checker.Indel at 0x11ed926d8>,
#                 <gap_checker.Indel at 0x11ed92748>],
#                'N22_N23': [<gap_checker.Indel at 0x11ed927f0>,
#                 <gap_checker.Indel at 0x11ed92828>],
#                'N25_sequence15': [<gap_checker.Indel at 0x11ed92898>],
#                'N25_N26': [],
#                'N29_N30': [<gap_checker.Indel at 0x11ed92978>],
#                'N29_N31': [],
#                'N32_N33': [<gap_checker.Indel at 0x11ed92a58>],
#                'N32_sequence18': [<gap_checker.Indel at 0x11ed92ac8>,
#                 <gap_checker.Indel at 0x11ed92b00>,
#                 <gap_checker.Indel at 0x11ed92b70>],
#                'N8_sequence31': [<gap_checker.Indel at 0x11ed92ba8>,
#                 <gap_checker.Indel at 0x11ed92c18>],
#                'N8_sequence14': [<gap_checker.Indel at 0x11ed92c88>],
#                'N12_N13': [],
#                'N12_sequence2': [<gap_checker.Indel at 0x11ed92d68>],
#                'N23_sequence33': [<gap_checker.Indel at 0x11ed92dd8>],
#                'N23_N24': [],
#                'N26_sequence1': [<gap_checker.Indel at 0x11ed92e80>,
#                 <gap_checker.Indel at 0x11ed92f28>,
#                 <gap_checker.Indel at 0x11ed92f60>],
#                'N26_sequence6': [<gap_checker.Indel at 0x11ed92f98>],
#                'N30_sequence37': [],
#                'N30_sequence38': [],
#                'N31_sequence10': [],
#                'N31_sequence12': [<gap_checker.Indel at 0x11ed9f048>,
#                 <gap_checker.Indel at 0x11ed9f0b8>],
#                'N33_N34': [],
#                'N33_N35': [<gap_checker.Indel at 0x11ed9f160>],
#                'N13_sequence24': [],
#                'N13_sequence39': [<gap_checker.Indel at 0x11ed9f198>],
#                'N24_sequence8': [<gap_checker.Indel at 0x11ed9f240>],
#                'N24_sequence4': [],
#                'N34_sequence40': [],
#                'N34_sequence11': [],
#                'N35_N36': [<gap_checker.Indel at 0x11ed9f2b0>],
#                'N35_sequence20': [<gap_checker.Indel at 0x11ed9f358>],
#                'N36_sequence28': [],
#                'N36_N37': [],
#                'N37_sequence19': [<gap_checker.Indel at 0x11ed9f438>],
#                'N37_sequence36': []},
#               '50': {'N0_N1': [<gap_checker.Indel at 0x11edc9828>,
#                 <gap_checker.Indel at 0x11ed16470>,
#                 <gap_checker.Indel at 0x11ed16518>,
#                 <gap_checker.Indel at 0x11ed16588>],
#                'N0_N3': [],
#                'N1_N2': [],
#                'N1_sequence30': [],
#                'N3_N4': [<gap_checker.Indel at 0x11ed166d8>,
#                 <gap_checker.Indel at 0x11ed16780>],
#                'N3_N27': [<gap_checker.Indel at 0x11ed167f0>],
#                'N2_sequence13': [<gap_checker.Indel at 0x11ed16828>,
#                 <gap_checker.Indel at 0x11ed168d0>],
#                'N2_sequence16': [<gap_checker.Indel at 0x11ed16940>],
#                'N4_N5': [],
#                'N4_N21': [],
#                'N27_N28': [<gap_checker.Indel at 0x11ed16a20>],
#                'N27_N37': [],
#                'N5_sequence2': [<gap_checker.Indel at 0x11ed16a90>,
#                 <gap_checker.Indel at 0x11ed16b00>,
#                 <gap_checker.Indel at 0x11ed16b38>,
#                 <gap_checker.Indel at 0x11ed16ba8>],
#                'N5_N6': [<gap_checker.Indel at 0x11ed16c88>],
#                'N21_N22': [<gap_checker.Indel at 0x11ed16d30>,
#                 <gap_checker.Indel at 0x11ed16d68>],
#                'N21_N26': [<gap_checker.Indel at 0x11ed16e48>,
#                 <gap_checker.Indel at 0x11ed16e80>,
#                 <gap_checker.Indel at 0x11ed16ef0>],
#                'N28_N29': [],
#                'N28_N35': [],
#                'N37_N38': [<gap_checker.Indel at 0x11ed1a048>],
#                'N37_N47': [<gap_checker.Indel at 0x11ed1a0f0>,
#                 <gap_checker.Indel at 0x11ed1a128>,
#                 <gap_checker.Indel at 0x11ed1a198>],
#                'N6_N7': [<gap_checker.Indel at 0x11ed1a240>],
#                'N6_N15': [<gap_checker.Indel at 0x11ed1a2e8>,
#                 <gap_checker.Indel at 0x11ed1a358>,
#                 <gap_checker.Indel at 0x11ed1a3c8>],
#                'N22_sequence26': [<gap_checker.Indel at 0x11ed1a400>,
#                 <gap_checker.Indel at 0x11ed1a438>,
#                 <gap_checker.Indel at 0x11ed1a470>],
#                'N22_N23': [<gap_checker.Indel at 0x11ed1a518>],
#                'N26_sequence43': [<gap_checker.Indel at 0x11ed1a5c0>,
#                 <gap_checker.Indel at 0x11ed1a668>,
#                 <gap_checker.Indel at 0x11ed1a6a0>,
#                 <gap_checker.Indel at 0x11ed1a710>],
#                'N26_sequence48': [<gap_checker.Indel at 0x11ed1a780>,
#                 <gap_checker.Indel at 0x11ed1a828>,
#                 <gap_checker.Indel at 0x11ed1a860>],
#                'N29_N30': [<gap_checker.Indel at 0x11ed1a908>],
#                'N29_N31': [<gap_checker.Indel at 0x11ed1a9b0>],
#                'N35_N36': [],
#                'N35_sequence37': [<gap_checker.Indel at 0x11ed1aa58>,
#                 <gap_checker.Indel at 0x11ed1aa90>,
#                 <gap_checker.Indel at 0x11ed1aac8>,
#                 <gap_checker.Indel at 0x11ed1ab38>],
#                'N38_N39': [<gap_checker.Indel at 0x11ed1ac18>],
#                'N38_N40': [<gap_checker.Indel at 0x11ed1ac88>],
#                'N47_N48': [<gap_checker.Indel at 0x11ed1acf8>,
#                 <gap_checker.Indel at 0x11ed1ad30>,
#                 <gap_checker.Indel at 0x11ed1ada0>,
#                 <gap_checker.Indel at 0x11ed1ae10>],
#                'N47_sequence34': [<gap_checker.Indel at 0x11ed1aeb8>,
#                 <gap_checker.Indel at 0x11ed1af28>,
#                 <gap_checker.Indel at 0x11ed1af98>,
#                 <gap_checker.Indel at 0x11ed1e048>],
#                'N7_N8': [],
#                'N7_sequence20': [<gap_checker.Indel at 0x11ed1e0f0>,
#                 <gap_checker.Indel at 0x11ed1e128>,
#                 <gap_checker.Indel at 0x11ed1e198>],
#                'N15_N16': [<gap_checker.Indel at 0x11ed1e240>,
#                 <gap_checker.Indel at 0x11ed1e2b0>],
#                'N15_N17': [<gap_checker.Indel at 0x11ed1e320>],
#                'N23_N24': [],
#                'N23_N25': [<gap_checker.Indel at 0x11ed1e400>,
#                 <gap_checker.Indel at 0x11ed1e4a8>],
#                'N30_sequence18': [<gap_checker.Indel at 0x11ed1e4e0>],
#                'N30_sequence40': [<gap_checker.Indel at 0x11ed1e550>,
#                 <gap_checker.Indel at 0x11ed1e588>],
#                'N31_N32': [<gap_checker.Indel at 0x11ed1e630>],
#                'N31_N34': [<gap_checker.Indel at 0x11ed1e6d8>,
#                 <gap_checker.Indel at 0x11ed1e710>],
#                'N36_sequence38': [<gap_checker.Indel at 0x11ed1e780>],
#                'N36_sequence17': [],
#                'N39_sequence33': [<gap_checker.Indel at 0x11ed1e828>,
#                 <gap_checker.Indel at 0x11ed1e898>],
#                'N39_sequence27': [<gap_checker.Indel at 0x11ed1e908>,
#                 <gap_checker.Indel at 0x11ed1e978>],
#                'N40_N41': [<gap_checker.Indel at 0x11ed1ea20>],
#                'N40_N43': [],
#                'N48_sequence10': [],
#                'N48_sequence5': [],
#                'N8_N9': [],
#                'N8_N14': [<gap_checker.Indel at 0x11ed1eb38>,
#                 <gap_checker.Indel at 0x11ed1eba8>,
#                 <gap_checker.Indel at 0x11ed1ec50>],
#                'N16_sequence15': [<gap_checker.Indel at 0x11ed1ecc0>,
#                 <gap_checker.Indel at 0x11ed1ed30>],
#                'N16_sequence45': [<gap_checker.Indel at 0x11ed1eda0>,
#                 <gap_checker.Indel at 0x11ed1ee10>,
#                 <gap_checker.Indel at 0x11ed1ee48>,
#                 <gap_checker.Indel at 0x11ed1eeb8>,
#                 <gap_checker.Indel at 0x11ed1ef28>,
#                 <gap_checker.Indel at 0x11ed1efd0>],
#                'N17_N18': [<gap_checker.Indel at 0x11ed2a0b8>],
#                'N17_sequence21': [],
#                'N24_sequence28': [<gap_checker.Indel at 0x11ed2a128>],
#                'N24_sequence6': [<gap_checker.Indel at 0x11ed2a198>,
#                 <gap_checker.Indel at 0x11ed2a208>],
#                'N25_sequence32': [],
#                'N25_sequence9': [],
#                'N32_N33': [<gap_checker.Indel at 0x11ed2a2b0>],
#                'N32_sequence49': [<gap_checker.Indel at 0x11ed2a320>,
#                 <gap_checker.Indel at 0x11ed2a3c8>],
#                'N34_sequence3': [<gap_checker.Indel at 0x11ed2a438>],
#                'N34_sequence29': [<gap_checker.Indel at 0x11ed2a4a8>],
#                'N41_sequence23': [<gap_checker.Indel at 0x11ed2a518>,
#                 <gap_checker.Indel at 0x11ed2a588>,
#                 <gap_checker.Indel at 0x11ed2a630>,
#                 <gap_checker.Indel at 0x11ed2a6a0>,
#                 <gap_checker.Indel at 0x11ed2a710>],
#                'N41_N42': [],
#                'N43_N44': [],
#                'N43_N46': [],
#                'N9_N10': [<gap_checker.Indel at 0x11ed2a860>],
#                'N9_N12': [],
#                'N14_sequence46': [],
#                'N14_sequence47': [<gap_checker.Indel at 0x11ed2a908>],
#                'N18_N19': [],
#                'N18_sequence8': [<gap_checker.Indel at 0x11ed2a9b0>,
#                 <gap_checker.Indel at 0x11ed2a9e8>,
#                 <gap_checker.Indel at 0x11ed2aa58>],
#                'N33_sequence42': [],
#                'N33_sequence4': [<gap_checker.Indel at 0x11ed2aac8>],
#                'N42_sequence39': [<gap_checker.Indel at 0x11ed2ab38>,
#                 <gap_checker.Indel at 0x11ed2ab70>,
#                 <gap_checker.Indel at 0x11ed2abe0>],
#                'N42_sequence35': [<gap_checker.Indel at 0x11ed2ac50>,
#                 <gap_checker.Indel at 0x11ed2ac88>,
#                 <gap_checker.Indel at 0x11ed2acf8>],
#                'N44_sequence12': [],
#                'N44_N45': [],
#                'N46_sequence1': [],
#                'N46_sequence7': [<gap_checker.Indel at 0x11ed2ada0>],
#                'N10_N11': [<gap_checker.Indel at 0x11ed2ae48>],
#                'N10_sequence44': [<gap_checker.Indel at 0x11ed2aeb8>],
#                'N12_sequence36': [<gap_checker.Indel at 0x11ed2af28>],
#                'N12_N13': [],
#                'N19_N20': [],
#                'N19_sequence22': [<gap_checker.Indel at 0x11ed37048>],
#                'N45_sequence25': [<gap_checker.Indel at 0x11ed37080>],
#                'N45_sequence14': [<gap_checker.Indel at 0x11ed370f0>,
#                 <gap_checker.Indel at 0x11ed37160>],
#                'N11_sequence31': [],
#                'N11_sequence11': [<gap_checker.Indel at 0x11ed371d0>],
#                'N13_sequence24': [],
#                'N13_sequence50': [],
#                'N20_sequence41': [],
#                'N20_sequence19': [<gap_checker.Indel at 0x11ed37240>,
#                 <gap_checker.Indel at 0x11ed372b0>]}},
#              'PSML': {'10': {'N0_N1': [],
#                'N0_sequence5': [<gap_checker.Indel at 0x11e02ccc0>,
#                 <gap_checker.Indel at 0x11e483940>,
#                 <gap_checker.Indel at 0x11e483978>,
#                 <gap_checker.Indel at 0x11e483080>,
#                 <gap_checker.Indel at 0x11e483160>,
#                 <gap_checker.Indel at 0x11e483b38>,
#                 <gap_checker.Indel at 0x11e4831d0>,
#                 <gap_checker.Indel at 0x11e069ef0>,
#                 <gap_checker.Indel at 0x11e0de630>,
#                 <gap_checker.Indel at 0x11e0de668>,
#                 <gap_checker.Indel at 0x11e0de5f8>,
#                 <gap_checker.Indel at 0x11e0de588>,
#                 <gap_checker.Indel at 0x11e0de400>,
#                 <gap_checker.Indel at 0x11e0de470>,
#                 <gap_checker.Indel at 0x11e0de390>,
#                 <gap_checker.Indel at 0x11e0de278>,
#                 <gap_checker.Indel at 0x11e0de2b0>,
#                 <gap_checker.Indel at 0x11e0de358>,
#                 <gap_checker.Indel at 0x11e0de1d0>,
#                 <gap_checker.Indel at 0x11e0de160>],
#                'N1_sequence3': [<gap_checker.Indel at 0x11e0de518>,
#                 <gap_checker.Indel at 0x11e0de080>,
#                 <gap_checker.Indel at 0x11e0de0f0>,
#                 <gap_checker.Indel at 0x11e0de710>,
#                 <gap_checker.Indel at 0x11e4222b0>,
#                 <gap_checker.Indel at 0x11e4229b0>,
#                 <gap_checker.Indel at 0x11e422eb8>,
#                 <gap_checker.Indel at 0x11e422f60>,
#                 <gap_checker.Indel at 0x11e422f98>,
#                 <gap_checker.Indel at 0x11e422d68>,
#                 <gap_checker.Indel at 0x11e422da0>,
#                 <gap_checker.Indel at 0x11e422dd8>,
#                 <gap_checker.Indel at 0x11e422e10>,
#                 <gap_checker.Indel at 0x11e422a58>,
#                 <gap_checker.Indel at 0x11e422ac8>],
#                'N1_N2': [],
#                'N2_N3': [],
#                'N2_N7': [],
#                'N3_N4': [],
#                'N3_N5': [<gap_checker.Indel at 0x11e422c18>,
#                 <gap_checker.Indel at 0x11e422cc0>,
#                 <gap_checker.Indel at 0x11e422978>,
#                 <gap_checker.Indel at 0x11e4227b8>,
#                 <gap_checker.Indel at 0x11e422860>,
#                 <gap_checker.Indel at 0x11e422898>,
#                 <gap_checker.Indel at 0x11e422780>,
#                 <gap_checker.Indel at 0x11e422630>,
#                 <gap_checker.Indel at 0x11e4226a0>,
#                 <gap_checker.Indel at 0x11e4226d8>,
#                 <gap_checker.Indel at 0x11e422748>],
#                'N7_sequence8': [<gap_checker.Indel at 0x11e422438>,
#                 <gap_checker.Indel at 0x11e422470>,
#                 <gap_checker.Indel at 0x11e4224a8>,
#                 <gap_checker.Indel at 0x11e422518>,
#                 <gap_checker.Indel at 0x11e422550>,
#                 <gap_checker.Indel at 0x11e4225c0>,
#                 <gap_checker.Indel at 0x11e422320>,
#                 <gap_checker.Indel at 0x11e422278>,
#                 <gap_checker.Indel at 0x11e422208>,
#                 <gap_checker.Indel at 0x11e1f3438>,
#                 <gap_checker.Indel at 0x11e1f3400>,
#                 <gap_checker.Indel at 0x11e1f33c8>],
#                'N7_N8': [<gap_checker.Indel at 0x11e211f60>,
#                 <gap_checker.Indel at 0x11e211cf8>,
#                 <gap_checker.Indel at 0x11e211dd8>,
#                 <gap_checker.Indel at 0x11e211e48>,
#                 <gap_checker.Indel at 0x11e211e80>,
#                 <gap_checker.Indel at 0x11e211eb8>,
#                 <gap_checker.Indel at 0x11e211fd0>,
#                 <gap_checker.Indel at 0x11e211c88>,
#                 <gap_checker.Indel at 0x11e1a86a0>,
#                 <gap_checker.Indel at 0x11e1a8668>,
#                 <gap_checker.Indel at 0x11e1a8550>],
#                'N4_sequence4': [<gap_checker.Indel at 0x11e1a85c0>,
#                 <gap_checker.Indel at 0x11e1a8588>,
#                 <gap_checker.Indel at 0x11e1a8518>,
#                 <gap_checker.Indel at 0x11e1c9b70>,
#                 <gap_checker.Indel at 0x11e1c97b8>,
#                 <gap_checker.Indel at 0x11e257cf8>,
#                 <gap_checker.Indel at 0x11e257cc0>,
#                 <gap_checker.Indel at 0x11e257c88>,
#                 <gap_checker.Indel at 0x11e257c18>,
#                 <gap_checker.Indel at 0x11e257198>],
#                'N4_sequence6': [<gap_checker.Indel at 0x11e257080>,
#                 <gap_checker.Indel at 0x11e2570f0>,
#                 <gap_checker.Indel at 0x11e257160>,
#                 <gap_checker.Indel at 0x11e2571d0>,
#                 <gap_checker.Indel at 0x11e257240>,
#                 <gap_checker.Indel at 0x11e2572e8>],
#                'N5_sequence7': [<gap_checker.Indel at 0x11e257358>,
#                 <gap_checker.Indel at 0x11e2573c8>,
#                 <gap_checker.Indel at 0x11e257400>,
#                 <gap_checker.Indel at 0x11e257588>,
#                 <gap_checker.Indel at 0x11e257a20>,
#                 <gap_checker.Indel at 0x11e0e2ac8>],
#                'N5_N6': [],
#                'N8_sequence10': [<gap_checker.Indel at 0x11e0e2b70>],
#                'N8_sequence9': [],
#                'N6_sequence2': [<gap_checker.Indel at 0x11e0e2be0>],
#                'N6_sequence1': []},
#               '20': {'N0_N1': [],
#                'N0_N17': [<gap_checker.Indel at 0x11e0fc550>,
#                 <gap_checker.Indel at 0x11e169f28>,
#                 <gap_checker.Indel at 0x11e169f60>,
#                 <gap_checker.Indel at 0x11e17a048>,
#                 <gap_checker.Indel at 0x11e17a0f0>,
#                 <gap_checker.Indel at 0x11e17a160>,
#                 <gap_checker.Indel at 0x11e17a208>,
#                 <gap_checker.Indel at 0x11e17a278>,
#                 <gap_checker.Indel at 0x11e17a320>,
#                 <gap_checker.Indel at 0x11e17a358>,
#                 <gap_checker.Indel at 0x11e17a3c8>,
#                 <gap_checker.Indel at 0x11e17a400>],
#                'N1_N2': [],
#                'N1_N3': [],
#                'N17_N18': [],
#                'N17_sequence3': [<gap_checker.Indel at 0x11e17a518>],
#                'N2_sequence12': [<gap_checker.Indel at 0x11e17a588>,
#                 <gap_checker.Indel at 0x11e17a5f8>,
#                 <gap_checker.Indel at 0x11e17a630>,
#                 <gap_checker.Indel at 0x11e17a6a0>,
#                 <gap_checker.Indel at 0x11e17a710>,
#                 <gap_checker.Indel at 0x11e17a780>,
#                 <gap_checker.Indel at 0x11e17a7f0>,
#                 <gap_checker.Indel at 0x11e17a898>,
#                 <gap_checker.Indel at 0x11e17a940>,
#                 <gap_checker.Indel at 0x11e17a9b0>,
#                 <gap_checker.Indel at 0x11e17aa20>,
#                 <gap_checker.Indel at 0x11e17aa90>,
#                 <gap_checker.Indel at 0x11e17ab00>],
#                'N2_sequence8': [<gap_checker.Indel at 0x11e17ab70>,
#                 <gap_checker.Indel at 0x11e17ac18>,
#                 <gap_checker.Indel at 0x11e17acc0>,
#                 <gap_checker.Indel at 0x11e17ad30>,
#                 <gap_checker.Indel at 0x11e17ad68>,
#                 <gap_checker.Indel at 0x11e17ada0>,
#                 <gap_checker.Indel at 0x11e17ae10>,
#                 <gap_checker.Indel at 0x11e17ae80>,
#                 <gap_checker.Indel at 0x11e17aef0>,
#                 <gap_checker.Indel at 0x11e17af60>,
#                 <gap_checker.Indel at 0x11e17afd0>,
#                 <gap_checker.Indel at 0x11e17d048>,
#                 <gap_checker.Indel at 0x11e17d0f0>],
#                'N3_N4': [],
#                'N3_N11': [<gap_checker.Indel at 0x11e17d1d0>,
#                 <gap_checker.Indel at 0x11e17d240>,
#                 <gap_checker.Indel at 0x11e17d2e8>,
#                 <gap_checker.Indel at 0x11e17d358>,
#                 <gap_checker.Indel at 0x11e17d3c8>,
#                 <gap_checker.Indel at 0x11e17d438>,
#                 <gap_checker.Indel at 0x11e17d4a8>,
#                 <gap_checker.Indel at 0x11e17d4e0>,
#                 <gap_checker.Indel at 0x11e17d550>,
#                 <gap_checker.Indel at 0x11e17d5c0>,
#                 <gap_checker.Indel at 0x11e17d630>,
#                 <gap_checker.Indel at 0x11e17d668>,
#                 <gap_checker.Indel at 0x11e17d6d8>],
#                'N18_sequence9': [<gap_checker.Indel at 0x11e17d710>,
#                 <gap_checker.Indel at 0x11e17d780>],
#                'N18_sequence18': [<gap_checker.Indel at 0x11e17d7b8>,
#                 <gap_checker.Indel at 0x11e17d7f0>],
#                'N4_N5': [],
#                'N4_N8': [<gap_checker.Indel at 0x11e17d898>,
#                 <gap_checker.Indel at 0x11e17d8d0>,
#                 <gap_checker.Indel at 0x11e17d908>,
#                 <gap_checker.Indel at 0x11e17d978>,
#                 <gap_checker.Indel at 0x11e17d9e8>,
#                 <gap_checker.Indel at 0x11e17da58>,
#                 <gap_checker.Indel at 0x11e17da90>,
#                 <gap_checker.Indel at 0x11e17db00>,
#                 <gap_checker.Indel at 0x11e17db70>,
#                 <gap_checker.Indel at 0x11e17dbe0>,
#                 <gap_checker.Indel at 0x11e17dc50>,
#                 <gap_checker.Indel at 0x11e17dcc0>,
#                 <gap_checker.Indel at 0x11e17dd68>],
#                'N11_N12': [],
#                'N11_sequence5': [<gap_checker.Indel at 0x11e17de10>,
#                 <gap_checker.Indel at 0x11e17de80>,
#                 <gap_checker.Indel at 0x11e17def0>,
#                 <gap_checker.Indel at 0x11e17df60>,
#                 <gap_checker.Indel at 0x11e186048>,
#                 <gap_checker.Indel at 0x11e1860b8>,
#                 <gap_checker.Indel at 0x11e186128>,
#                 <gap_checker.Indel at 0x11e186198>,
#                 <gap_checker.Indel at 0x11e186208>,
#                 <gap_checker.Indel at 0x11e186240>,
#                 <gap_checker.Indel at 0x11e1862b0>,
#                 <gap_checker.Indel at 0x11e186320>,
#                 <gap_checker.Indel at 0x11e186390>,
#                 <gap_checker.Indel at 0x11e186400>,
#                 <gap_checker.Indel at 0x11e186470>],
#                'N5_sequence6': [<gap_checker.Indel at 0x11e1864e0>,
#                 <gap_checker.Indel at 0x11e186550>,
#                 <gap_checker.Indel at 0x11e1865c0>,
#                 <gap_checker.Indel at 0x11e186630>,
#                 <gap_checker.Indel at 0x11e1866a0>,
#                 <gap_checker.Indel at 0x11e1866d8>,
#                 <gap_checker.Indel at 0x11e186780>,
#                 <gap_checker.Indel at 0x11e1867b8>,
#                 <gap_checker.Indel at 0x11e186828>,
#                 <gap_checker.Indel at 0x11e186898>,
#                 <gap_checker.Indel at 0x11e186908>,
#                 <gap_checker.Indel at 0x11e1869b0>,
#                 <gap_checker.Indel at 0x11e1869e8>,
# ...
#                'N2_N3': [<gap_checker.Indel at 0x11ecb4cc0>],
#                'N2_N5': [],
#                'N14_sequence27': [<gap_checker.Indel at 0x11ecb4d68>,
#                 <gap_checker.Indel at 0x11ecb4dd8>,
#                 <gap_checker.Indel at 0x11ecb4e10>,
#                 <gap_checker.Indel at 0x11ecb4e80>,
#                 <gap_checker.Indel at 0x11ecb4ef0>],
#                'N14_N15': [<gap_checker.Indel at 0x11ecb4f60>],
#                'N18_N19': [<gap_checker.Indel at 0x11ecbb048>,
#                 <gap_checker.Indel at 0x11ecbb0b8>,
#                 <gap_checker.Indel at 0x11ecbb0f0>,
#                 <gap_checker.Indel at 0x11ecbb160>],
#                'N18_N27': [],
#                'N3_N4': [<gap_checker.Indel at 0x11ecbb2b0>,
#                 <gap_checker.Indel at 0x11ecbb358>,
#                 <gap_checker.Indel at 0x11ecbb400>],
#                'N3_sequence32': [<gap_checker.Indel at 0x11ecbb4a8>,
#                 <gap_checker.Indel at 0x11ecbb518>,
#                 <gap_checker.Indel at 0x11ecbb5c0>,
#                 <gap_checker.Indel at 0x11ecbb630>,
#                 <gap_checker.Indel at 0x11ecbb6a0>,
#                 <gap_checker.Indel at 0x11ecbb710>],
#                'N5_N6': [],
#                'N5_N10': [<gap_checker.Indel at 0x11ecbb7b8>,
#                 <gap_checker.Indel at 0x11ecbb828>,
#                 <gap_checker.Indel at 0x11ecbb860>,
#                 <gap_checker.Indel at 0x11ecbb908>],
#                'N15_sequence34': [<gap_checker.Indel at 0x11ecbb9b0>,
#                 <gap_checker.Indel at 0x11ecbba20>],
#                'N15_N16': [<gap_checker.Indel at 0x11ecbbac8>],
#                'N19_N20': [<gap_checker.Indel at 0x11ecbbba8>],
#                'N19_N21': [],
#                'N27_N28': [<gap_checker.Indel at 0x11ecbbc88>,
#                 <gap_checker.Indel at 0x11ecbbcc0>],
#                'N27_N38': [<gap_checker.Indel at 0x11ecbbd68>,
#                 <gap_checker.Indel at 0x11ecbbe10>,
#                 <gap_checker.Indel at 0x11ecbbe80>,
#                 <gap_checker.Indel at 0x11ecbbeb8>,
#                 <gap_checker.Indel at 0x11ecbbf28>,
#                 <gap_checker.Indel at 0x11ecbbf60>],
#                'N4_sequence5': [<gap_checker.Indel at 0x11ecbbf98>,
#                 <gap_checker.Indel at 0x11ecbf048>,
#                 <gap_checker.Indel at 0x11ecbf080>,
#                 <gap_checker.Indel at 0x11ecbf0f0>,
#                 <gap_checker.Indel at 0x11ecbf160>],
#                'N4_sequence13': [<gap_checker.Indel at 0x11ecbf208>,
#                 <gap_checker.Indel at 0x11ecbf240>,
#                 <gap_checker.Indel at 0x11ecbf2b0>],
#                'N6_N7': [<gap_checker.Indel at 0x11ecbf358>,
#                 <gap_checker.Indel at 0x11ecbf400>,
#                 <gap_checker.Indel at 0x11ecbf438>,
#                 <gap_checker.Indel at 0x11ecbf4a8>,
#                 <gap_checker.Indel at 0x11ecbf518>,
#                 <gap_checker.Indel at 0x11ecbf588>,
#                 <gap_checker.Indel at 0x11ecbf5c0>,
#                 <gap_checker.Indel at 0x11ecbf668>],
#                'N6_N9': [<gap_checker.Indel at 0x11ecbf710>,
#                 <gap_checker.Indel at 0x11ecbf748>,
#                 <gap_checker.Indel at 0x11ecbf7f0>,
#                 <gap_checker.Indel at 0x11ecbf860>],
#                'N10_N11': [],
#                'N10_sequence23': [<gap_checker.Indel at 0x11ecbf908>,
#                 <gap_checker.Indel at 0x11ecbf978>,
#                 <gap_checker.Indel at 0x11ecbf9b0>,
#                 <gap_checker.Indel at 0x11ecbfa58>,
#                 <gap_checker.Indel at 0x11ecbfac8>,
#                 <gap_checker.Indel at 0x11ecbfb38>],
#                'N16_sequence25': [],
#                'N16_sequence7': [],
#                'N20_sequence29': [<gap_checker.Indel at 0x11ecbfba8>,
#                 <gap_checker.Indel at 0x11ecbfbe0>,
#                 <gap_checker.Indel at 0x11ecbfc50>,
#                 <gap_checker.Indel at 0x11ecbfc88>,
#                 <gap_checker.Indel at 0x11ecbfcf8>],
#                'N20_sequence35': [<gap_checker.Indel at 0x11ecbfd68>,
#                 <gap_checker.Indel at 0x11ecbfda0>],
#                'N21_N22': [<gap_checker.Indel at 0x11ecbfe48>],
#                'N21_N25': [<gap_checker.Indel at 0x11ecbfef0>],
#                'N28_N29': [],
#                'N28_N32': [],
#                'N38_sequence3': [],
#                'N38_sequence22': [],
#                'N7_N8': [],
#                'N7_sequence16': [<gap_checker.Indel at 0x11ecc8048>,
#                 <gap_checker.Indel at 0x11ecc80f0>],
#                'N9_sequence26': [<gap_checker.Indel at 0x11ecc8160>,
#                 <gap_checker.Indel at 0x11ecc8208>,
#                 <gap_checker.Indel at 0x11ecc8278>,
#                 <gap_checker.Indel at 0x11ecc82e8>],
#                'N9_sequence9': [<gap_checker.Indel at 0x11ecc8390>,
#                 <gap_checker.Indel at 0x11ecc8400>],
#                'N11_N12': [],
#                'N11_sequence30': [<gap_checker.Indel at 0x11ecc84e0>,
#                 <gap_checker.Indel at 0x11ecc8588>],
#                'N22_sequence21': [<gap_checker.Indel at 0x11ecc8630>,
#                 <gap_checker.Indel at 0x11ecc86a0>,
#                 <gap_checker.Indel at 0x11ecc8710>],
#                'N22_N23': [<gap_checker.Indel at 0x11ecc87b8>],
#                'N25_sequence15': [<gap_checker.Indel at 0x11ecc87f0>],
#                'N25_N26': [],
#                'N29_N30': [<gap_checker.Indel at 0x11ecc88d0>],
#                'N29_N31': [],
#                'N32_N33': [<gap_checker.Indel at 0x11ecc89b0>],
#                'N32_sequence18': [<gap_checker.Indel at 0x11ecc8a20>,
#                 <gap_checker.Indel at 0x11ecc8a58>,
#                 <gap_checker.Indel at 0x11ecc8ac8>],
#                'N8_sequence31': [<gap_checker.Indel at 0x11ecc8b00>,
#                 <gap_checker.Indel at 0x11ecc8ba8>,
#                 <gap_checker.Indel at 0x11ecc8c18>],
#                'N8_sequence14': [],
#                'N12_N13': [],
#                'N12_sequence2': [<gap_checker.Indel at 0x11ecc8cc0>],
#                'N23_sequence33': [<gap_checker.Indel at 0x11ecc8d30>],
#                'N23_N24': [],
#                'N26_sequence1': [<gap_checker.Indel at 0x11ecc8dd8>,
#                 <gap_checker.Indel at 0x11ecc8e80>,
#                 <gap_checker.Indel at 0x11ecc8eb8>],
#                'N26_sequence6': [<gap_checker.Indel at 0x11ecc8ef0>],
#                'N30_sequence37': [],
#                'N30_sequence38': [],
#                'N31_sequence10': [],
#                'N31_sequence12': [<gap_checker.Indel at 0x11ecc8f60>,
#                 <gap_checker.Indel at 0x11ecc8fd0>],
#                'N33_N34': [],
#                'N33_N35': [<gap_checker.Indel at 0x11ed160b8>],
#                'N13_sequence24': [],
#                'N13_sequence39': [<gap_checker.Indel at 0x11ed160f0>],
#                'N24_sequence8': [<gap_checker.Indel at 0x11ed16198>],
#                'N24_sequence4': [],
#                'N34_sequence40': [],
#                'N34_sequence11': [],
#                'N35_N36': [<gap_checker.Indel at 0x11ed16208>],
#                'N35_sequence20': [<gap_checker.Indel at 0x11ed162b0>],
#                'N36_sequence28': [],
#                'N36_N37': [],
#                'N37_sequence19': [<gap_checker.Indel at 0x11ed16390>],
#                'N37_sequence36': []},
#               '50': {'N0_N1': [<gap_checker.Indel at 0x11ed37390>,
#                 <gap_checker.Indel at 0x11e4d3278>,
#                 <gap_checker.Indel at 0x11e4d32b0>,
#                 <gap_checker.Indel at 0x11e4d3320>,
#                 <gap_checker.Indel at 0x11e4d33c8>,
#                 <gap_checker.Indel at 0x11e4d3438>,
#                 <gap_checker.Indel at 0x11e4d34a8>],
#                'N0_N3': [],
#                'N1_N2': [],
#                'N1_sequence30': [<gap_checker.Indel at 0x11e4d35c0>],
#                'N3_N4': [],
#                'N3_N27': [<gap_checker.Indel at 0x11e4d36d8>,
#                 <gap_checker.Indel at 0x11e4d3748>,
#                 <gap_checker.Indel at 0x11e4d3780>],
#                'N2_sequence13': [<gap_checker.Indel at 0x11e4d3828>],
#                'N2_sequence16': [<gap_checker.Indel at 0x11e4d3898>],
#                'N4_N5': [],
#                'N4_N21': [],
#                'N27_N28': [],
#                'N27_N37': [],
#                'N5_sequence2': [<gap_checker.Indel at 0x11e4d3a20>,
#                 <gap_checker.Indel at 0x11e4d3a90>,
#                 <gap_checker.Indel at 0x11e4d3ac8>,
#                 <gap_checker.Indel at 0x11e4d3b38>],
#                'N5_N6': [],
#                'N21_N22': [<gap_checker.Indel at 0x11e4d3c50>,
#                 <gap_checker.Indel at 0x11e4d3c88>,
#                 <gap_checker.Indel at 0x11e4d3cf8>],
#                'N21_N26': [<gap_checker.Indel at 0x11e4d3dd8>,
#                 <gap_checker.Indel at 0x11e4d3e10>],
#                'N28_N29': [],
#                'N28_N35': [],
#                'N37_N38': [<gap_checker.Indel at 0x11e4d3f28>],
#                'N37_N47': [<gap_checker.Indel at 0x11e4d3fd0>,
#                 <gap_checker.Indel at 0x11eb50080>,
#                 <gap_checker.Indel at 0x11eb500f0>],
#                'N6_N7': [<gap_checker.Indel at 0x11eb50198>],
#                'N6_N15': [<gap_checker.Indel at 0x11eb50240>,
#                 <gap_checker.Indel at 0x11eb502b0>],
#                'N22_sequence26': [<gap_checker.Indel at 0x11eb50320>,
#                 <gap_checker.Indel at 0x11eb50358>,
#                 <gap_checker.Indel at 0x11eb50390>],
#                'N22_N23': [<gap_checker.Indel at 0x11eb50438>],
#                'N26_sequence43': [<gap_checker.Indel at 0x11eb504e0>,
#                 <gap_checker.Indel at 0x11eb50588>,
#                 <gap_checker.Indel at 0x11eb505c0>,
#                 <gap_checker.Indel at 0x11eb50630>],
#                'N26_sequence48': [<gap_checker.Indel at 0x11eb506a0>,
#                 <gap_checker.Indel at 0x11eb50748>,
#                 <gap_checker.Indel at 0x11eb50780>],
#                'N29_N30': [<gap_checker.Indel at 0x11eb50828>],
#                'N29_N31': [],
#                'N35_N36': [],
#                'N35_sequence37': [<gap_checker.Indel at 0x11eb50908>,
#                 <gap_checker.Indel at 0x11eb50940>,
#                 <gap_checker.Indel at 0x11eb50978>,
#                 <gap_checker.Indel at 0x11eb509e8>],
#                'N38_N39': [<gap_checker.Indel at 0x11eb50ac8>,
#                 <gap_checker.Indel at 0x11eb50b00>],
#                'N38_N40': [],
#                'N47_N48': [<gap_checker.Indel at 0x11eb50ba8>,
#                 <gap_checker.Indel at 0x11eb50be0>,
#                 <gap_checker.Indel at 0x11eb50c50>,
#                 <gap_checker.Indel at 0x11eb50cc0>],
#                'N47_sequence34': [<gap_checker.Indel at 0x11eb50d68>,
#                 <gap_checker.Indel at 0x11eb50dd8>,
#                 <gap_checker.Indel at 0x11eb50e48>,
#                 <gap_checker.Indel at 0x11eb50eb8>],
#                'N7_N8': [],
#                'N7_sequence20': [<gap_checker.Indel at 0x11eb50f60>,
#                 <gap_checker.Indel at 0x11eb50f98>,
#                 <gap_checker.Indel at 0x11eb53048>],
#                'N15_N16': [],
#                'N15_N17': [<gap_checker.Indel at 0x11eb53128>,
#                 <gap_checker.Indel at 0x11eb53198>],
#                'N23_N24': [],
#                'N23_N25': [<gap_checker.Indel at 0x11eb53240>,
#                 <gap_checker.Indel at 0x11eb532e8>],
#                'N30_sequence18': [<gap_checker.Indel at 0x11eb53320>],
#                'N30_sequence40': [<gap_checker.Indel at 0x11eb53390>,
#                 <gap_checker.Indel at 0x11eb533c8>],
#                'N31_N32': [<gap_checker.Indel at 0x11eb53470>,
#                 <gap_checker.Indel at 0x11eb534e0>],
#                'N31_N34': [<gap_checker.Indel at 0x11eb53588>,
#                 <gap_checker.Indel at 0x11eb535f8>],
#                'N36_sequence38': [<gap_checker.Indel at 0x11eb53668>],
#                'N36_sequence17': [],
#                'N39_sequence33': [<gap_checker.Indel at 0x11eb53710>,
#                 <gap_checker.Indel at 0x11eb53780>],
#                'N39_sequence27': [<gap_checker.Indel at 0x11eb537f0>,
#                 <gap_checker.Indel at 0x11eb53860>],
#                'N40_N41': [],
#                'N40_N43': [],
#                'N48_sequence10': [],
#                'N48_sequence5': [],
#                'N8_N9': [],
#                'N8_N14': [<gap_checker.Indel at 0x11eb539b0>,
#                 <gap_checker.Indel at 0x11eb53a20>,
#                 <gap_checker.Indel at 0x11eb53ac8>],
#                'N16_sequence15': [<gap_checker.Indel at 0x11eb53b38>,
#                 <gap_checker.Indel at 0x11eb53ba8>,
#                 <gap_checker.Indel at 0x11eb53c18>],
#                'N16_sequence45': [<gap_checker.Indel at 0x11eb53c88>,
#                 <gap_checker.Indel at 0x11eb53cf8>,
#                 <gap_checker.Indel at 0x11eb53d30>,
#                 <gap_checker.Indel at 0x11eb53da0>,
#                 <gap_checker.Indel at 0x11eb53e10>,
#                 <gap_checker.Indel at 0x11eb53eb8>],
#                'N17_N18': [<gap_checker.Indel at 0x11eb53f60>],
#                'N17_sequence21': [],
#                'N24_sequence28': [<gap_checker.Indel at 0x11eb53fd0>],
#                'N24_sequence6': [<gap_checker.Indel at 0x11eb61080>,
#                 <gap_checker.Indel at 0x11eb610f0>],
#                'N25_sequence32': [],
#                'N25_sequence9': [],
#                'N32_N33': [<gap_checker.Indel at 0x11eb61198>],
#                'N32_sequence49': [<gap_checker.Indel at 0x11eb61208>,
#                 <gap_checker.Indel at 0x11eb612b0>],
#                'N34_sequence3': [],
#                'N34_sequence29': [<gap_checker.Indel at 0x11eb61320>,
#                 <gap_checker.Indel at 0x11eb61390>],
#                'N41_sequence23': [<gap_checker.Indel at 0x11eb61400>,
#                 <gap_checker.Indel at 0x11eb61470>,
#                 <gap_checker.Indel at 0x11eb61518>,
#                 <gap_checker.Indel at 0x11eb61588>,
#                 <gap_checker.Indel at 0x11eb615f8>],
#                'N41_N42': [],
#                'N43_N44': [],
#                'N43_N46': [],
#                'N9_N10': [<gap_checker.Indel at 0x11eb61748>],
#                'N9_N12': [],
#                'N14_sequence46': [],
#                'N14_sequence47': [<gap_checker.Indel at 0x11eb617f0>],
#                'N18_N19': [],
#                'N18_sequence8': [<gap_checker.Indel at 0x11eb61898>,
#                 <gap_checker.Indel at 0x11eb618d0>,
#                 <gap_checker.Indel at 0x11eb61940>],
#                'N33_sequence42': [],
#                'N33_sequence4': [<gap_checker.Indel at 0x11eb619b0>],
#                'N42_sequence39': [<gap_checker.Indel at 0x11eb61a20>,
#                 <gap_checker.Indel at 0x11eb61a58>,
#                 <gap_checker.Indel at 0x11eb61ac8>,
#                 <gap_checker.Indel at 0x11eb61b38>],
#                'N42_sequence35': [<gap_checker.Indel at 0x11eb61be0>,
#                 <gap_checker.Indel at 0x11eb61c18>,
#                 <gap_checker.Indel at 0x11eb61c88>,
#                 <gap_checker.Indel at 0x11eb61d30>],
#                'N44_sequence12': [],
#                'N44_N45': [],
#                'N46_sequence1': [],
#                'N46_sequence7': [<gap_checker.Indel at 0x11eb61e10>],
#                'N10_N11': [<gap_checker.Indel at 0x11eb61eb8>],
#                'N10_sequence44': [<gap_checker.Indel at 0x11eb61f28>],
#                'N12_sequence36': [<gap_checker.Indel at 0x11eb61f98>],
#                'N12_N13': [],
#                'N19_N20': [],
#                'N19_sequence22': [<gap_checker.Indel at 0x11eb6b0b8>],
#                'N45_sequence25': [<gap_checker.Indel at 0x11eb6b0f0>],
#                'N45_sequence14': [<gap_checker.Indel at 0x11eb6b160>,
#                 <gap_checker.Indel at 0x11eb6b1d0>],
#                'N11_sequence31': [],
#                'N11_sequence11': [<gap_checker.Indel at 0x11eb6b240>],
#                'N13_sequence24': [],
#                'N13_sequence50': [],
#                'N20_sequence41': [],
#                'N20_sequence19': [<gap_checker.Indel at 0x11eb6b2b0>,
#                 <gap_checker.Indel at 0x11eb6b320>]}}})

# %%
def indel_present(indelible_branch, indelible_indel, method_gap_dict):
    for method_indel in method_gap_dict[branch]:
        if method_indel.category == indelible_indel.category and method_indel.start == indelible_indel.start and method_indel.end == indelible_indel.end:
            return True
        else:
            return False
    else:
        return False

with open (output_file, 'w+') as output:
    writer = csv.writer(output, delimiter=',', quotechar='\"', quoting=csv.QUOTE_MINIMAL)
    writer.writerow(['Taxa', 'Name', 'Category', 'Start', 'End', 'Terminal', 'Content', 'Gapped_Content', 'Width', 'Descendants', 'Root_Dist', 'Child_Extant'] + methods)

    for taxon in taxa:
        
        indelible_tree = ete3.Tree(f"./indelible_output/{taxon}/cleaned_N0_trees/1.nwk", format=1)
        with open(f'./output_dicts/{taxon}/gaps_indelible_1.p', 'rb') as handle:
            indelible_gap_dict = pickle.load(handle)


        for branch, indel_list in indelible_gap_dict.items():
            child_node = branch.split("_")[1]
            tree_node = indelible_tree&child_node
            descendants = len([x for x in tree_node.iter_descendants()])
            root_dist = tree_node.get_distance(indelible_tree.get_tree_root())
            child_extant = False
            for child in tree_node.children:
                if child.is_leaf():
                    child_extant = True

            for indel in indel_list:
                print (indel)
                method_presence = [indel_present(branch, indel, methods_dict[method][taxon]) for method in methods]
                print (method_presence)
                print (branch)
                print (branch.split("_")[1])
                
            
                
                writer.writerow([taxon, f'{branch}_{indel.start}_{indel.end}', indel.category, indel.start, indel.end, indel.terminal, indel.content, indel.gapped_content, indel.width, descendants, root_dist, child_extant] + method_presence)


                    
    "with open (output_file, 'w+') as output:\n",
    "    \n",
    "    writer = csv.writer(output, delimiter=',', quotechar='\"', quoting=csv.QUOTE_MINIMAL)\n",
    "    writer.writerow(['Name', 'Root', 'Type', 'Kingdom', 'Phylum', 'Class', 'Order', 'Family', 'Genus', 'Species', 'Extra'])\n",
# Out:
# <gap_checker.Indel object at 0x11eac75c0>
# [False, False, False, False, False, False]
# N0_N1
# N1
# <gap_checker.Indel object at 0x11eac77f0>
# [False, False, False, False, False, False]
# N0_N1
# N1
# <gap_checker.Indel object at 0x11eac7908>
# [False, False, False, False, False, False]
# N0_N1
# N1
# <gap_checker.Indel object at 0x11eac7898>
# [False, False, True, False, False, False]
# N0_N1
# N1
# <gap_checker.Indel object at 0x11eac71d0>
# [False, False, False, False, False, False]
# N0_N1
# N1
# <gap_checker.Indel object at 0x11eac7470>
# [False, False, False, False, False, False]
# N0_N1
# N1
# <gap_checker.Indel object at 0x11eac7f28>
# [False, False, False, False, False, False]
# N0_N1
# N1
# <gap_checker.Indel object at 0x11e0836d8>
# [False, False, False, False, False, False]
# N0_N1
# N1
# <gap_checker.Indel object at 0x11e0837b8>
# [False, False, False, False, False, False]
# N0_N1
# N1
# <gap_checker.Indel object at 0x11e0839b0>
# [False, False, False, False, False, False]
# N0_N1
# N1
# <gap_checker.Indel object at 0x11e083e10>
# [False, False, False, False, False, False]
# N0_N1
# N1
# <gap_checker.Indel object at 0x11e0837f0>
# [False, False, False, False, False, False]
# N0_N1
# N1
# <gap_checker.Indel object at 0x11e083dd8>
# [False, False, False, False, False, False]
# N0_N1
# N1
# <gap_checker.Indel object at 0x11e041b00>
# [False, True, True, True, False, False]
# N0_sequence5
# sequence5
# <gap_checker.Indel object at 0x11e31e208>
# [False, False, False, False, False, False]
# N0_sequence5
# sequence5
# <gap_checker.Indel object at 0x11e31e5c0>
# [False, False, False, False, False, False]
# N0_sequence5
# sequence5
# <gap_checker.Indel object at 0x11e31eeb8>
# [False, False, False, False, False, False]
# N0_sequence5
# sequence5
# <gap_checker.Indel object at 0x11e31efd0>
# [False, False, False, False, False, False]
# N0_sequence5
# sequence5
# <gap_checker.Indel object at 0x10a83eac8>
# [False, False, False, False, False, False]
# N0_sequence5
# sequence5
# <gap_checker.Indel object at 0x10a83ea58>
# [False, False, False, False, False, False]
# N0_sequence5
# sequence5
# <gap_checker.Indel object at 0x11e324978>
# [False, False, False, False, False, False]
# N0_sequence5
# sequence5
# <gap_checker.Indel object at 0x11e324550>
# [False, False, False, False, False, False]
# N0_sequence5
# sequence5
# <gap_checker.Indel object at 0x11e202b00>
# [False, False, False, False, False, False]
# N0_sequence5
# sequence5
# <gap_checker.Indel object at 0x11e202a20>
# [False, False, False, False, False, False]
# N0_sequence5
# sequence5
# <gap_checker.Indel object at 0x11e2028d0>
# [False, False, False, False, False, False]
# N0_sequence5
# sequence5
# <gap_checker.Indel object at 0x11e202860>
# [False, False, False, False, False, False]
# N0_sequence5
# sequence5
# <gap_checker.Indel object at 0x11e202a58>
# [False, False, False, False, False, False]
# N0_sequence5
# sequence5
# <gap_checker.Indel object at 0x11e2026d8>
# [False, False, False, False, False, False]
# N0_sequence5
# sequence5
# <gap_checker.Indel object at 0x11e2027f0>
# [False, False, False, False, False, False]
# N0_sequence5
# sequence5
# <gap_checker.Indel object at 0x11e202b38>
# [False, True, False, False, False, False]
# N1_sequence3
# sequence3
# <gap_checker.Indel object at 0x11e202b70>
# [False, False, False, False, False, False]
# N1_sequence3
# sequence3
# <gap_checker.Indel object at 0x11eac47f0>
# [False, False, False, False, False, False]
# N1_sequence3
# sequence3
# <gap_checker.Indel object at 0x11eac4b70>
# [False, False, False, False, False, False]
# N1_sequence3
# sequence3
# <gap_checker.Indel object at 0x11eac4ef0>
# [False, False, False, False, False, False]
# N1_sequence3
# sequence3
# <gap_checker.Indel object at 0x11eac4d30>
# [False, False, False, False, False, False]
# N1_sequence3
# sequence3
# <gap_checker.Indel object at 0x11eaf4978>
# [False, False, False, False, False, False]
# N1_sequence3
# sequence3
# <gap_checker.Indel object at 0x11eaf4b38>
# [False, False, False, False, False, False]
# N1_sequence3
# sequence3
# <gap_checker.Indel object at 0x11eaf4898>
# [False, False, False, False, False, False]
# N1_sequence3
# sequence3
# <gap_checker.Indel object at 0x11eac4908>
# [False, False, False, False, False, False]
# N1_sequence3
# sequence3
# <gap_checker.Indel object at 0x11eac4b00>
# [False, False, False, False, False, False]
# N1_N2
# N2
# <gap_checker.Indel object at 0x11eac4cc0>
# [False, False, False, False, False, False]
# N1_N2
# N2
# <gap_checker.Indel object at 0x11eac46d8>
# [False, False, False, False, False, False]
# N1_N2
# N2
# <gap_checker.Indel object at 0x11eac4550>
# [False, False, False, False, False, False]
# N1_N2
# N2
# <gap_checker.Indel object at 0x11eac4518>
# [False, False, False, False, False, False]
# N1_N2
# N2
# <gap_checker.Indel object at 0x11eac44a8>
# [False, False, False, False, False, False]
# N1_N2
# N2
# <gap_checker.Indel object at 0x11eac4400>
# [False, False, False, False, False, False]
# N1_N2
# N2
# <gap_checker.Indel object at 0x11eac4320>
# [False, False, False, False, False, False]
# N2_N7
# N7
# <gap_checker.Indel object at 0x11eac42e8>
# [False, False, False, False, False, False]
# N2_N7
# N7
# <gap_checker.Indel object at 0x11eac42b0>
# [False, False, False, False, False, False]
# N2_N7
# N7
# <gap_checker.Indel object at 0x11eac4198>
# [False, False, False, False, False, False]
# N3_N4
# N4
# <gap_checker.Indel object at 0x11eac4128>
# [False, False, False, False, False, False]
# N3_N4
# N4
# <gap_checker.Indel object at 0x11eac47b8>
# [False, False, False, False, False, False]
# N3_N4
# N4
# <gap_checker.Indel object at 0x11eac4898>
# [False, False, False, False, False, False]
# N3_N5
# N5
# <gap_checker.Indel object at 0x11eac4780>
# [False, False, False, False, False, False]
# N3_N5
# N5
# <gap_checker.Indel object at 0x11eac4860>
# [False, False, False, False, False, False]
# N3_N5
# N5
# <gap_checker.Indel object at 0x11eac4710>
# [False, False, False, False, False, False]
# N3_N5
# N5
# <gap_checker.Indel object at 0x11eac46a0>
# [False, False, False, False, False, False]
# N3_N5
# N5
# <gap_checker.Indel object at 0x11eb6b7b8>
# [False, False, False, False, False, False]
# N3_N5
# N5
# <gap_checker.Indel object at 0x11eb6b978>
# [False, False, False, False, False, False]
# N3_N5
# N5
# <gap_checker.Indel object at 0x11eb6b630>
# [False, True, False, False, False, False]
# N7_sequence8
# sequence8
# <gap_checker.Indel object at 0x11eb6b5f8>
# [False, False, True, False, False, False]
# N7_sequence8
# sequence8
# <gap_checker.Indel object at 0x11eb6bb38>
# [False, False, False, False, False, False]
# N7_sequence8
# sequence8
# <gap_checker.Indel object at 0x11eb6bfd0>
# [False, False, False, False, False, False]
# N7_sequence8
# sequence8
# <gap_checker.Indel object at 0x11eb6bcf8>
# [False, False, False, False, False, False]
# N7_sequence8
# sequence8
# <gap_checker.Indel object at 0x11eb6b710>
# [False, False, False, False, False, False]
# N7_sequence8
# sequence8
# <gap_checker.Indel object at 0x11eb6b9e8>
# [False, True, True, True, False, False]
# N7_N8
# N8
# <gap_checker.Indel object at 0x11eb6b860>
# [False, False, False, False, True, False]
# N7_N8
# N8
# <gap_checker.Indel object at 0x11eb6bb70>
# [True, False, False, False, False, False]
# N7_N8
# N8
# <gap_checker.Indel object at 0x11eb6bbe0>
# [False, False, False, False, False, False]
# N7_N8
# N8
# <gap_checker.Indel object at 0x11eb6b8d0>
# [False, False, False, False, False, False]
# N7_N8
# N8
# <gap_checker.Indel object at 0x11eb6bf98>
# [False, False, False, False, False, False]
# N7_N8
# N8
# <gap_checker.Indel object at 0x11eb6bb00>
# [False, False, False, False, False, False]
# N7_N8
# N8
# <gap_checker.Indel object at 0x11eb6be80>
# [False, False, False, False, False, False]
# N7_N8
# N8
# <gap_checker.Indel object at 0x11eb6b9b0>
# [False, False, False, False, False, False]
# N7_N8
# N8
# <gap_checker.Indel object at 0x11eb6b6d8>
# [False, False, False, False, False, False]
# N7_N8
# N8
# <gap_checker.Indel object at 0x11eb6bc88>
# [True, True, False, False, False, False]
# N4_sequence4
# sequence4
# <gap_checker.Indel object at 0x11eb6b6a0>
# [False, False, True, True, False, False]
# N4_sequence4
# sequence4
# <gap_checker.Indel object at 0x11eb6bd68>
# [False, False, False, False, False, False]
# N4_sequence4
# sequence4
# <gap_checker.Indel object at 0x11eb6ba58>
# [False, False, False, False, False, False]
# N4_sequence4
# sequence4
# <gap_checker.Indel object at 0x11eb6b3c8>
# [False, False, False, False, False, False]
# N4_sequence4
# sequence4
# <gap_checker.Indel object at 0x11eb6bc18>
# [False, False, False, False, False, False]
# N4_sequence4
# sequence4
# <gap_checker.Indel object at 0x11e0defd0>
# [False, False, False, False, False, False]
# N4_sequence4
# sequence4
# <gap_checker.Indel object at 0x11e0de898>
# [False, False, False, False, False, False]
# N4_sequence4
# sequence4
# <gap_checker.Indel object at 0x11e0ded30>
# [False, False, False, False, False, False]
# N4_sequence4
# sequence4
# <gap_checker.Indel object at 0x11e0dea90>
# [False, False, False, False, False, False]
# N4_sequence4
# sequence4
# <gap_checker.Indel object at 0x11e0de940>
# [False, False, False, False, False, False]
# N4_sequence4
# sequence4
# <gap_checker.Indel object at 0x11e0ded68>
# [False, False, False, False, False, False]
# N4_sequence6
# sequence6
# <gap_checker.Indel object at 0x11e0deba8>
# [False, False, False, False, False, False]
# N4_sequence6
# sequence6
# <gap_checker.Indel object at 0x11e0de908>
# [False, False, False, False, False, False]
# N4_sequence6
# sequence6
# <gap_checker.Indel object at 0x11e0de8d0>
# [False, False, False, False, False, False]
# N4_sequence6
# sequence6
# <gap_checker.Indel object at 0x11e0decf8>
# [False, False, False, False, False, False]
# N5_sequence7
# sequence7
# <gap_checker.Indel object at 0x11e0dee48>
# [True, False, False, False, True, True]
# N5_sequence7
# sequence7
# <gap_checker.Indel object at 0x11e0deac8>
# [False, False, False, False, False, False]
# N5_sequence7
# sequence7
# <gap_checker.Indel object at 0x11e0e2a20>
# [True, False, False, False, True, True]
# N5_N6
# N6
# <gap_checker.Indel object at 0x11e0e2438>
# [False, False, False, False, False, False]
# N5_N6
# N6
# <gap_checker.Indel object at 0x11e0e27b8>
# [False, False, False, False, False, False]
# N5_N6
# N6
# <gap_checker.Indel object at 0x11e0e28d0>
# [True, True, True, True, True, True]
# N8_sequence10
# sequence10
# <gap_checker.Indel object at 0x11e0e2630>
# [True, True, True, True, True, True]
# N6_sequence2
# sequence2
# <gap_checker.Indel object at 0x11eaaf668>
# [False, False, False, False, False, False]
# N0_N1
# N1
# <gap_checker.Indel object at 0x11ebb0ac8>
# [True, True, True, True, True, True]
# N0_N17
# N17
# <gap_checker.Indel object at 0x11ebb0b00>
# [False, False, False, False, False, False]
# N0_N17
# N17
# <gap_checker.Indel object at 0x11ebb0b38>
# [False, False, False, False, False, False]
# N0_N17
# N17
# <gap_checker.Indel object at 0x11ebb0eb8>
# [False, False, False, False, False, False]
# N0_N17
# N17
# <gap_checker.Indel object at 0x11ebb0c88>
# [False, False, False, False, False, False]
# N0_N17
# N17
# <gap_checker.Indel object at 0x11ebb0cf8>
# [False, False, False, False, False, False]
# N0_N17
# N17
# <gap_checker.Indel object at 0x11ebb09b0>
# [False, False, False, False, False, False]
# N0_N17
# N17
# <gap_checker.Indel object at 0x11ebb0940>
# [False, False, False, False, False, False]
# N0_N17
# N17
# <gap_checker.Indel object at 0x11ebb0978>
# [False, False, False, False, False, False]
# N0_N17
# N17
# <gap_checker.Indel object at 0x11ebb0898>
# [True, False, True, False, True, False]
# N1_N2
# N2
# <gap_checker.Indel object at 0x11ebb0828>
# [False, False, False, False, False, False]
# N1_N2
# N2
# <gap_checker.Indel object at 0x11ebb05c0>
# [False, False, False, False, False, False]
# N1_N2
# N2
# <gap_checker.Indel object at 0x11ebb0668>
# [False, False, False, False, False, False]
# N1_N3
# N3
# <gap_checker.Indel object at 0x11ebb0710>
# [True, False, True, False, True, False]
# N17_N18
# N18
# <gap_checker.Indel object at 0x11ebb0780>
# [True, True, True, True, True, True]
# N2_sequence12
# sequence12
# <gap_checker.Indel object at 0x11ebb07b8>
# [False, False, False, False, False, False]
# N2_sequence12
# sequence12
# <gap_checker.Indel object at 0x11ebb0588>
# [False, False, False, False, False, False]
# N2_sequence12
# sequence12
# <gap_checker.Indel object at 0x11ebb0550>
# [False, False, False, False, False, False]
# N2_sequence12
# sequence12
# <gap_checker.Indel object at 0x11ebb0be0>
# [False, False, False, False, False, False]
# N2_sequence12
# sequence12
# <gap_checker.Indel object at 0x11ebb0ef0>
# [False, False, False, False, False, False]
# N2_sequence12
# sequence12
# <gap_checker.Indel object at 0x11ebb0208>
# [False, False, False, False, False, False]
# N2_sequence12
# sequence12
# <gap_checker.Indel object at 0x11ebb00f0>
# [False, False, False, False, False, False]
# N2_sequence12
# sequence12
# <gap_checker.Indel object at 0x11ebb00b8>
# [False, False, False, False, False, False]
# N2_sequence12
# sequence12
# <gap_checker.Indel object at 0x11ebb0080>
# [False, False, False, False, False, False]
# N2_sequence12
# sequence12
# <gap_checker.Indel object at 0x11ebb02b0>
# [False, False, False, False, False, False]
# N2_sequence12
# sequence12
# <gap_checker.Indel object at 0x11ebb0128>
# [True, True, True, True, True, True]
# N2_sequence8
# sequence8
# <gap_checker.Indel object at 0x11e4e4080>
# [False, False, False, False, False, False]
# N2_sequence8
# sequence8
# <gap_checker.Indel object at 0x11e4e4128>
# [False, False, False, False, False, False]
# N2_sequence8
# sequence8
# <gap_checker.Indel object at 0x11e4e4198>
# [False, False, False, False, False, False]
# N2_sequence8
# sequence8
# <gap_checker.Indel object at 0x11e4e41d0>
# [False, False, False, False, False, False]
# N2_sequence8
# sequence8
# <gap_checker.Indel object at 0x11e4e4208>
# [False, False, False, False, False, False]
# N2_sequence8
# sequence8
# <gap_checker.Indel object at 0x11e4e4278>
# [False, False, False, False, False, False]
# N2_sequence8
# sequence8
# <gap_checker.Indel object at 0x11e4e42e8>
# [False, False, False, False, False, False]
# N2_sequence8
# sequence8
# <gap_checker.Indel object at 0x11e4e4358>
# [False, False, False, False, False, False]
# N2_sequence8
# sequence8
# <gap_checker.Indel object at 0x11e4e4400>
# [False, False, False, False, False, False]
# N2_sequence8
# sequence8
# <gap_checker.Indel object at 0x11e4e44e0>
# [False, True, True, True, False, True]
# N3_N11
# N11
# <gap_checker.Indel object at 0x11e4e4550>
# [False, False, False, False, False, False]
# N3_N11
# N11
# <gap_checker.Indel object at 0x11e4e45f8>
# [False, False, False, False, True, False]
# N3_N11
# N11
# <gap_checker.Indel object at 0x11e4e4668>
# [False, False, False, False, False, False]
# N3_N11
# N11
# <gap_checker.Indel object at 0x11e4e46a0>
# [False, False, False, False, False, False]
# N3_N11
# N11
# <gap_checker.Indel object at 0x11e4e4710>
# [False, False, False, False, False, False]
# N3_N11
# N11
# <gap_checker.Indel object at 0x11e4e4748>
# [True, True, True, True, True, True]
# N18_sequence9
# sequence9
# <gap_checker.Indel object at 0x11e4e47b8>
# [False, False, False, False, False, False]
# N18_sequence9
# sequence9
# <gap_checker.Indel object at 0x11e4e47f0>
# [True, True, True, True, True, True]
# N18_sequence18
# sequence18
# <gap_checker.Indel object at 0x11e4e4828>
# [False, False, False, False, False, False]
# N18_sequence18
# sequence18
# <gap_checker.Indel object at 0x11e4e4898>
# [False, False, False, False, False, False]
# N4_N5
# N5
# <gap_checker.Indel object at 0x11e4e4908>
# [True, True, True, True, True, True]
# N4_N8
# N8
# <gap_checker.Indel object at 0x11e4e4940>
# [False, False, False, False, False, False]
# N4_N8
# N8
# <gap_checker.Indel object at 0x11e4e4978>
# [False, False, False, False, False, False]
# N4_N8
# N8
# <gap_checker.Indel object at 0x11e4e49e8>
# [False, False, False, False, False, False]
# N4_N8
# N8
# <gap_checker.Indel object at 0x11e4e4a58>
# [False, False, False, False, False, False]
# N4_N8
# N8
# <gap_checker.Indel object at 0x11e4e4ac8>
# [False, False, False, False, False, False]
# N4_N8
# N8
# <gap_checker.Indel object at 0x11e4e4b00>
# [False, False, False, False, False, False]
# N4_N8
# N8
# <gap_checker.Indel object at 0x11e4e4b70>
# [False, False, False, False, False, False]
# N4_N8
# N8
# <gap_checker.Indel object at 0x11e4e4be0>
# [False, False, False, False, False, False]
# N4_N8
# N8
# <gap_checker.Indel object at 0x11e4e4c18>
# [False, False, False, False, False, False]
# N4_N8
# N8
# <gap_checker.Indel object at 0x11e4e4cc0>
# [False, False, False, False, False, False]
# N4_N8
# N8
# <gap_checker.Indel object at 0x11e4e4d68>
# [False, False, False, False, False, False]
# N4_N8
# N8
# <gap_checker.Indel object at 0x11e4e4e10>
# [False, False, False, False, False, False]
# N4_N8
# N8
# <gap_checker.Indel object at 0x11e4e4e80>
# [False, False, False, False, False, False]
# N4_N8
# N8
# <gap_checker.Indel object at 0x11e4e4f28>
# [False, False, True, False, False, False]
# N11_N12
# N12
# <gap_checker.Indel object at 0x11e4e4fd0>
# [False, False, False, False, False, False]
# N11_N12
# N12
# <gap_checker.Indel object at 0x11e4d6080>
# [False, False, False, False, False, False]
# N11_N12
# N12
# <gap_checker.Indel object at 0x11e4d60f0>
# [False, True, True, True, False, True]
# N11_sequence5
# sequence5
# <gap_checker.Indel object at 0x11e4d6160>
# [True, False, False, False, True, False]
# N11_sequence5
# sequence5
# <gap_checker.Indel object at 0x11e4d61d0>
# [False, False, False, False, False, False]
# N11_sequence5
# sequence5
# <gap_checker.Indel object at 0x11e4d6240>
# [False, False, False, False, False, False]
# N11_sequence5
# sequence5
# <gap_checker.Indel object at 0x11e4d62e8>
# [False, False, False, False, False, False]
# N11_sequence5
# sequence5
# <gap_checker.Indel object at 0x11e4d6358>
# [False, False, False, False, False, False]
# N11_sequence5
# sequence5
# <gap_checker.Indel object at 0x11e4d63c8>
# [False, False, False, False, False, False]
# N11_sequence5
# sequence5
# <gap_checker.Indel object at 0x11e4d6438>
# [False, True, True, True, True, True]
# N5_sequence6
# sequence6
# <gap_checker.Indel object at 0x11e4d64a8>
# [True, False, False, False, False, False]
# N5_sequence6
# sequence6
# <gap_checker.Indel object at 0x11e4d6518>
# [False, False, False, False, False, False]
# N5_sequence6
# sequence6
# <gap_checker.Indel object at 0x11e4d6588>
# [False, False, False, False, False, False]
# N5_sequence6
# sequence6
# <gap_checker.Indel object at 0x11e4d65f8>
# [False, False, False, False, False, False]
# N5_sequence6
# sequence6
# <gap_checker.Indel object at 0x11e4d6630>
# [False, False, False, False, False, False]
# N5_sequence6
# sequence6
# <gap_checker.Indel object at 0x11e4d66d8>
# [False, False, False, False, False, False]
# N5_sequence6
# sequence6
# <gap_checker.Indel object at 0x11e4d6748>
# [False, False, False, False, False, False]
# N5_sequence6
# sequence6
# <gap_checker.Indel object at 0x11e4d67b8>
# [False, False, False, False, False, False]
# N5_sequence6
# sequence6
# <gap_checker.Indel object at 0x11e4d6828>
# [False, False, False, False, False, False]
# N5_sequence6
# sequence6
# <gap_checker.Indel object at 0x11e4d6898>
# [False, False, False, False, False, False]
# N5_sequence6
# sequence6
# <gap_checker.Indel object at 0x11e4d68d0>
# [False, False, False, False, False, False]
# N5_sequence6
# sequence6
# <gap_checker.Indel object at 0x11e4d6940>
# [False, False, False, False, False, False]
# N5_sequence6
# sequence6
# <gap_checker.Indel object at 0x11e4d69b0>
# [False, False, False, False, False, False]
# N5_sequence6
# sequence6
# <gap_checker.Indel object at 0x11e4d6a20>
# [False, False, False, False, False, False]
# N5_N6
# N6
# <gap_checker.Indel object at 0x11e4d6ac8>
# [False, False, False, False, True, False]
# N5_N6
# N6
# <gap_checker.Indel object at 0x11e4d6b38>
# [True, False, False, False, False, False]
# N5_N6
# N6
# <gap_checker.Indel object at 0x11e4d6ba8>
# [False, False, False, False, False, False]
# N5_N6
# N6
# <gap_checker.Indel object at 0x11e4d6c50>
# [True, False, False, False, False, False]
# N8_sequence14
# sequence14
# <gap_checker.Indel object at 0x11e4d6c88>
# [False, False, False, False, False, False]
# N8_sequence14
# sequence14
# <gap_checker.Indel object at 0x11e4d6d30>
# [True, False, True, False, False, False]
# N8_N9
# N9
# <gap_checker.Indel object at 0x11e4d6d68>
# [False, False, False, False, True, False]
# N8_N9
# N9
# <gap_checker.Indel object at 0x11e4d6dd8>
# [False, False, False, False, False, False]
# N8_N9
# N9
# <gap_checker.Indel object at 0x11e4d6e48>
# [False, False, False, False, False, False]
# N8_N9
# N9
# <gap_checker.Indel object at 0x11e4d6ef0>
# [True, True, True, True, True, True]
# N12_sequence13
# sequence13
# <gap_checker.Indel object at 0x11e4d6f60>
# [False, False, False, False, False, False]
# N12_sequence13
# sequence13
# <gap_checker.Indel object at 0x11e4d6fd0>
# [False, False, False, False, False, False]
# N12_sequence13
# sequence13
# <gap_checker.Indel object at 0x11e4db048>
# [False, False, False, False, False, False]
# N12_sequence13
# sequence13
# <gap_checker.Indel object at 0x11e4db0b8>
# [False, False, False, False, False, False]
# N12_sequence13
# sequence13
# <gap_checker.Indel object at 0x11e4db128>
# [False, False, False, False, False, False]
# N12_sequence13
# sequence13
# <gap_checker.Indel object at 0x11e4db1d0>
# [False, False, True, False, True, False]
# N12_N13
# N13
# <gap_checker.Indel object at 0x11e4db240>
# [False, False, False, False, False, False]
# N12_N13
# N13
# <gap_checker.Indel object at 0x11e4db2b0>
# [False, True, True, True, True, True]
# N6_sequence15
# sequence15
# <gap_checker.Indel object at 0x11e4db358>
# [False, False, False, False, False, False]
# N6_sequence15
# sequence15
# <gap_checker.Indel object at 0x11e4db3c8>
# [False, False, False, False, False, False]
# N6_sequence15
# sequence15
# <gap_checker.Indel object at 0x11e4db400>
# [False, False, False, False, False, False]
# N6_sequence15
# sequence15
# <gap_checker.Indel object at 0x11e4db4a8>
# [False, False, False, False, False, False]
# N6_sequence15
# sequence15
# <gap_checker.Indel object at 0x11e4db5c0>
# [True, True, True, True, True, True]
# N13_sequence10
# sequence10
# <gap_checker.Indel object at 0x11e4db630>
# [False, False, False, False, False, False]
# N13_sequence10
# sequence10
# <gap_checker.Indel object at 0x11e4db6a0>
# [False, False, False, False, False, False]
# N13_sequence10
# sequence10
# <gap_checker.Indel object at 0x11e4db6d8>
# [False, False, False, False, False, False]
# N13_sequence10
# sequence10
# <gap_checker.Indel object at 0x11e4db748>
# [False, False, False, False, False, False]
# N13_sequence10
# sequence10
# <gap_checker.Indel object at 0x11e4db7f0>
# [False, False, False, False, False, False]
# N13_sequence10
# sequence10
# <gap_checker.Indel object at 0x11e4db860>
# [True, True, True, True, True, True]
# N7_sequence1
# sequence1
# <gap_checker.Indel object at 0x11e4db8d0>
# [False, False, False, False, False, False]
# N7_sequence1
# sequence1
# <gap_checker.Indel object at 0x11e4db978>
# [False, False, False, False, False, False]
# N7_sequence1
# sequence1
# <gap_checker.Indel object at 0x11e4db9e8>
# [True, True, False, False, False, True]
# N7_sequence17
# sequence17
# <gap_checker.Indel object at 0x11e4dba90>
# [False, False, True, True, True, False]
# N7_sequence17
# sequence17
# <gap_checker.Indel object at 0x11e4dbb00>
# [False, False, False, False, False, False]
# N7_sequence17
# sequence17
# <gap_checker.Indel object at 0x11e4dbb38>
# [False, False, False, False, False, False]
# N7_sequence17
# sequence17
# <gap_checker.Indel object at 0x11e4dbc18>
# [True, True, True, True, True, True]
# N10_sequence4
# sequence4
# <gap_checker.Indel object at 0x11e4dbcc0>
# [True, False, True, True, True, True]
# N14_sequence7
# sequence7
# <gap_checker.Indel object at 0x11e4dbcf8>
# [False, False, False, False, False, False]
# N14_sequence7
# sequence7
# <gap_checker.Indel object at 0x11e4dbd68>
# [False, False, False, False, False, False]
# N14_sequence7
# sequence7
# <gap_checker.Indel object at 0x11e4dbdd8>
# [False, False, False, False, False, False]
# N14_sequence7
# sequence7
# <gap_checker.Indel object at 0x11e4dbe48>
# [False, False, False, False, False, False]
# N14_sequence7
# sequence7
# <gap_checker.Indel object at 0x11e4dbeb8>
# [False, False, False, False, False, False]
# N14_sequence7
# sequence7
# <gap_checker.Indel object at 0x11e4dbf60>
# [False, False, False, False, False, False]
# N14_sequence7
# sequence7
# <gap_checker.Indel object at 0x11e4eb080>
# [True, False, False, False, False, False]
# N14_N15
# N15
# <gap_checker.Indel object at 0x11e4eb0f0>
# [False, False, False, False, False, False]
# N14_N15
# N15
# <gap_checker.Indel object at 0x11e4eb128>
# [False, False, False, False, False, False]
# N14_N15
# N15
# <gap_checker.Indel object at 0x11e4eb198>
# [False, False, False, False, False, False]
# N14_N15
# N15
# <gap_checker.Indel object at 0x11e4eb240>
# [True, False, True, True, True, True]
# N15_sequence11
# sequence11
# <gap_checker.Indel object at 0x11e4eb2e8>
# [True, False, True, True, True, True]
# N15_N16
# N16
# <gap_checker.Indel object at 0x11e4eb320>
# [False, True, False, False, False, False]
# N15_N16
# N16
# <gap_checker.Indel object at 0x11e4eb3c8>
# [False, False, False, False, False, False]
# N15_N16
# N16
# <gap_checker.Indel object at 0x11e4eb438>
# [False, False, False, False, False, False]
# N15_N16
# N16
# <gap_checker.Indel object at 0x11e4eb470>
# [False, False, False, False, False, False]
# N15_N16
# N16
# <gap_checker.Indel object at 0x11e4eb4a8>
# [True, True, True, True, True, True]
# N16_sequence19
# sequence19
# <gap_checker.Indel object at 0x11e202a20>
# [False, False, True, False, True, True]
# N0_N1
# N1
# <gap_checker.Indel object at 0x11e202a58>
# [False, False, False, False, False, False]
# N0_N1
# N1
# <gap_checker.Indel object at 0x11e2029e8>
# [False, False, False, False, False, False]
# N0_N13
# N13
# <gap_checker.Indel object at 0x11e0836d8>
# [False, False, True, False, True, True]
# N1_sequence23
# sequence23
# <gap_checker.Indel object at 0x11e0831d0>
# [True, False, False, False, False, False]
# N1_sequence23
# sequence23
# <gap_checker.Indel object at 0x11e0832b0>
# [False, False, False, False, False, False]
# N1_sequence23
# sequence23
# <gap_checker.Indel object at 0x11e083e10>
# [False, False, False, False, False, False]
# N1_sequence23
# sequence23
# <gap_checker.Indel object at 0x11e083fd0>
# [False, False, False, False, False, False]
# N1_sequence23
# sequence23
# <gap_checker.Indel object at 0x11e083dd8>
# [False, False, False, False, False, False]
# N1_sequence23
# sequence23
# <gap_checker.Indel object at 0x11ebb0fd0>
# [True, True, True, True, True, True]
# N13_N14
# N14
# <gap_checker.Indel object at 0x11ebb0a20>
# [False, False, False, False, False, False]
# N13_N14
# N14
# <gap_checker.Indel object at 0x11ebb0e10>
# [False, False, False, False, False, False]
# N13_N14
# N14
# <gap_checker.Indel object at 0x11eac7710>
# [False, False, False, False, False, False]
# N13_N14
# N14
# <gap_checker.Indel object at 0x11eac77f0>
# [False, False, False, False, False, False]
# N13_N14
# N14
# <gap_checker.Indel object at 0x11eac7828>
# [False, False, False, False, False, False]
# N13_N14
# N14
# <gap_checker.Indel object at 0x11eac7898>
# [False, False, False, False, False, False]
# N13_N14
# N14
# <gap_checker.Indel object at 0x11eac71d0>
# [False, False, False, False, False, False]
# N13_N14
# N14
# <gap_checker.Indel object at 0x11eac7438>
# [False, False, False, False, False, False]
# N13_N14
# N14
# <gap_checker.Indel object at 0x11eac7f28>
# [False, False, False, False, False, False]
# N13_N15
# N15
# <gap_checker.Indel object at 0x11e4eb550>
# [False, False, False, False, False, False]
# N13_N15
# N15
# <gap_checker.Indel object at 0x11e4eb630>
# [True, True, True, False, True, False]
# N2_N3
# N3
# <gap_checker.Indel object at 0x11e4eb668>
# [False, False, False, False, False, False]
# N2_N3
# N3
# <gap_checker.Indel object at 0x11e4eb6d8>
# [False, False, False, False, False, False]
# N2_N3
# N3
# <gap_checker.Indel object at 0x11e4eb710>
# [False, False, False, False, False, False]
# N2_N3
# N3
# <gap_checker.Indel object at 0x11e4eb7f0>
# [True, True, True, True, True, True]
# N2_N8
# N8
# <gap_checker.Indel object at 0x11e4eb898>
# [False, False, False, False, False, False]
# N2_N8
# N8
# <gap_checker.Indel object at 0x11e4eb940>
# [False, False, False, False, False, False]
# N2_N8
# N8
# <gap_checker.Indel object at 0x11e4eb9b0>
# [False, False, False, False, False, False]
# N2_N8
# N8
# <gap_checker.Indel object at 0x11e4eba90>
# [True, True, True, True, True, False]
# N14_sequence20
# sequence20
# <gap_checker.Indel object at 0x11e4ebb00>
# [False, False, False, False, False, False]
# N14_sequence20
# sequence20
# <gap_checker.Indel object at 0x11e4ebb70>
# [True, True, True, True, True, False]
# N14_sequence17
# sequence17
# <gap_checker.Indel object at 0x11e4ebc18>
# [False, False, False, False, False, False]
# N15_N16
# N16
# <gap_checker.Indel object at 0x11e4ebc50>
# [False, True, True, True, True, True]
# N15_sequence11
# sequence11
# <gap_checker.Indel object at 0x11e4ebcc0>
# [False, False, False, False, False, False]
# N15_sequence11
# sequence11
# <gap_checker.Indel object at 0x11e4ebcf8>
# [False, False, False, False, False, False]
# N15_sequence11
# sequence11
# <gap_checker.Indel object at 0x11e4ebd30>
# [False, False, False, False, False, False]
# N15_sequence11
# sequence11
# <gap_checker.Indel object at 0x11e4ebda0>
# [False, False, False, False, False, False]
# N15_sequence11
# sequence11
# <gap_checker.Indel object at 0x11e4ebe10>
# [False, False, False, False, False, False]
# N15_sequence11
# sequence11
# <gap_checker.Indel object at 0x11e4ebe80>
# [False, False, False, False, False, False]
# N15_sequence11
# sequence11
# <gap_checker.Indel object at 0x11e4ebef0>
# [False, False, False, False, False, False]
# N15_sequence11
# sequence11
# <gap_checker.Indel object at 0x11e4ebf98>
# [False, False, True, False, True, False]
# N3_N4
# N4
# <gap_checker.Indel object at 0x11e4e2080>
# [True, False, False, False, False, False]
# N3_N4
# N4
# <gap_checker.Indel object at 0x11e4e2128>
# [True, False, True, False, True, False]
# N3_sequence16
# sequence16
# <gap_checker.Indel object at 0x11e4e2198>
# [False, False, False, False, False, False]
# N3_sequence16
# sequence16
# <gap_checker.Indel object at 0x11e4e2208>
# [False, False, False, False, False, False]
# N3_sequence16
# sequence16
# <gap_checker.Indel object at 0x11e4e22b0>
# [True, True, True, True, True, True]
# N8_N9
# N9
# <gap_checker.Indel object at 0x11e4e22e8>
# [False, False, False, False, False, False]
# N8_N9
# N9
# <gap_checker.Indel object at 0x11e4e2358>
# [False, False, False, False, False, False]
# N8_N9
# N9
# <gap_checker.Indel object at 0x11e4e2400>
# [False, False, False, False, False, False]
# N8_N9
# N9
# <gap_checker.Indel object at 0x11e4e24e0>
# [False, True, True, True, True, True]
# N16_N17
# N17
# <gap_checker.Indel object at 0x11e4e2588>
# [False, False, False, False, False, False]
# N16_N17
# N17
# <gap_checker.Indel object at 0x11e4e25c0>
# [True, False, False, False, False, False]
# N16_N17
# N17
# <gap_checker.Indel object at 0x11e4e2630>
# [False, False, False, False, False, False]
# N16_N17
# N17
# <gap_checker.Indel object at 0x11e4e26a0>
# [False, False, False, False, False, False]
# N16_N17
# N17
# <gap_checker.Indel object at 0x11e4e2780>
# [True, True, True, True, True, True]
# N4_sequence19
# sequence19
# <gap_checker.Indel object at 0x11e4e27b8>
# [False, False, False, False, False, False]
# N4_sequence19
# sequence19
# <gap_checker.Indel object at 0x11e4e27f0>
# [False, False, False, False, False, False]
# N4_sequence19
# sequence19
# <gap_checker.Indel object at 0x11e4e2898>
# [False, False, False, False, False, False]
# N4_sequence19
# sequence19
# <gap_checker.Indel object at 0x11e4e2908>
# [False, False, False, False, False, False]
# N4_sequence19
# sequence19
# <gap_checker.Indel object at 0x11e4e2978>
# [False, False, False, False, False, False]
# N4_sequence19
# sequence19
# <gap_checker.Indel object at 0x11e4e29b0>
# [False, False, False, False, False, False]
# N4_sequence19
# sequence19
# <gap_checker.Indel object at 0x11e4e2a20>
# [True, True, True, True, True, True]
# N10_sequence22
# sequence22
# <gap_checker.Indel object at 0x11e4e2a90>
# [False, False, False, False, False, False]
# N10_sequence22
# sequence22
# <gap_checker.Indel object at 0x11e4e2b38>
# [False, False, False, False, False, False]
# N10_sequence22
# sequence22
# <gap_checker.Indel object at 0x11e4e2be0>
# [True, True, True, True, True, True]
# N10_N11
# N11
# <gap_checker.Indel object at 0x11e4e2c88>
# [True, False, True, False, True, True]
# N17_N18
# N18
# <gap_checker.Indel object at 0x11e4e2cc0>
# [False, False, False, False, False, False]
# N17_N18
# N18
# <gap_checker.Indel object at 0x11e4e2cf8>
# [False, False, False, False, False, False]
# N17_N18
# N18
# <gap_checker.Indel object at 0x11e4e2da0>
# [True, False, True, False, True, True]
# N17_N19
# N19
# <gap_checker.Indel object at 0x11e4e2e48>
# [False, True, True, True, True, True]
# N21_N22
# N22
# <gap_checker.Indel object at 0x11e4e2eb8>
# [False, False, False, False, False, False]
# N21_N22
# N22
# <gap_checker.Indel object at 0x11e4e2ef0>
# [False, False, False, False, False, False]
# N21_N22
# N22
# <gap_checker.Indel object at 0x11e4e2f60>
# [False, False, False, False, False, False]
# N21_N22
# N22
# <gap_checker.Indel object at 0x11e4e2f98>
# [False, False, False, False, False, False]
# N21_N22
# N22
# <gap_checker.Indel object at 0x11e4f4048>
# [False, False, False, False, False, False]
# N21_N22
# N22
# <gap_checker.Indel object at 0x11e4f40b8>
# [False, False, False, False, False, False]
# N21_N22
# N22
# <gap_checker.Indel object at 0x11e4f4128>
# [False, False, True, True, True, True]
# N5_sequence24
# sequence24
# <gap_checker.Indel object at 0x11e4f4160>
# [True, False, False, False, False, False]
# N5_sequence24
# sequence24
# <gap_checker.Indel object at 0x11e4f4198>
# [False, False, False, False, False, False]
# N5_sequence24
# sequence24
# <gap_checker.Indel object at 0x11e4f4240>
# [False, False, False, False, False, False]
# N5_sequence24
# sequence24
# <gap_checker.Indel object at 0x11e4f42b0>
# [False, False, False, False, False, False]
# N5_sequence24
# sequence24
# <gap_checker.Indel object at 0x11e4f4358>
# [True, True, True, True, True, True]
# N5_N6
# N6
# <gap_checker.Indel object at 0x11e4f43c8>
# [False, False, False, False, False, False]
# N5_N6
# N6
# <gap_checker.Indel object at 0x11e4f4438>
# [False, False, False, False, False, False]
# N5_N6
# N6
# <gap_checker.Indel object at 0x11e4f44a8>
# [False, False, False, False, False, False]
# N5_N6
# N6
# <gap_checker.Indel object at 0x11e4f4518>
# [False, False, False, False, False, False]
# N5_N6
# N6
# <gap_checker.Indel object at 0x11e4f4550>
# [False, False, False, False, False, False]
# N5_N6
# N6
# <gap_checker.Indel object at 0x11e4f4630>
# [True, True, True, True, True, True]
# N18_sequence18
# sequence18
# <gap_checker.Indel object at 0x11e4f4668>
# [True, True, True, True, True, True]
# N18_sequence29
# sequence29
# <gap_checker.Indel object at 0x11e4f4710>
# [False, False, False, False, False, False]
# N18_sequence29
# sequence29
# <gap_checker.Indel object at 0x11e4f4780>
# [False, False, False, False, False, False]
# N18_sequence29
# sequence29
# <gap_checker.Indel object at 0x11e4f47f0>
# [False, False, False, False, False, False]
# N18_sequence29
# sequence29
# <gap_checker.Indel object at 0x11e4f4898>
# [True, True, True, True, True, True]
# N19_sequence10
# sequence10
# <gap_checker.Indel object at 0x11e4f4908>
# [False, False, False, False, False, False]
# N19_sequence10
# sequence10
# <gap_checker.Indel object at 0x11e4f4940>
# [False, False, False, False, False, False]
# N19_sequence10
# sequence10
# <gap_checker.Indel object at 0x11e4f49b0>
# [False, False, False, False, False, False]
# N19_sequence10
# sequence10
# <gap_checker.Indel object at 0x11e4f4a58>
# [True, True, True, True, True, True]
# N22_sequence7
# sequence7
# <gap_checker.Indel object at 0x11e4f4ac8>
# [False, False, False, False, False, False]
# N22_sequence7
# sequence7
# <gap_checker.Indel object at 0x11e4f4b00>
# [False, False, False, False, False, False]
# N22_sequence7
# sequence7
# <gap_checker.Indel object at 0x11e4f4be0>
# [True, False, False, False, False, False]
# N24_N25
# N25
# <gap_checker.Indel object at 0x11e4f4c50>
# [False, False, True, False, True, False]
# N24_N25
# N25
# <gap_checker.Indel object at 0x11e4f4cc0>
# [False, False, False, False, False, False]
# N24_N25
# N25
# <gap_checker.Indel object at 0x11e4f4d30>
# [False, False, False, False, False, False]
# N24_N27
# N27
# <gap_checker.Indel object at 0x11e4f4dd8>
# [True, False, True, False, True, False]
# N6_N7
# N7
# <gap_checker.Indel object at 0x11e4f4e48>
# [True, True, True, True, True, True]
# N6_sequence5
# sequence5
# <gap_checker.Indel object at 0x11e4f4eb8>
# [False, False, False, False, False, False]
# N6_sequence5
# sequence5
# <gap_checker.Indel object at 0x11e4f4f28>
# [True, True, True, True, True, True]
# N20_sequence21
# sequence21
# <gap_checker.Indel object at 0x11e4f4f60>
# [True, True, True, True, True, True]
# N20_sequence9
# sequence9
# <gap_checker.Indel object at 0x11e4f4fd0>
# [False, False, False, False, False, False]
# N20_sequence9
# sequence9
# <gap_checker.Indel object at 0x11e4fe048>
# [True, True, True, True, True, True]
# N23_sequence13
# sequence13
# <gap_checker.Indel object at 0x11e4fe0b8>
# [False, False, False, False, False, False]
# N23_sequence13
# sequence13
# <gap_checker.Indel object at 0x11e4fe0f0>
# [False, False, False, False, False, False]
# N23_sequence13
# sequence13
# <gap_checker.Indel object at 0x11e4fe198>
# [True, True, True, True, True, True]
# N23_sequence8
# sequence8
# <gap_checker.Indel object at 0x11e4fe208>
# [True, False, True, False, True, False]
# N25_N26
# N26
# <gap_checker.Indel object at 0x11e4fe278>
# [False, False, False, False, False, False]
# N25_N26
# N26
# <gap_checker.Indel object at 0x11e4fe2e8>
# [True, False, False, False, False, False]
# N25_sequence12
# sequence12
# <gap_checker.Indel object at 0x11e4fe358>
# [False, False, False, False, False, False]
# N25_sequence12
# sequence12
# <gap_checker.Indel object at 0x11e4fe3c8>
# [False, False, False, False, False, False]
# N25_sequence12
# sequence12
# <gap_checker.Indel object at 0x11e4fe470>
# [True, False, True, False, True, True]
# N27_N28
# N28
# <gap_checker.Indel object at 0x11e4fe4a8>
# [True, True, True, True, True, True]
# N27_sequence27
# sequence27
# <gap_checker.Indel object at 0x11e4fe4e0>
# [False, False, False, False, False, False]
# N27_sequence27
# sequence27
# <gap_checker.Indel object at 0x11e4fe550>
# [False, False, False, False, False, False]
# N27_sequence27
# sequence27
# <gap_checker.Indel object at 0x11e4fe5f8>
# [False, False, False, False, False, False]
# N27_sequence27
# sequence27
# <gap_checker.Indel object at 0x11e4fe630>
# [False, False, False, False, False, False]
# N27_sequence27
# sequence27
# <gap_checker.Indel object at 0x11e4fe6a0>
# [False, False, False, False, False, False]
# N27_sequence27
# sequence27
# <gap_checker.Indel object at 0x11e4fe710>
# [True, True, True, True, True, True]
# N7_sequence14
# sequence14
# <gap_checker.Indel object at 0x11e4fe780>
# [False, False, False, False, False, False]
# N7_sequence14
# sequence14
# <gap_checker.Indel object at 0x11e4fe828>
# [True, True, True, True, True, True]
# N26_sequence2
# sequence2
# <gap_checker.Indel object at 0x11e4fe898>
# [False, False, False, False, False, False]
# N26_sequence2
# sequence2
# <gap_checker.Indel object at 0x11e4fe908>
# [False, False, False, False, False, False]
# N26_sequence2
# sequence2
# <gap_checker.Indel object at 0x11e4fe9b0>
# [True, True, True, True, True, True]
# N28_sequence4
# sequence4
# <gap_checker.Indel object at 0x11e4fea20>
# [False, False, False, False, False, False]
# N28_sequence4
# sequence4
# <gap_checker.Indel object at 0x11e4eb4e0>
# [False, True, False, False, False, False]
# N0_N1
# N1
# <gap_checker.Indel object at 0x11e4eb0f0>
# [False, False, False, False, False, False]
# N0_N17
# N17
# <gap_checker.Indel object at 0x11e4eb198>
# [False, False, False, False, False, False]
# N0_N17
# N17
# <gap_checker.Indel object at 0x11e4eb4a8>
# [False, False, False, False, False, True]
# N1_N2
# N2
# <gap_checker.Indel object at 0x11ebb0a90>
# [False, False, False, False, False, False]
# N1_N14
# N14
# <gap_checker.Indel object at 0x11ebb05f8>
# [True, True, True, True, True, True]
# N17_sequence17
# sequence17
# <gap_checker.Indel object at 0x11ebb06a0>
# [False, False, False, False, False, False]
# N17_sequence17
# sequence17
# <gap_checker.Indel object at 0x11ebb0780>
# [False, False, False, False, False, False]
# N17_sequence17
# sequence17
# <gap_checker.Indel object at 0x11ebb07f0>
# [False, False, False, False, False, False]
# N17_sequence17
# sequence17
# <gap_checker.Indel object at 0x11ebb08d0>
# [False, False, False, False, False, False]
# N17_sequence17
# sequence17
# <gap_checker.Indel object at 0x11ebb0400>
# [False, False, False, False, False, False]
# N17_sequence17
# sequence17
# <gap_checker.Indel object at 0x11ebb04a8>
# [False, False, False, False, False, False]
# N17_sequence17
# sequence17
# <gap_checker.Indel object at 0x11ebb0438>
# [False, False, False, False, False, False]
# N17_sequence17
# sequence17
# <gap_checker.Indel object at 0x11ebb00f0>
# [True, False, True, False, True, False]
# N2_N3
# N3
# <gap_checker.Indel object at 0x11ebb0278>
# [False, False, False, False, False, False]
# N2_N3
# N3
# <gap_checker.Indel object at 0x11ebb0160>
# [False, False, False, False, False, False]
# N2_N5
# N5
# <gap_checker.Indel object at 0x11ebb0748>
# [True, False, True, False, True, False]
# N14_sequence27
# sequence27
# <gap_checker.Indel object at 0x11ebb0668>
# [False, False, False, False, False, False]
# N14_sequence27
# sequence27
# <gap_checker.Indel object at 0x11ebb06d8>
# [False, False, False, False, False, False]
# N14_sequence27
# sequence27
# <gap_checker.Indel object at 0x11ebb0908>
# [False, False, False, False, False, False]
# N14_sequence27
# sequence27
# <gap_checker.Indel object at 0x11ebb0630>
# [True, False, True, False, True, False]
# N14_N15
# N15
# <gap_checker.Indel object at 0x11ebb0b00>
# [False, False, False, False, False, True]
# N14_N15
# N15
# <gap_checker.Indel object at 0x11ebb0ba8>
# [False, False, False, False, False, False]
# N14_N15
# N15
# <gap_checker.Indel object at 0x11ebb0eb8>
# [False, False, False, False, False, False]
# N14_N15
# N15
# <gap_checker.Indel object at 0x11ebb0c88>
# [True, True, True, True, True, True]
# N18_N19
# N19
# <gap_checker.Indel object at 0x11ebb0cf8>
# [False, False, False, False, False, False]
# N18_N19
# N19
# <gap_checker.Indel object at 0x11ebb09e8>
# [False, False, False, False, False, False]
# N18_N19
# N19
# <gap_checker.Indel object at 0x11ebb0940>
# [False, False, False, False, False, False]
# N18_N19
# N19
# <gap_checker.Indel object at 0x11e2027b8>
# [True, False, True, False, True, False]
# N3_N4
# N4
# <gap_checker.Indel object at 0x11e4fea58>
# [True, True, True, True, True, True]
# N3_sequence32
# sequence32
# <gap_checker.Indel object at 0x11e4feac8>
# [False, False, False, False, False, False]
# N3_sequence32
# sequence32
# <gap_checker.Indel object at 0x11e4feb70>
# [False, False, False, False, False, False]
# N3_sequence32
# sequence32
# <gap_checker.Indel object at 0x11e4feba8>
# [False, False, False, False, False, False]
# N3_sequence32
# sequence32
# <gap_checker.Indel object at 0x11e4fec18>
# [False, False, False, False, False, False]
# N3_sequence32
# sequence32
# <gap_checker.Indel object at 0x11e4fec88>
# [False, False, False, False, False, False]
# N3_sequence32
# sequence32
# <gap_checker.Indel object at 0x11e4fed30>
# [True, True, True, True, True, True]
# N5_N10
# N10
# <gap_checker.Indel object at 0x11e4feda0>
# [False, False, False, False, False, False]
# N5_N10
# N10
# <gap_checker.Indel object at 0x11e4fedd8>
# [False, False, False, False, False, False]
# N5_N10
# N10
# <gap_checker.Indel object at 0x11e4fee80>
# [False, False, False, False, False, False]
# N5_N10
# N10
# <gap_checker.Indel object at 0x11e4fef28>
# [True, True, True, True, True, True]
# N15_sequence34
# sequence34
# <gap_checker.Indel object at 0x11e4fef98>
# [False, False, False, False, False, False]
# N15_sequence34
# sequence34
# <gap_checker.Indel object at 0x11ebb4080>
# [True, True, True, True, True, True]
# N15_N16
# N16
# <gap_checker.Indel object at 0x11ebb4160>
# [False, False, True, False, True, True]
# N19_N20
# N20
# <gap_checker.Indel object at 0x11ebb4240>
# [True, True, True, True, True, True]
# N27_N28
# N28
# <gap_checker.Indel object at 0x11ebb4278>
# [False, False, False, False, False, False]
# N27_N28
# N28
# <gap_checker.Indel object at 0x11ebb4320>
# [True, True, True, True, True, True]
# N27_N38
# N38
# <gap_checker.Indel object at 0x11ebb43c8>
# [False, False, False, False, False, False]
# N27_N38
# N38
# <gap_checker.Indel object at 0x11ebb4438>
# [False, False, False, False, False, False]
# N27_N38
# N38
# <gap_checker.Indel object at 0x11ebb4470>
# [False, False, False, False, False, False]
# N27_N38
# N38
# <gap_checker.Indel object at 0x11ebb44e0>
# [False, False, False, False, False, False]
# N27_N38
# N38
# <gap_checker.Indel object at 0x11ebb4518>
# [False, False, False, False, False, False]
# N27_N38
# N38
# <gap_checker.Indel object at 0x11ebb4550>
# [True, True, True, True, True, True]
# N4_sequence5
# sequence5
# <gap_checker.Indel object at 0x11ebb45c0>
# [False, False, False, False, False, False]
# N4_sequence5
# sequence5
# <gap_checker.Indel object at 0x11ebb45f8>
# [False, False, False, False, False, False]
# N4_sequence5
# sequence5
# <gap_checker.Indel object at 0x11ebb4668>
# [False, False, False, False, False, False]
# N4_sequence5
# sequence5
# <gap_checker.Indel object at 0x11ebb4710>
# [True, True, True, True, True, True]
# N4_sequence13
# sequence13
# <gap_checker.Indel object at 0x11ebb4748>
# [False, False, False, False, False, False]
# N4_sequence13
# sequence13
# <gap_checker.Indel object at 0x11ebb47b8>
# [False, False, False, False, False, False]
# N4_sequence13
# sequence13
# <gap_checker.Indel object at 0x11ebb4860>
# [False, False, False, False, False, False]
# N4_sequence13
# sequence13
# <gap_checker.Indel object at 0x11ebb4940>
# [True, True, True, True, False, True]
# N6_N7
# N7
# <gap_checker.Indel object at 0x11ebb49b0>
# [False, False, False, False, True, False]
# N6_N7
# N7
# <gap_checker.Indel object at 0x11ebb49e8>
# [False, False, False, False, False, False]
# N6_N7
# N7
# <gap_checker.Indel object at 0x11ebb4a58>
# [False, False, False, False, False, False]
# N6_N7
# N7
# <gap_checker.Indel object at 0x11ebb4ac8>
# [False, False, False, False, False, False]
# N6_N7
# N7
# <gap_checker.Indel object at 0x11ebb4b38>
# [False, False, False, False, False, False]
# N6_N7
# N7
# <gap_checker.Indel object at 0x11ebb4b70>
# [False, False, False, False, False, False]
# N6_N7
# N7
# <gap_checker.Indel object at 0x11ebb4c18>
# [False, False, False, False, False, False]
# N6_N7
# N7
# <gap_checker.Indel object at 0x11ebb4cc0>
# [True, False, True, False, True, True]
# N6_N9
# N9
# <gap_checker.Indel object at 0x11ebb4cf8>
# [False, False, False, False, False, False]
# N6_N9
# N9
# <gap_checker.Indel object at 0x11ebb4d30>
# [False, False, False, False, False, False]
# N6_N9
# N9
# <gap_checker.Indel object at 0x11ebb4e10>
# [True, True, True, True, True, True]
# N10_sequence23
# sequence23
# <gap_checker.Indel object at 0x11ebb4e80>
# [False, False, False, False, False, False]
# N10_sequence23
# sequence23
# <gap_checker.Indel object at 0x11ebb4eb8>
# [False, False, False, False, False, False]
# N10_sequence23
# sequence23
# <gap_checker.Indel object at 0x11ebb4f60>
# [False, False, False, False, False, False]
# N10_sequence23
# sequence23
# <gap_checker.Indel object at 0x11ebb4fd0>
# [False, False, False, False, False, False]
# N10_sequence23
# sequence23
# <gap_checker.Indel object at 0x11eaec080>
# [False, False, False, False, False, False]
# N10_sequence23
# sequence23
# <gap_checker.Indel object at 0x11eaec0f0>
# [True, True, True, True, True, True]
# N20_sequence29
# sequence29
# <gap_checker.Indel object at 0x11eaec128>
# [False, False, False, False, False, False]
# N20_sequence29
# sequence29
# <gap_checker.Indel object at 0x11eaec198>
# [False, False, False, False, False, False]
# N20_sequence29
# sequence29
# <gap_checker.Indel object at 0x11eaec1d0>
# [False, False, False, False, False, False]
# N20_sequence29
# sequence29
# <gap_checker.Indel object at 0x11eaec240>
# [False, False, False, False, False, False]
# N20_sequence29
# sequence29
# <gap_checker.Indel object at 0x11eaec2b0>
# [True, True, True, True, True, True]
# N20_sequence35
# sequence35
# <gap_checker.Indel object at 0x11eaec2e8>
# [False, False, False, False, False, False]
# N20_sequence35
# sequence35
# <gap_checker.Indel object at 0x11eaec390>
# [True, True, True, True, False, False]
# N21_N22
# N22
# <gap_checker.Indel object at 0x11eaec400>
# [False, False, False, False, False, False]
# N21_N22
# N22
# <gap_checker.Indel object at 0x11eaec470>
# [True, False, True, False, True, True]
# N21_N25
# N25
# <gap_checker.Indel object at 0x11eaec588>
# [True, True, False, False, False, False]
# N7_sequence16
# sequence16
# <gap_checker.Indel object at 0x11eaec5c0>
# [False, False, False, False, False, False]
# N7_sequence16
# sequence16
# <gap_checker.Indel object at 0x11eaec630>
# [True, False, True, False, True, False]
# N9_sequence26
# sequence26
# <gap_checker.Indel object at 0x11eaec668>
# [False, False, False, False, False, False]
# N9_sequence26
# sequence26
# <gap_checker.Indel object at 0x11eaec6d8>
# [True, False, True, False, True, True]
# N9_sequence9
# sequence9
# <gap_checker.Indel object at 0x11eaec748>
# [False, False, False, False, False, False]
# N9_sequence9
# sequence9
# <gap_checker.Indel object at 0x11eaec7f0>
# [False, False, False, False, False, False]
# N9_sequence9
# sequence9
# <gap_checker.Indel object at 0x11eaec898>
# [True, True, True, True, True, True]
# N11_sequence30
# sequence30
# <gap_checker.Indel object at 0x11eaec940>
# [False, False, False, False, False, False]
# N11_sequence30
# sequence30
# <gap_checker.Indel object at 0x11eaec9e8>
# [True, True, True, True, True, True]
# N22_sequence21
# sequence21
# <gap_checker.Indel object at 0x11eaeca58>
# [False, False, False, False, False, False]
# N22_sequence21
# sequence21
# <gap_checker.Indel object at 0x11eaecb00>
# [True, True, True, True, True, True]
# N22_N23
# N23
# <gap_checker.Indel object at 0x11eaecb38>
# [False, False, False, False, False, False]
# N22_N23
# N23
# <gap_checker.Indel object at 0x11eaecba8>
# [True, False, True, False, True, True]
# N25_sequence15
# sequence15
# <gap_checker.Indel object at 0x11eaecc88>
# [True, True, True, True, True, True]
# N29_N30
# N30
# <gap_checker.Indel object at 0x11eaecd68>
# [True, True, True, True, True, True]
# N32_N33
# N33
# <gap_checker.Indel object at 0x11eaecdd8>
# [True, True, True, True, True, True]
# N32_sequence18
# sequence18
# <gap_checker.Indel object at 0x11eaece10>
# [False, False, False, False, False, False]
# N32_sequence18
# sequence18
# <gap_checker.Indel object at 0x11eaece80>
# [False, False, False, False, False, False]
# N32_sequence18
# sequence18
# <gap_checker.Indel object at 0x11eaeceb8>
# [True, True, False, False, False, False]
# N8_sequence31
# sequence31
# <gap_checker.Indel object at 0x11eaecf28>
# [False, False, False, False, False, False]
# N8_sequence31
# sequence31
# <gap_checker.Indel object at 0x11eaecf98>
# [True, True, False, False, False, False]
# N8_sequence14
# sequence14
# <gap_checker.Indel object at 0x11ebdf0b8>
# [True, True, True, True, True, True]
# N12_sequence2
# sequence2
# <gap_checker.Indel object at 0x11ebdf128>
# [True, True, True, True, True, True]
# N23_sequence33
# sequence33
# <gap_checker.Indel object at 0x11ebdf1d0>
# [True, True, True, True, True, True]
# N26_sequence1
# sequence1
# <gap_checker.Indel object at 0x11ebdf278>
# [False, False, False, False, False, False]
# N26_sequence1
# sequence1
# <gap_checker.Indel object at 0x11ebdf2b0>
# [False, False, False, False, False, False]
# N26_sequence1
# sequence1
# <gap_checker.Indel object at 0x11ebdf2e8>
# [True, True, True, True, True, True]
# N26_sequence6
# sequence6
# <gap_checker.Indel object at 0x11ebdf358>
# [True, True, True, True, True, True]
# N31_sequence12
# sequence12
# <gap_checker.Indel object at 0x11ebdf3c8>
# [False, False, False, False, False, False]
# N31_sequence12
# sequence12
# <gap_checker.Indel object at 0x11ebdf470>
# [True, True, True, True, False, True]
# N33_N35
# N35
# <gap_checker.Indel object at 0x11ebdf4a8>
# [True, True, True, True, True, True]
# N13_sequence39
# sequence39
# <gap_checker.Indel object at 0x11ebdf550>
# [True, True, True, True, True, True]
# N24_sequence8
# sequence8
# <gap_checker.Indel object at 0x11ebdf5c0>
# [True, True, True, True, False, True]
# N35_N36
# N36
# <gap_checker.Indel object at 0x11ebdf668>
# [True, True, True, True, False, True]
# N35_sequence20
# sequence20
# <gap_checker.Indel object at 0x11ebdf748>
# [True, True, True, True, True, True]
# N37_sequence19
# sequence19
# <gap_checker.Indel object at 0x11e4eb2b0>
# [True, False, True, False, True, False]
# N0_N1
# N1
# <gap_checker.Indel object at 0x11ebd5668>
# [False, False, False, False, False, False]
# N0_N1
# N1
# <gap_checker.Indel object at 0x11ebd5710>
# [False, False, False, False, False, False]
# N0_N1
# N1
# <gap_checker.Indel object at 0x11ebd5780>
# [False, False, False, False, False, False]
# N0_N1
# N1
# <gap_checker.Indel object at 0x11ebd57f0>
# [False, False, False, False, False, False]
# N0_N1
# N1
# <gap_checker.Indel object at 0x11ebd58d0>
# [False, False, False, False, False, False]
# N0_N3
# N3
# <gap_checker.Indel object at 0x11ebd5940>
# [False, False, False, False, True, False]
# N0_N3
# N3
# <gap_checker.Indel object at 0x11ebd59b0>
# [False, False, True, True, False, True]
# N1_sequence30
# sequence30
# <gap_checker.Indel object at 0x11ebd5ac8>
# [False, False, True, False, False, True]
# N3_N27
# N27
# <gap_checker.Indel object at 0x11ebd5b38>
# [True, True, False, False, True, False]
# N3_N27
# N27
# <gap_checker.Indel object at 0x11ebd5b70>
# [False, False, False, False, False, False]
# N3_N27
# N27
# <gap_checker.Indel object at 0x11ebd5c18>
# [False, False, True, True, False, True]
# N2_sequence13
# sequence13
# <gap_checker.Indel object at 0x11ebd5c88>
# [False, False, True, True, False, True]
# N2_sequence16
# sequence16
# <gap_checker.Indel object at 0x11ebd5e10>
# [True, False, True, False, True, True]
# N5_sequence2
# sequence2
# <gap_checker.Indel object at 0x11ebd5e80>
# [False, False, False, False, False, False]
# N5_sequence2
# sequence2
# <gap_checker.Indel object at 0x11ebd5eb8>
# [False, False, False, False, False, False]
# N5_sequence2
# sequence2
# <gap_checker.Indel object at 0x11ebd5f28>
# [False, False, False, False, False, False]
# N5_sequence2
# sequence2
# <gap_checker.Indel object at 0x11e505080>
# [True, False, True, False, True, True]
# N21_N22
# N22
# <gap_checker.Indel object at 0x11e5050b8>
# [False, False, False, False, False, False]
# N21_N22
# N22
# <gap_checker.Indel object at 0x11e505128>
# [False, False, False, False, False, False]
# N21_N22
# N22
# <gap_checker.Indel object at 0x11e505208>
# [True, False, True, False, True, True]
# N21_N26
# N26
# <gap_checker.Indel object at 0x11e505240>
# [False, False, False, False, False, False]
# N21_N26
# N26
# <gap_checker.Indel object at 0x11e505358>
# [True, True, False, True, True, True]
# N37_N38
# N38
# <gap_checker.Indel object at 0x11e505400>
# [False, True, True, True, True, True]
# N37_N47
# N47
# <gap_checker.Indel object at 0x11e505470>
# [False, False, False, False, False, False]
# N37_N47
# N47
# <gap_checker.Indel object at 0x11e5054e0>
# [False, False, False, False, False, False]
# N37_N47
# N47
# <gap_checker.Indel object at 0x11e505588>
# [True, False, False, False, False, True]
# N6_N7
# N7
# <gap_checker.Indel object at 0x11e505630>
# [True, False, False, False, False, True]
# N6_N15
# N15
# <gap_checker.Indel object at 0x11e5056a0>
# [False, False, False, False, True, False]
# N6_N15
# N15
# <gap_checker.Indel object at 0x11e505710>
# [True, True, True, True, True, True]
# N22_sequence26
# sequence26
# <gap_checker.Indel object at 0x11e505748>
# [False, False, False, False, False, False]
# N22_sequence26
# sequence26
# <gap_checker.Indel object at 0x11e505780>
# [False, False, False, False, False, False]
# N22_sequence26
# sequence26
# <gap_checker.Indel object at 0x11e505828>
# [True, False, True, False, True, True]
# N22_N23
# N23
# <gap_checker.Indel object at 0x11e5058d0>
# [True, False, False, False, False, True]
# N26_sequence43
# sequence43
# <gap_checker.Indel object at 0x11e505978>
# [False, False, False, False, False, False]
# N26_sequence43
# sequence43
# <gap_checker.Indel object at 0x11e5059b0>
# [False, False, False, False, False, False]
# N26_sequence43
# sequence43
# <gap_checker.Indel object at 0x11e505a20>
# [False, False, False, False, False, False]
# N26_sequence43
# sequence43
# <gap_checker.Indel object at 0x11e505a90>
# [True, False, True, False, True, True]
# N26_sequence48
# sequence48
# <gap_checker.Indel object at 0x11e505b38>
# [False, False, False, False, False, False]
# N26_sequence48
# sequence48
# <gap_checker.Indel object at 0x11e505b70>
# [False, False, False, False, False, False]
# N26_sequence48
# sequence48
# <gap_checker.Indel object at 0x11e505c18>
# [True, False, True, False, True, True]
# N29_N30
# N30
# <gap_checker.Indel object at 0x11e505cf8>
# [True, True, True, True, True, True]
# N35_sequence37
# sequence37
# <gap_checker.Indel object at 0x11e505d30>
# [False, False, False, False, False, False]
# N35_sequence37
# sequence37
# <gap_checker.Indel object at 0x11e505d68>
# [False, False, False, False, False, False]
# N35_sequence37
# sequence37
# <gap_checker.Indel object at 0x11e505dd8>
# [False, False, False, False, False, False]
# N35_sequence37
# sequence37
# <gap_checker.Indel object at 0x11e505eb8>
# [False, True, True, True, True, True]
# N38_N39
# N39
# <gap_checker.Indel object at 0x11e505ef0>
# [True, False, False, False, False, False]
# N38_N39
# N39
# <gap_checker.Indel object at 0x11e505f98>
# [True, True, True, True, True, True]
# N47_N48
# N48
# <gap_checker.Indel object at 0x11e505fd0>
# [False, False, False, False, False, False]
# N47_N48
# N48
# <gap_checker.Indel object at 0x11ebe7080>
# [False, False, False, False, False, False]
# N47_N48
# N48
# <gap_checker.Indel object at 0x11ebe70f0>
# [False, False, False, False, False, False]
# N47_N48
# N48
# <gap_checker.Indel object at 0x11ebe7198>
# [True, True, True, True, True, True]
# N47_sequence34
# sequence34
# <gap_checker.Indel object at 0x11ebe7208>
# [False, False, False, False, False, False]
# N47_sequence34
# sequence34
# <gap_checker.Indel object at 0x11ebe7278>
# [False, False, False, False, False, False]
# N47_sequence34
# sequence34
# <gap_checker.Indel object at 0x11ebe72e8>
# [False, False, False, False, False, False]
# N47_sequence34
# sequence34
# <gap_checker.Indel object at 0x11ebe7390>
# [True, True, True, True, True, True]
# N7_sequence20
# sequence20
# <gap_checker.Indel object at 0x11ebe73c8>
# [False, False, False, False, False, False]
# N7_sequence20
# sequence20
# <gap_checker.Indel object at 0x11ebe7438>
# [False, False, False, False, False, False]
# N7_sequence20
# sequence20
# <gap_checker.Indel object at 0x11ebe74e0>
# [True, False, True, False, True, False]
# N15_N16
# N16
# <gap_checker.Indel object at 0x11ebe7588>
# [True, False, True, False, True, True]
# N15_N17
# N17
# <gap_checker.Indel object at 0x11ebe75f8>
# [False, False, False, False, False, False]
# N15_N17
# N17
# <gap_checker.Indel object at 0x11ebe76a0>
# [True, True, True, True, True, True]
# N23_N25
# N25
# <gap_checker.Indel object at 0x11ebe7748>
# [False, False, False, False, False, False]
# N23_N25
# N25
# <gap_checker.Indel object at 0x11ebe7780>
# [True, False, True, False, True, True]
# N30_sequence18
# sequence18
# <gap_checker.Indel object at 0x11ebe77f0>
# [True, False, True, False, True, True]
# N30_sequence40
# sequence40
# <gap_checker.Indel object at 0x11ebe7828>
# [False, False, False, False, False, False]
# N30_sequence40
# sequence40
# <gap_checker.Indel object at 0x11ebe78d0>
# [True, True, True, True, True, True]
# N31_N32
# N32
# <gap_checker.Indel object at 0x11ebe7940>
# [False, False, False, False, False, False]
# N31_N32
# N32
# <gap_checker.Indel object at 0x11ebe79e8>
# [False, True, False, True, False, False]
# N31_N34
# N34
# <gap_checker.Indel object at 0x11ebe7a58>
# [False, False, False, False, False, False]
# N31_N34
# N34
# <gap_checker.Indel object at 0x11ebe7ac8>
# [True, True, True, True, True, True]
# N36_sequence38
# sequence38
# <gap_checker.Indel object at 0x11ebe7b70>
# [True, True, True, True, True, True]
# N39_sequence33
# sequence33
# <gap_checker.Indel object at 0x11ebe7be0>
# [False, False, False, False, False, False]
# N39_sequence33
# sequence33
# <gap_checker.Indel object at 0x11ebe7c50>
# [True, True, True, True, True, True]
# N39_sequence27
# sequence27
# <gap_checker.Indel object at 0x11ebe7cc0>
# [False, False, False, False, False, False]
# N39_sequence27
# sequence27
# <gap_checker.Indel object at 0x11ebe7d68>
# [True, False, False, False, True, False]
# N40_N41
# N41
# <gap_checker.Indel object at 0x11ebe7e80>
# [True, True, True, True, True, True]
# N8_N14
# N14
# <gap_checker.Indel object at 0x11ebe7ef0>
# [False, False, False, False, False, False]
# N8_N14
# N14
# <gap_checker.Indel object at 0x11ebe7f98>
# [False, False, False, False, False, False]
# N8_N14
# N14
# <gap_checker.Indel object at 0x11ebe8048>
# [True, False, True, False, True, False]
# N16_sequence15
# sequence15
# <gap_checker.Indel object at 0x11ebe80b8>
# [False, False, False, False, False, False]
# N16_sequence15
# sequence15
# <gap_checker.Indel object at 0x11ebe8128>
# [True, False, True, False, True, True]
# N16_sequence45
# sequence45
# <gap_checker.Indel object at 0x11ebe8198>
# [False, False, False, False, False, False]
# N16_sequence45
# sequence45
# <gap_checker.Indel object at 0x11ebe81d0>
# [False, False, False, False, False, False]
# N16_sequence45
# sequence45
# <gap_checker.Indel object at 0x11ebe8240>
# [False, False, False, False, False, False]
# N16_sequence45
# sequence45
# <gap_checker.Indel object at 0x11ebe82b0>
# [False, False, False, False, False, False]
# N16_sequence45
# sequence45
# <gap_checker.Indel object at 0x11ebe8358>
# [False, False, False, False, False, False]
# N16_sequence45
# sequence45
# <gap_checker.Indel object at 0x11ebe8400>
# [True, False, True, False, True, True]
# N17_N18
# N18
# <gap_checker.Indel object at 0x11ebe8470>
# [True, True, True, True, True, True]
# N24_sequence28
# sequence28
# <gap_checker.Indel object at 0x11ebe84e0>
# [True, True, True, True, True, True]
# N24_sequence6
# sequence6
# <gap_checker.Indel object at 0x11ebe8550>
# [False, False, False, False, False, False]
# N24_sequence6
# sequence6
# <gap_checker.Indel object at 0x11ebe85f8>
# [True, True, True, True, True, True]
# N32_N33
# N33
# <gap_checker.Indel object at 0x11ebe8668>
# [True, True, True, True, True, True]
# N32_sequence49
# sequence49
# <gap_checker.Indel object at 0x11ebe8710>
# [False, False, False, False, False, False]
# N32_sequence49
# sequence49
# <gap_checker.Indel object at 0x11ebe8780>
# [True, True, True, True, True, False]
# N34_sequence3
# sequence3
# <gap_checker.Indel object at 0x11ebe87f0>
# [True, True, True, True, True, False]
# N34_sequence29
# sequence29
# <gap_checker.Indel object at 0x11ebe8860>
# [True, True, True, True, True, True]
# N41_sequence23
# sequence23
# <gap_checker.Indel object at 0x11ebe88d0>
# [False, False, False, False, False, False]
# N41_sequence23
# sequence23
# <gap_checker.Indel object at 0x11ebe8978>
# [False, False, False, False, False, False]
# N41_sequence23
# sequence23
# <gap_checker.Indel object at 0x11ebe89e8>
# [False, False, False, False, False, False]
# N41_sequence23
# sequence23
# <gap_checker.Indel object at 0x11ebe8a58>
# [False, False, False, False, False, False]
# N41_sequence23
# sequence23
# <gap_checker.Indel object at 0x11ebe8ba8>
# [True, True, True, True, True, True]
# N9_N10
# N10
# <gap_checker.Indel object at 0x11ebe8c50>
# [True, True, True, True, True, True]
# N14_sequence47
# sequence47
# <gap_checker.Indel object at 0x11ebe8cf8>
# [True, True, True, True, True, True]
# N18_sequence8
# sequence8
# <gap_checker.Indel object at 0x11ebe8d30>
# [False, False, False, False, False, False]
# N18_sequence8
# sequence8
# <gap_checker.Indel object at 0x11ebe8da0>
# [False, False, False, False, False, False]
# N18_sequence8
# sequence8
# <gap_checker.Indel object at 0x11ebe8e10>
# [True, True, True, True, True, True]
# N33_sequence4
# sequence4
# <gap_checker.Indel object at 0x11ebe8e80>
# [True, True, True, True, False, True]
# N42_sequence39
# sequence39
# <gap_checker.Indel object at 0x11ebe8eb8>
# [False, False, False, False, True, False]
# N42_sequence39
# sequence39
# <gap_checker.Indel object at 0x11ebe8f28>
# [False, False, False, False, False, False]
# N42_sequence39
# sequence39
# <gap_checker.Indel object at 0x11ebe8f98>
# [True, True, True, True, False, True]
# N42_sequence35
# sequence35
# <gap_checker.Indel object at 0x11ebe8fd0>
# [False, False, False, False, False, False]
# N42_sequence35
# sequence35
# <gap_checker.Indel object at 0x11ebea080>
# [False, False, False, False, False, False]
# N42_sequence35
# sequence35
# <gap_checker.Indel object at 0x11ebea128>
# [True, True, True, True, True, True]
# N46_sequence7
# sequence7
# <gap_checker.Indel object at 0x11ebea1d0>
# [True, True, True, True, True, True]
# N10_N11
# N11
# <gap_checker.Indel object at 0x11ebea240>
# [True, True, True, True, True, True]
# N10_sequence44
# sequence44
# <gap_checker.Indel object at 0x11ebea2b0>
# [True, True, True, True, True, True]
# N12_sequence36
# sequence36
# <gap_checker.Indel object at 0x11ebea390>
# [True, True, True, True, True, True]
# N19_sequence22
# sequence22
# <gap_checker.Indel object at 0x11ebea3c8>
# [True, True, True, True, True, True]
# N45_sequence25
# sequence25
# <gap_checker.Indel object at 0x11ebea438>
# [True, True, True, True, True, True]
# N45_sequence14
# sequence14
# <gap_checker.Indel object at 0x11ebea4a8>
# [False, False, False, False, False, False]
# N45_sequence14
# sequence14
# <gap_checker.Indel object at 0x11ebea518>
# [True, True, True, True, True, True]
# N11_sequence11
# sequence11
# <gap_checker.Indel object at 0x11ebea588>
# [True, True, True, True, True, True]
# N20_sequence19
# sequence19
# <gap_checker.Indel object at 0x11ebea5f8>
# [False, False, False, False, False, False]
# N20_sequence19
# sequence19
